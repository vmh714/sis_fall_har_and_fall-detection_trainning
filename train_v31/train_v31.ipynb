# %% [markdown]
# # v31 — 4 kênh [3 accel + gyro_mag] (bỏ trục xoay, giữ magnitude)
#
# = v30 (windowing gyro-Trans, dps clip±500/500, head avg+max, Trans w=0.55) NHƯNG input **4 kênh**: gyro 3 trục → 1 `gyro_mag = sqrt(gx²+gy²+gz²)`.
#
# **Lý do:** 5 lớp phân biệt bằng cường độ + tư thế (accel 3 trục), KHÔNG cần trục xoay → gom gyro về magnitude. Lợi: input nhỏ hơn + **bất biến hướng lắp thiết bị** (đeo lệch vẫn đúng).
#
# **Dùng lại `cache_v30`** (6 kênh) → convert 6→4 lúc load, KHÔNG windowing lại.

# %% [markdown]
# ## 📌 4 kênh: vì sao bỏ được trục gyro
#
# - Input: `[ax, ay, az, gyro_mag]` — accel **3 trục** (giữ hướng trọng lực = tư thế), gyro gom về **1 magnitude**.
# - Bỏ trục xoay (gx/gy/gz riêng) vì 5 lớp khác nhau ở **cường độ + tư thế**, không ở **chiều xoay**.
# - Normalize: accel `clip(±8g)/8`→[-1,1]; `gyro_mag` `clip(0,500 dps)/500`→[0,1] (một phía).
# - **Bất biến hướng lắp**: magnitude không đổi theo góc đeo → deploy robust hơn.
# - (App xác định hướng/AHRS thì phải quay lại 3 gyro riêng — bài toán khác.)

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781780224.415609  948917 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — v29 (CNN thuần ESP-NN, head avg+max)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, Flatten, Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 4), n_classes=5):
    # v29 = kien truc v28 (CNN thuan ESP-NN, head avg+max). Chi khac o apply_preprocessing (gyro scale).
    #   Head avg+max: GAP pha loang xung gyro cua Trans -> them nhanh max-over-time giu dinh.
    #   Dung MaxPooling1D(full)+Flatten (op MAX_POOL_2D, ESP-NN 7.83x) thay GlobalMaxPooling (REDUCE_MAX, khong tang toc).
    inp = Input(shape=input_shape)

    x = Conv1D(24, 3, strides=2, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    x = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 100->50

    x = SeparableConv1D(48, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 50->25

    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 25->12

    # Head: avg (MEAN) + max-over-time (MAX_POOL_2D) -> bat dinh xung gyro cua Trans
    a = GlobalAveragePooling1D()(x)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x)
    m = Flatten()(m)
    x = Concatenate()([a, m])
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inp, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v31'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v31"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

# v31: 6 kenh -> 4 kenh [ax,ay,az,gyro_mag] + normalize (thay apply_preprocessing 6ch)
def _to4(X):
    if X.ndim != 3 or X.shape[0] == 0: return X
    gm = np.sqrt((X[:, :, 3:6]**2).sum(axis=2, keepdims=True))   # gyro magnitude (dps)
    X4 = np.concatenate([X[:, :, 0:3], gm], axis=2).astype(np.float32)
    X4[:, :, 0:3] = np.clip(X4[:, :, 0:3], -8.0, 8.0) / 8.0        # accel -> [-1,1]
    X4[:, :, 3:4] = np.clip(X4[:, :, 3:4], 0.0, 500.0) / 500.0     # gyro_mag -> [0,1]
    return X4
X_train, X_val, X_test = _to4(X_train), _to4(X_val), _to4(X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 4), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 4)]             0         []
#
#  conv1d (Conv1D)             (None, 100, 24)              288       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 100, 24)              96        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 100, 24)              0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 100, 32)              840       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 100, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 100, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 50, 32)               0         ['activation_1[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 50, 48)               1632      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 50, 48)               192       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 50, 48)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 48)               0         ['activation_2[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 25, 64)               3216      ['max_pooling1d_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 25, 64)               256       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 25, 64)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 12, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)                0         ['max_pooling1d_2[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['max_pooling1d_2[0][0]']
#  GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 64)                   0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 5)                    645       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7293 (28.49 KB)
# Trainable params: 6957 (27.18 KB)
# Non-trainable params: 336 (1.31 KB)
# __________________________________________________________________________________________________
# I0000 00:00:1781780226.814541  948917 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/100
# I0000 00:00:1781780228.639547  949680 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781780229.989485  949677 service.cc:153] XLA service 0x7f06a1de3b50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781780229.989503  949677 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781780229.995186  949677 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781780230.071869  949677 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 569/569 [==============================] - ETA: 0s - loss: 0.9657 - accuracy: 0.7784
# Epoch 1: val_loss improved from inf to 0.88341, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 7s 6ms/step - loss: 0.9657 - accuracy: 0.7784 - val_loss: 0.8834 - val_accuracy: 0.7298 - lr: 0.0010
# Epoch 2/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.7737 - accuracy: 0.8712
# Epoch 2: val_loss improved from 0.88341 to 0.62616, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.7735 - accuracy: 0.8712 - val_loss: 0.6262 - val_accuracy: 0.9061 - lr: 0.0010
# Epoch 3/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.7356 - accuracy: 0.8921
# Epoch 3: val_loss improved from 0.62616 to 0.59998, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.7355 - accuracy: 0.8921 - val_loss: 0.6000 - val_accuracy: 0.9178 - lr: 0.0010
# Epoch 4/100
# 569/569 [==============================] - ETA: 0s - loss: 0.7111 - accuracy: 0.9054
# Epoch 4: val_loss improved from 0.59998 to 0.58996, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.7111 - accuracy: 0.9054 - val_loss: 0.5900 - val_accuracy: 0.9216 - lr: 0.0010
# Epoch 5/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6952 - accuracy: 0.9125
# Epoch 5: val_loss did not improve from 0.58996
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6953 - accuracy: 0.9125 - val_loss: 0.5909 - val_accuracy: 0.9149 - lr: 0.0010
# Epoch 6/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6847 - accuracy: 0.9187
# Epoch 6: val_loss did not improve from 0.58996
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6846 - accuracy: 0.9187 - val_loss: 0.5911 - val_accuracy: 0.9166 - lr: 0.0010
# Epoch 7/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6747 - accuracy: 0.9246
# Epoch 7: val_loss improved from 0.58996 to 0.57276, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6753 - accuracy: 0.9244 - val_loss: 0.5728 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 8/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6660 - accuracy: 0.9289
# Epoch 8: val_loss improved from 0.57276 to 0.56743, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6662 - accuracy: 0.9288 - val_loss: 0.5674 - val_accuracy: 0.9256 - lr: 0.0010
# Epoch 9/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6592 - accuracy: 0.9313
# Epoch 9: val_loss improved from 0.56743 to 0.56380, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6592 - accuracy: 0.9313 - val_loss: 0.5638 - val_accuracy: 0.9294 - lr: 0.0010
# Epoch 10/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6587 - accuracy: 0.9325
# Epoch 10: val_loss did not improve from 0.56380
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6586 - accuracy: 0.9325 - val_loss: 0.5656 - val_accuracy: 0.9279 - lr: 0.0010
# Epoch 11/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6518 - accuracy: 0.9363
# Epoch 11: val_loss did not improve from 0.56380
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6518 - accuracy: 0.9363 - val_loss: 0.5710 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 12/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6494 - accuracy: 0.9371
# Epoch 12: val_loss improved from 0.56380 to 0.55845, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6495 - accuracy: 0.9373 - val_loss: 0.5584 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 13/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6460 - accuracy: 0.9388
# Epoch 13: val_loss improved from 0.55845 to 0.54537, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/best_model_v31.keras
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6461 - accuracy: 0.9386 - val_loss: 0.5454 - val_accuracy: 0.9370 - lr: 0.0010
# Epoch 14/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6425 - accuracy: 0.9404
# Epoch 14: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6424 - accuracy: 0.9404 - val_loss: 0.5566 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 15/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6411 - accuracy: 0.9409
# Epoch 15: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6410 - accuracy: 0.9408 - val_loss: 0.5544 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 16/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6385 - accuracy: 0.9426
# Epoch 16: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6385 - accuracy: 0.9426 - val_loss: 0.5573 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 17/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.9423
# Epoch 17: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6376 - accuracy: 0.9423 - val_loss: 0.5588 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 18/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.9442
# Epoch 18: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6358 - accuracy: 0.9440 - val_loss: 0.5525 - val_accuracy: 0.9337 - lr: 0.0010
# Epoch 19/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6300 - accuracy: 0.9460
# Epoch 19: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6300 - accuracy: 0.9460 - val_loss: 0.5482 - val_accuracy: 0.9363 - lr: 5.0000e-04
# Epoch 20/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6299 - accuracy: 0.9461
# Epoch 20: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6300 - accuracy: 0.9460 - val_loss: 0.5491 - val_accuracy: 0.9353 - lr: 5.0000e-04
# Epoch 21/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6289 - accuracy: 0.9466
# Epoch 21: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6289 - accuracy: 0.9466 - val_loss: 0.5458 - val_accuracy: 0.9353 - lr: 5.0000e-04
# Epoch 22/100
# 560/569 [============================>.] - ETA: 0s - loss: 0.6269 - accuracy: 0.9484
# Epoch 22: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6267 - accuracy: 0.9483 - val_loss: 0.5496 - val_accuracy: 0.9368 - lr: 5.0000e-04
# Epoch 23/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6277 - accuracy: 0.9478
# Epoch 23: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6277 - accuracy: 0.9477 - val_loss: 0.5472 - val_accuracy: 0.9342 - lr: 5.0000e-04
# Epoch 24/100
# 560/569 [============================>.] - ETA: 0s - loss: 0.6238 - accuracy: 0.9492
# Epoch 24: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6243 - accuracy: 0.9492 - val_loss: 0.5462 - val_accuracy: 0.9368 - lr: 2.5000e-04
# Epoch 25/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6228 - accuracy: 0.9491
# Epoch 25: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6228 - accuracy: 0.9491 - val_loss: 0.5460 - val_accuracy: 0.9356 - lr: 2.5000e-04
# Epoch 26/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6233 - accuracy: 0.9492
# Epoch 26: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6233 - accuracy: 0.9492 - val_loss: 0.5467 - val_accuracy: 0.9373 - lr: 2.5000e-04
# Epoch 27/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6231 - accuracy: 0.9499
# Epoch 27: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6230 - accuracy: 0.9500 - val_loss: 0.5486 - val_accuracy: 0.9363 - lr: 2.5000e-04
# Epoch 28/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6224 - accuracy: 0.9506
# Epoch 28: val_loss did not improve from 0.54537
# 569/569 [==============================] - 3s 5ms/step - loss: 0.6225 - accuracy: 0.9506 - val_loss: 0.5459 - val_accuracy: 0.9350 - lr: 2.5000e-04
# 24/24 [==============================] - 0s 4ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v31 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9618    0.9108    0.9356      1906
#          Run     0.9738    0.9604    0.9671      1085
#         Idle     0.8979    0.9199    0.9088      1798
#        Trans     0.7407    0.8413    0.7878       567
#         Fall     0.9812    0.9747    0.9779       750
#
#     accuracy                         0.9237      6106
#    macro avg     0.9111    0.9214    0.9154      6106
# weighted avg     0.9270    0.9237    0.9248      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 731
#   - TỶ LỆ RECALL TÉ NGÃ: 97.47%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/report_v31.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 4), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_z5zik8c/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_z5zik8c/assets
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v31/model_v31_int8.tflite  (24936 bytes)
# [*] Input : [  1 200   4] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v31.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781780318.474731  948917 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781780318.474749  948917 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781780318.474953  948917 reader.cc:83] Reading SavedModel from: /tmp/tmp_z5zik8c
# I0000 00:00:1781780318.476998  948917 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781780318.477007  948917 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp_z5zik8c
# I0000 00:00:1781780318.485481  948917 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781780318.487603  948917 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781780318.519102  948917 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp_z5zik8c
# I0000 00:00:1781780318.535907  948917 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 60994 microseconds.
# I0000 00:00:1781780318.627702  948917 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.574 M  ops, equivalently 0.287 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781780318.710086  948917 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.574 M  ops, equivalently 0.287 M  MACs
# W0000 00:00:1781780318.710106  948917 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
