# %% [markdown]
# # v30_resnet1d — ResNet-1D (v25: SE + residual) trên PIPELINE v30
#
# **Giữ nguyên kiến trúc ResNet-1D của v25** (Conv stem + 4 ResNet block SeparableConv + SE + residual, head GAP+GMP) NHƯNG chạy trên **pipeline data v30**:
# - gyro **dps clip±500/500** (gyro **sống trên INT8** — v25 pipeline cũ /2000 gyro chết).
# - **Trans cắt theo sự kiện gyro RMS>20** (nhãn sạch), augment ×0.9/1.1, Trans weight 0.55.
# - Reuse **`cache_v30`** → KHÔNG windowing lại.
#
# Mục đích: so công bằng **ResNet vs CNN-v30 vs LSTM** trên cùng data v30; và đo tác động fix gyro trên ResNet.

# %% [markdown]
# ## 📌 Ghi chú
# - Kiến trúc = **ResNet-1D v25** (SeparableConv + SE block + residual, head GAP+GMP).
# - Pipeline data = **v30** (gyro dps clip±500/500, Trans theo sự kiện gyro, augment ×0.9/1.1).
# - SE block dùng sigmoid (ESP-NN không tăng tốc) + GMP→REDUCE_MAX — giữ nguyên như v25 để so công bằng.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
#os.environ['TF_USE_LEGACY_KERAS'] = '1'
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781924538.604858 3208732 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — ResNet-1D v25 (SE + residual)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     Multiply, Add, GlobalAveragePooling1D, GlobalMaxPooling1D,
                                     Concatenate, Dropout, Dense, Reshape)
from tensorflow.keras.models import Model

def se_block_v25(x, c, ratio=4):
    # SE block (Conv1D pointwise) — nhu v25
    se = GlobalAveragePooling1D()(x)
    se = Reshape((1, c))(se)
    se = Conv1D(c // ratio, kernel_size=1, use_bias=False)(se)
    se = Activation('relu6')(se)
    se = Conv1D(c, kernel_size=1, use_bias=False)(se)
    se = Activation('sigmoid')(se)
    return Multiply()([x, se])

def resnet1d_block(x, filters, kernel_size, strides, apply_se=True):
    residual = x
    y = SeparableConv1D(filters, kernel_size, strides=strides, padding='same', use_bias=False)(x)
    y = BatchNormalization()(y); y = Activation('relu6')(y)
    y = SeparableConv1D(filters, kernel_size, strides=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    if residual.shape[-1] != filters or strides != 1:
        residual = Conv1D(filters, kernel_size=1, strides=strides, padding='same', use_bias=False)(residual)
        residual = BatchNormalization()(residual)
    if apply_se:
        y = se_block_v25(y, c=filters, ratio=4)
    y = Add()([y, residual]); y = Activation('relu6')(y)
    return Dropout(0.2)(y)

def build_model(input_shape=(200, 6), n_classes=5):
    # ResNet-1D v25 nguyen ban: stem Conv16 + 4 block (16,32,32,64) + GAP+GMP + Dense
    inputs = Input(shape=input_shape)
    x = Conv1D(16, kernel_size=3, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = resnet1d_block(x, filters=16, kernel_size=3, strides=1)
    x = resnet1d_block(x, filters=32, kernel_size=3, strides=2)
    x = resnet1d_block(x, filters=32, kernel_size=3, strides=1)
    x = resnet1d_block(x, filters=64, kernel_size=3, strides=2)
    gap = GlobalAveragePooling1D()(x)
    gmp = GlobalMaxPooling1D()(x)
    x = Concatenate()([gap, gmp])
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_resnet1d'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_resnet1d"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 1.0, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# I0000 00:00:1781924541.141241 3208732 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 200, 6)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 100, 16)   │        288 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 100, 16)   │         64 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 100, 16)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d    │ (None, 100, 16)   │        304 │ activation[0][0]  │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 16)   │         64 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 100, 16)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_1  │ (None, 100, 16)   │        304 │ activation_1[0][… │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 16)   │         64 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 16)     │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 1, 4)      │         64 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1, 4)      │          0 │ conv1d_1[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 1, 16)     │         64 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 16)     │          0 │ conv1d_2[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 100, 16)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 100, 16)   │          0 │ multiply[0][0],   │
# │                     │                   │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 100, 16)   │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 100, 16)   │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_2  │ (None, 50, 32)    │        560 │ dropout[0][0]     │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 32)    │        128 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 50, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_3  │ (None, 50, 32)    │      1,120 │ activation_5[0][… │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 32)    │        128 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 32)     │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 1, 8)      │        256 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 1, 8)      │          0 │ conv1d_4[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 1, 32)     │        256 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 1, 32)     │          0 │ conv1d_5[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 50, 32)    │        512 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 50, 32)    │          0 │ batch_normalizat… │
# │ (Multiply)          │                   │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 32)    │        128 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 50, 32)    │          0 │ multiply_1[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 50, 32)    │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 50, 32)    │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_4  │ (None, 50, 32)    │      1,120 │ dropout_1[0][0]   │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 32)    │        128 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 50, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_5  │ (None, 50, 32)    │      1,120 │ activation_9[0][… │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 32)    │        128 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 32)     │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 1, 8)      │        256 │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 1, 8)      │          0 │ conv1d_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 1, 32)     │        256 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 1, 32)     │          0 │ conv1d_7[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 50, 32)    │          0 │ batch_normalizat… │
# │ (Multiply)          │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 50, 32)    │          0 │ multiply_2[0][0], │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 50, 32)    │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 50, 32)    │          0 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_6  │ (None, 25, 64)    │      2,144 │ dropout_2[0][0]   │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 64)    │        256 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 25, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv1d_7  │ (None, 25, 64)    │      4,288 │ activation_13[0]… │
# │ (SeparableConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 64)    │        256 │ separable_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 64)     │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 1, 16)     │      1,024 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 1, 16)     │          0 │ conv1d_9[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 1, 64)     │      1,024 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 1, 64)     │          0 │ conv1d_10[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 25, 64)    │      2,048 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 25, 64)    │          0 │ batch_normalizat… │
# │ (Multiply)          │                   │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 64)    │        256 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 25, 64)    │          0 │ multiply_3[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 25, 64)    │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 25, 64)    │          0 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ dropout_3[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 64)        │          0 │ dropout_3[0][0]   │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │        645 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 19,253 (75.21 KB)
#  Trainable params: 18,453 (72.08 KB)
#  Non-trainable params: 800 (3.12 KB)
# Epoch 1/100
# I0000 00:00:1781924547.846198 3208965 service.cc:153] XLA service 0x7f14ec0533d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781924547.846219 3208965 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781924548.015617 3208965 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781924548.960640 3208965 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781924549.232565 3208965 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_11435__.97
#  25/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.2869 - loss: 3.3742
# I0000 00:00:1781924563.769402 3208965 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5606 - loss: 1.8076
# I0000 00:00:1781924568.054587 3208964 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_11435__.97
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5618 - loss: 1.8036
# Epoch 1: val_loss improved from None to 1.02623, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.6891 - loss: 1.3444 - val_accuracy: 0.6735 - val_loss: 1.0262 - learning_rate: 0.0010
# Epoch 2/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8494 - loss: 0.9224
# Epoch 2: val_loss improved from 1.02623 to 0.62569, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8673 - loss: 0.8777 - val_accuracy: 0.9021 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 3/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8938 - loss: 0.8057
# Epoch 3: val_loss improved from 0.62569 to 0.61921, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9017 - loss: 0.7915 - val_accuracy: 0.9023 - val_loss: 0.6192 - learning_rate: 0.0010
# Epoch 4/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9075 - loss: 0.7692
# Epoch 4: val_loss improved from 0.61921 to 0.59274, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9135 - loss: 0.7580 - val_accuracy: 0.9129 - val_loss: 0.5927 - learning_rate: 0.0010
# Epoch 5/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9169 - loss: 0.7509
# Epoch 5: val_loss did not improve from 0.59274
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9208 - loss: 0.7400 - val_accuracy: 0.8988 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 6/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9253 - loss: 0.7293
# Epoch 6: val_loss did not improve from 0.59274
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9254 - loss: 0.7256 - val_accuracy: 0.9043 - val_loss: 0.6026 - learning_rate: 0.0010
# Epoch 7/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9310 - loss: 0.7161
# Epoch 7: val_loss improved from 0.59274 to 0.58593, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9302 - loss: 0.7164 - val_accuracy: 0.9156 - val_loss: 0.5859 - learning_rate: 0.0010
# Epoch 8/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9333 - loss: 0.7064
# Epoch 8: val_loss improved from 0.58593 to 0.56447, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9329 - loss: 0.7057 - val_accuracy: 0.9212 - val_loss: 0.5645 - learning_rate: 0.0010
# Epoch 9/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.7026
# Epoch 9: val_loss did not improve from 0.56447
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9345 - loss: 0.7000 - val_accuracy: 0.9195 - val_loss: 0.5711 - learning_rate: 0.0010
# Epoch 10/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9378 - loss: 0.6969
# Epoch 10: val_loss improved from 0.56447 to 0.55906, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9376 - loss: 0.6955 - val_accuracy: 0.9219 - val_loss: 0.5591 - learning_rate: 0.0010
# Epoch 11/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9341 - loss: 0.7044
# Epoch 11: val_loss did not improve from 0.55906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9369 - loss: 0.6969 - val_accuracy: 0.9235 - val_loss: 0.5620 - learning_rate: 0.0010
# Epoch 12/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9350 - loss: 0.7010
# Epoch 12: val_loss improved from 0.55906 to 0.55317, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9385 - loss: 0.6901 - val_accuracy: 0.9253 - val_loss: 0.5532 - learning_rate: 0.0010
# Epoch 13/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9392 - loss: 0.6962
# Epoch 13: val_loss did not improve from 0.55317
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9401 - loss: 0.6871 - val_accuracy: 0.9252 - val_loss: 0.5539 - learning_rate: 0.0010
# Epoch 14/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9428 - loss: 0.6829
# Epoch 14: val_loss did not improve from 0.55317
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9433 - loss: 0.6787 - val_accuracy: 0.9186 - val_loss: 0.5614 - learning_rate: 0.0010
# Epoch 15/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.6813
# Epoch 15: val_loss improved from 0.55317 to 0.55085, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9441 - loss: 0.6773 - val_accuracy: 0.9285 - val_loss: 0.5509 - learning_rate: 0.0010
# Epoch 16/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9423 - loss: 0.6769
# Epoch 16: val_loss improved from 0.55085 to 0.54634, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9439 - loss: 0.6766 - val_accuracy: 0.9270 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 17/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9454 - loss: 0.6739
# Epoch 17: val_loss did not improve from 0.54634
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9454 - loss: 0.6733 - val_accuracy: 0.9262 - val_loss: 0.5464 - learning_rate: 0.0010
# Epoch 18/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9436 - loss: 0.6738
# Epoch 18: val_loss did not improve from 0.54634
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9447 - loss: 0.6729 - val_accuracy: 0.9256 - val_loss: 0.5497 - learning_rate: 0.0010
# Epoch 19/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9361 - loss: 0.6975
# Epoch 19: val_loss improved from 0.54634 to 0.54406, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9430 - loss: 0.6800 - val_accuracy: 0.9313 - val_loss: 0.5441 - learning_rate: 0.0010
# Epoch 20/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9459 - loss: 0.6709
# Epoch 20: val_loss did not improve from 0.54406
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9472 - loss: 0.6679 - val_accuracy: 0.9282 - val_loss: 0.5444 - learning_rate: 0.0010
# Epoch 21/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9480 - loss: 0.6670
# Epoch 21: val_loss did not improve from 0.54406
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9478 - loss: 0.6657 - val_accuracy: 0.9298 - val_loss: 0.5481 - learning_rate: 0.0010
# Epoch 22/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9478 - loss: 0.6654
# Epoch 22: val_loss improved from 0.54406 to 0.54269, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9489 - loss: 0.6637 - val_accuracy: 0.9314 - val_loss: 0.5427 - learning_rate: 0.0010
# Epoch 23/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.6629
# Epoch 23: val_loss improved from 0.54269 to 0.52906, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9500 - loss: 0.6614 - val_accuracy: 0.9373 - val_loss: 0.5291 - learning_rate: 0.0010
# Epoch 24/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9478 - loss: 0.6679
# Epoch 24: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9495 - loss: 0.6615 - val_accuracy: 0.9278 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 25/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9472 - loss: 0.6680
# Epoch 25: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9497 - loss: 0.6598 - val_accuracy: 0.9279 - val_loss: 0.5468 - learning_rate: 0.0010
# Epoch 26/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9519 - loss: 0.6571
# Epoch 26: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9519 - loss: 0.6576 - val_accuracy: 0.9311 - val_loss: 0.5384 - learning_rate: 0.0010
# Epoch 27/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9527 - loss: 0.6573
# Epoch 27: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9525 - loss: 0.6560 - val_accuracy: 0.9340 - val_loss: 0.5363 - learning_rate: 0.0010
# Epoch 28/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9453 - loss: 0.6707
# Epoch 28: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9506 - loss: 0.6599 - val_accuracy: 0.9325 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 29/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.6553
# Epoch 29: val_loss did not improve from 0.52906
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9553 - loss: 0.6496 - val_accuracy: 0.9356 - val_loss: 0.5317 - learning_rate: 5.0000e-04
# Epoch 30/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9568 - loss: 0.6444
# Epoch 30: val_loss improved from 0.52906 to 0.52900, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9566 - loss: 0.6458 - val_accuracy: 0.9371 - val_loss: 0.5290 - learning_rate: 5.0000e-04
# Epoch 31/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9577 - loss: 0.6416
# Epoch 31: val_loss improved from 0.52900 to 0.52817, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9574 - loss: 0.6444 - val_accuracy: 0.9377 - val_loss: 0.5282 - learning_rate: 5.0000e-04
# Epoch 32/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.6442
# Epoch 32: val_loss improved from 0.52817 to 0.52633, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9583 - loss: 0.6430 - val_accuracy: 0.9383 - val_loss: 0.5263 - learning_rate: 5.0000e-04
# Epoch 33/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9581 - loss: 0.6422
# Epoch 33: val_loss did not improve from 0.52633
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9569 - loss: 0.6453 - val_accuracy: 0.9383 - val_loss: 0.5285 - learning_rate: 5.0000e-04
# Epoch 34/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9544 - loss: 0.6462
# Epoch 34: val_loss did not improve from 0.52633
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9564 - loss: 0.6453 - val_accuracy: 0.9371 - val_loss: 0.5299 - learning_rate: 5.0000e-04
# Epoch 35/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9597 - loss: 0.6371
# Epoch 35: val_loss did not improve from 0.52633
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9578 - loss: 0.6422 - val_accuracy: 0.9348 - val_loss: 0.5295 - learning_rate: 5.0000e-04
# Epoch 36/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9596 - loss: 0.6365
# Epoch 36: val_loss did not improve from 0.52633
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9590 - loss: 0.6393 - val_accuracy: 0.9377 - val_loss: 0.5301 - learning_rate: 5.0000e-04
# Epoch 37/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9569 - loss: 0.6464
# Epoch 37: val_loss improved from 0.52633 to 0.52151, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9572 - loss: 0.6435 - val_accuracy: 0.9422 - val_loss: 0.5215 - learning_rate: 5.0000e-04
# Epoch 38/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.6438
# Epoch 38: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9595 - loss: 0.6395 - val_accuracy: 0.9387 - val_loss: 0.5277 - learning_rate: 5.0000e-04
# Epoch 39/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9581 - loss: 0.6427
# Epoch 39: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9591 - loss: 0.6399 - val_accuracy: 0.9360 - val_loss: 0.5281 - learning_rate: 5.0000e-04
# Epoch 40/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9595 - loss: 0.6393
# Epoch 40: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9596 - loss: 0.6384 - val_accuracy: 0.9403 - val_loss: 0.5228 - learning_rate: 5.0000e-04
# Epoch 41/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9572 - loss: 0.6409
# Epoch 41: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9585 - loss: 0.6391 - val_accuracy: 0.9383 - val_loss: 0.5299 - learning_rate: 5.0000e-04
# Epoch 42/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9598 - loss: 0.6363
# Epoch 42: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9594 - loss: 0.6381 - val_accuracy: 0.9377 - val_loss: 0.5245 - learning_rate: 5.0000e-04
# Epoch 43/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.6347
# Epoch 43: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9609 - loss: 0.6348 - val_accuracy: 0.9406 - val_loss: 0.5246 - learning_rate: 2.5000e-04
# Epoch 44/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9595 - loss: 0.6364
# Epoch 44: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9611 - loss: 0.6338 - val_accuracy: 0.9420 - val_loss: 0.5237 - learning_rate: 2.5000e-04
# Epoch 45/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9629 - loss: 0.6295
# Epoch 45: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9621 - loss: 0.6326 - val_accuracy: 0.9408 - val_loss: 0.5234 - learning_rate: 2.5000e-04
# Epoch 46/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9605 - loss: 0.6351
# Epoch 46: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9616 - loss: 0.6327 - val_accuracy: 0.9405 - val_loss: 0.5239 - learning_rate: 2.5000e-04
# Epoch 47/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.6360
# Epoch 47: val_loss did not improve from 0.52151
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9619 - loss: 0.6329 - val_accuracy: 0.9399 - val_loss: 0.5228 - learning_rate: 2.5000e-04
# Epoch 48/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9625 - loss: 0.6293
# Epoch 48: val_loss improved from 0.52151 to 0.52128, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9628 - loss: 0.6310 - val_accuracy: 0.9413 - val_loss: 0.5213 - learning_rate: 1.2500e-04
# Epoch 49/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9615 - loss: 0.6316
# Epoch 49: val_loss did not improve from 0.52128
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9623 - loss: 0.6307 - val_accuracy: 0.9408 - val_loss: 0.5225 - learning_rate: 1.2500e-04
# Epoch 50/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9629 - loss: 0.6293
# Epoch 50: val_loss improved from 0.52128 to 0.52091, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9625 - loss: 0.6311 - val_accuracy: 0.9410 - val_loss: 0.5209 - learning_rate: 1.2500e-04
# Epoch 51/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9624 - loss: 0.6291
# Epoch 51: val_loss did not improve from 0.52091
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9626 - loss: 0.6313 - val_accuracy: 0.9400 - val_loss: 0.5231 - learning_rate: 1.2500e-04
# Epoch 52/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.6286
# Epoch 52: val_loss did not improve from 0.52091
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9621 - loss: 0.6321 - val_accuracy: 0.9408 - val_loss: 0.5230 - learning_rate: 1.2500e-04
# Epoch 53/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9633 - loss: 0.6305
# Epoch 53: val_loss improved from 0.52091 to 0.52068, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9623 - loss: 0.6314 - val_accuracy: 0.9425 - val_loss: 0.5207 - learning_rate: 1.2500e-04
# Epoch 54/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.6329
# Epoch 54: val_loss did not improve from 0.52068
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9631 - loss: 0.6300 - val_accuracy: 0.9413 - val_loss: 0.5211 - learning_rate: 1.2500e-04
# Epoch 55/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9637 - loss: 0.6290
# Epoch 55: val_loss improved from 0.52068 to 0.51976, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9632 - loss: 0.6294 - val_accuracy: 0.9422 - val_loss: 0.5198 - learning_rate: 1.2500e-04
# Epoch 56/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9639 - loss: 0.6265
# Epoch 56: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9632 - loss: 0.6302 - val_accuracy: 0.9413 - val_loss: 0.5220 - learning_rate: 1.2500e-04
# Epoch 57/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9617 - loss: 0.6290
# Epoch 57: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9623 - loss: 0.6301 - val_accuracy: 0.9416 - val_loss: 0.5222 - learning_rate: 1.2500e-04
# Epoch 58/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.6297
# Epoch 58: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9636 - loss: 0.6289 - val_accuracy: 0.9428 - val_loss: 0.5207 - learning_rate: 1.2500e-04
# Epoch 59/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9618 - loss: 0.6315
# Epoch 59: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9629 - loss: 0.6286 - val_accuracy: 0.9422 - val_loss: 0.5213 - learning_rate: 1.2500e-04
# Epoch 60/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9633 - loss: 0.6262
# Epoch 60: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9627 - loss: 0.6299 - val_accuracy: 0.9426 - val_loss: 0.5221 - learning_rate: 1.2500e-04
# Epoch 61/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.6268
# Epoch 61: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9633 - loss: 0.6287 - val_accuracy: 0.9397 - val_loss: 0.5248 - learning_rate: 6.2500e-05
# Epoch 62/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9644 - loss: 0.6270
# Epoch 62: val_loss did not improve from 0.51976
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9630 - loss: 0.6290 - val_accuracy: 0.9420 - val_loss: 0.5221 - learning_rate: 6.2500e-05
# Epoch 63/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.6331
# Epoch 63: val_loss improved from 0.51976 to 0.51940, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9645 - loss: 0.6279 - val_accuracy: 0.9437 - val_loss: 0.5194 - learning_rate: 6.2500e-05
# Epoch 64/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9641 - loss: 0.6257
# Epoch 64: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9634 - loss: 0.6280 - val_accuracy: 0.9425 - val_loss: 0.5208 - learning_rate: 6.2500e-05
# Epoch 65/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.6322
# Epoch 65: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9632 - loss: 0.6294 - val_accuracy: 0.9428 - val_loss: 0.5208 - learning_rate: 6.2500e-05
# Epoch 66/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.6266
# Epoch 66: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9643 - loss: 0.6269 - val_accuracy: 0.9423 - val_loss: 0.5210 - learning_rate: 6.2500e-05
# Epoch 67/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9649 - loss: 0.6278
# Epoch 67: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9635 - loss: 0.6279 - val_accuracy: 0.9436 - val_loss: 0.5202 - learning_rate: 6.2500e-05
# Epoch 68/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9637 - loss: 0.6269
# Epoch 68: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9634 - loss: 0.6276 - val_accuracy: 0.9417 - val_loss: 0.5225 - learning_rate: 6.2500e-05
# Epoch 69/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9632 - loss: 0.6284
# Epoch 69: val_loss did not improve from 0.51940
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9640 - loss: 0.6273 - val_accuracy: 0.9423 - val_loss: 0.5203 - learning_rate: 3.1250e-05
# Epoch 70/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9644 - loss: 0.6263
# Epoch 70: val_loss improved from 0.51940 to 0.51929, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9642 - loss: 0.6274 - val_accuracy: 0.9446 - val_loss: 0.5193 - learning_rate: 3.1250e-05
# Epoch 71/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 0.6275
# Epoch 71: val_loss did not improve from 0.51929
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9646 - loss: 0.6261 - val_accuracy: 0.9440 - val_loss: 0.5198 - learning_rate: 3.1250e-05
# Epoch 72/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.6284
# Epoch 72: val_loss did not improve from 0.51929
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9633 - loss: 0.6266 - val_accuracy: 0.9434 - val_loss: 0.5210 - learning_rate: 3.1250e-05
# Epoch 73/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9638 - loss: 0.6302
# Epoch 73: val_loss improved from 0.51929 to 0.51925, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9634 - loss: 0.6274 - val_accuracy: 0.9436 - val_loss: 0.5193 - learning_rate: 3.1250e-05
# Epoch 74/100
# 560/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9637 - loss: 0.6286
# Epoch 74: val_loss did not improve from 0.51925
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9635 - loss: 0.6275 - val_accuracy: 0.9437 - val_loss: 0.5194 - learning_rate: 3.1250e-05
# Epoch 75/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9632 - loss: 0.6262
# Epoch 75: val_loss improved from 0.51925 to 0.51890, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/best_model_v30_resnet1d.keras
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9639 - loss: 0.6270 - val_accuracy: 0.9434 - val_loss: 0.5189 - learning_rate: 3.1250e-05
# Epoch 76/100
# 567/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9647 - loss: 0.6252
# Epoch 76: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9638 - loss: 0.6271 - val_accuracy: 0.9434 - val_loss: 0.5199 - learning_rate: 3.1250e-05
# Epoch 77/100
# 566/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9639 - loss: 0.6278
# Epoch 77: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9638 - loss: 0.6269 - val_accuracy: 0.9422 - val_loss: 0.5208 - learning_rate: 3.1250e-05
# Epoch 78/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9650 - loss: 0.6222
# Epoch 78: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9642 - loss: 0.6270 - val_accuracy: 0.9423 - val_loss: 0.5208 - learning_rate: 3.1250e-05
# Epoch 79/100
# 564/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9665 - loss: 0.6211
# Epoch 79: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9644 - loss: 0.6267 - val_accuracy: 0.9433 - val_loss: 0.5195 - learning_rate: 3.1250e-05
# Epoch 80/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9647 - loss: 0.6301
# Epoch 80: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9637 - loss: 0.6277 - val_accuracy: 0.9429 - val_loss: 0.5198 - learning_rate: 3.1250e-05
# Epoch 81/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.6282
# Epoch 81: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9640 - loss: 0.6266 - val_accuracy: 0.9429 - val_loss: 0.5204 - learning_rate: 1.5625e-05
# Epoch 82/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9640 - loss: 0.6286
# Epoch 82: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9635 - loss: 0.6270 - val_accuracy: 0.9422 - val_loss: 0.5210 - learning_rate: 1.5625e-05
# Epoch 83/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9630 - loss: 0.6272
# Epoch 83: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9634 - loss: 0.6273 - val_accuracy: 0.9425 - val_loss: 0.5203 - learning_rate: 1.5625e-05
# Epoch 84/100
# 565/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9635 - loss: 0.6274
# Epoch 84: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9629 - loss: 0.6276 - val_accuracy: 0.9429 - val_loss: 0.5202 - learning_rate: 1.5625e-05
# Epoch 85/100
# 562/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9653 - loss: 0.6268
# Epoch 85: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9640 - loss: 0.6266 - val_accuracy: 0.9434 - val_loss: 0.5201 - learning_rate: 1.5625e-05
# Epoch 86/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9655 - loss: 0.6239
# Epoch 86: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9654 - loss: 0.6254 - val_accuracy: 0.9429 - val_loss: 0.5202 - learning_rate: 7.8125e-06
# Epoch 87/100
# 561/569 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9619 - loss: 0.6322
# Epoch 87: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9640 - loss: 0.6264 - val_accuracy: 0.9434 - val_loss: 0.5192 - learning_rate: 7.8125e-06
# Epoch 88/100
# 563/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9652 - loss: 0.6283
# Epoch 88: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9649 - loss: 0.6258 - val_accuracy: 0.9436 - val_loss: 0.5193 - learning_rate: 7.8125e-06
# Epoch 89/100
# 568/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.6259
# Epoch 89: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9643 - loss: 0.6259 - val_accuracy: 0.9437 - val_loss: 0.5197 - learning_rate: 7.8125e-06
# Epoch 90/100
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9646 - loss: 0.6262
# Epoch 90: val_loss did not improve from 0.51890
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9651 - loss: 0.6265 - val_accuracy: 0.9428 - val_loss: 0.5208 - learning_rate: 7.8125e-06
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_resnet1d (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9788    0.9218    0.9495      1906
#          Run     0.9814    0.9742    0.9778      1085
#         Idle     0.8937    0.9583    0.9249      1798
#        Trans     0.8382    0.8589    0.8484       567
#         Fall     1.0000    0.9667    0.9831       750
#
#     accuracy                         0.9415      6106
#    macro avg     0.9384    0.9360    0.9367      6106
# weighted avg     0.9438    0.9415    0.9420      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 725
#   - TỶ LỆ RECALL TÉ NGÃ: 96.67%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/report_v30_resnet1d.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpirl54czw/assets
# INFO:tensorflow:Assets written to: /tmp/tmpirl54czw/assets
# Saved artifact at '/tmp/tmpirl54czw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 200, 6), dtype=tf.float32, name='keras_tensor_73')
# Output Type:
#   TensorSpec(shape=(1, 5), dtype=tf.float32, name=None)
# Captures:
#   139736560125328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736263760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736264720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736562466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736264528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736265104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736265296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736265488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736263568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736265872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736265680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736266256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736266448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736266640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736264912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736267024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736266832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736267408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736264336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736268176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736267792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736268368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736263184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736268752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736268560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736269136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736269328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736263952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736269712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736270288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736267600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736264144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736266064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736271248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736560124176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736560125136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736560124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369200080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735369201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025949264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025944848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139736025946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736262224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736263376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736262800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736262416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736267216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139732736271632: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781924902.551080 3208732 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781924902.551098 3208732 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781924902.551354 3208732 reader.cc:83] Reading SavedModel from: /tmp/tmpirl54czw
# I0000 00:00:1781924902.554127 3208732 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781924902.554146 3208732 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpirl54czw
# I0000 00:00:1781924902.578869 3208732 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781924902.584641 3208732 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781924902.728663 3208732 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpirl54czw
# I0000 00:00:1781924902.781569 3208732 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 230224 microseconds.
# I0000 00:00:1781924902.990302 3208732 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 1.105 M  ops, equivalently 0.553 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781924903.166596 3208732 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 1.105 M  ops, equivalently 0.553 M  MACs
# W0000 00:00:1781924903.166616 3208732 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d/model_v30_resnet1d_int8.tflite  (72016 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['ADD', 'CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'LOGISTIC', 'MEAN', 'MUL', 'REDUCE_MAX', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v30_resnet1d.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
