# %% [markdown]
# # v30_kd — Knowledge Distillation: teacher TCN v30 → student CNN v30
#
# **Mục tiêu:** giữ student = **CNN v30 nguyên bản** (nhanh ~20ms, arena 16.5KB, tflite 25KB trên ESP32-S3) nhưng cho học **soft-label** của teacher **TCN v30** (Trans F1 0.93 nhưng ~2058ms/infer → chỉ làm thầy, KHÔNG deploy). Điểm nghẽn của student là **Trans F1 (0.80→fw 0.85)**; KD nhắm bơm "dark knowledge" của teacher vào đây.
#
# - **Teacher:** `output_v30_tcn/best_model_v30_tcn.keras` (precompute soft-label 1 lần trên train/val).
# - **Student:** CNN v30 — chỉ tách `Dense(softmax)` → `Dense(logits)+Softmax` để KD lấy logits; **graph tflite KHÔNG đổi** (vẫn `FULLY_CONNECTED+SOFTMAX`) → size/latency/arena giống hệt v30.
# - **Loss:** `α·CE(hard, class-weight Fall×3/Trans×0.55) + (1−α)·T²·KD(soft)`. Mặc định `α=0.5, T=4.0` (chỉnh ở đầu cell train).
# - **Pipeline = v30** (gyro dps clip±500/500, Trans gyro-event, augment ×0.9/1.1). **Dùng lại `cache_v30`**.
#
# > ⚠️ **Chạy trên server `har_fall`.** Đã có `cache_v30` → **BỎ QUA cell Step 1 + Step 2 (windowing)**, chạy thẳng từ cell ML Pipeline. Cần `output_v30_tcn/best_model_v30_tcn.keras` tồn tại trước.
# > Kỳ vọng thực tế: Trans F1 ~0.85→0.88-0.90, Fall recall giữ ≥97%. Sau train → export INT8 → nhúng `model_data_v30_kd.cc/.h` vào firmware để đo trên chip.

# %% [markdown]
# ## 📌 Tài liệu: đơn vị gyro & chuẩn hóa (v30)
#
# - **Accel** (ADXL345): `raw×32/8192` → **g**; normalize `clip(±8g)/8` → ~[-1,1].
# - **Gyro** (ITG3200): `raw×4000/65536` → **dps** (KHÔNG ×π/180); normalize **`clip(±500 dps)/500`** → ~[-1,1].
#
# **Vì sao /500:** rà soát dataset → per-axis gyro p99.9 ≈ **349 dps**, max hoạt động ~366 dps (run), sensor bão hòa 2000. Clip **500** phủ đủ + headroom, dùng hết dải [-1,1] (so với /2000 cũ làm gyro bé tí → **chết khi quantize INT8**).
#
# **Gyro zero-centered** (đứng yên ≈ 0) → chỉ chia, không trừ offset.
#
# **KHỚP firmware:** firmware cũng `clip(dps,±500)/500` → train-space = deploy-space, gyro sống trên cả PC lẫn MCU.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 2. Tiền xử lý (Extract & Preprocess - Step 1)
# Chuyển đổi gia tốc (g), góc quay (rad/s) và downsample 100Hz.

# %%
import glob
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm

INPUT_DIR  = Path(WORKSPACE) / 'SisFall_dataset'
OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Processed_v30'

target_har = {'D01', 'D02', 'D03', 'D04', 'D05', 'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17', 'D18', 'D19'}
ACCEL_SCALE = 32.0 / 8192.0
GYRO_SCALE = 4000.0 / 65536.0   # raw -> dps (KHONG nhan pi/180), khop firmware

all_files = list(INPUT_DIR.rglob('*.txt'))
files_to_process = [f for f in all_files if f.name.startswith('F') or f.name[:3] in target_har]

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

for file_path in tqdm(files_to_process, desc="Preprocessing"):
    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            lines = f.readlines()
            
        data = []
        for line in lines:
            line = line.strip().rstrip(';')
            if not line: continue
            parts = line.split(',')
            if len(parts) >= 6:
                data.append([float(x) for x in parts[:6]])
                
        if not data: continue
        df = pd.DataFrame(data, columns=['ax', 'ay', 'az', 'gx', 'gy', 'gz'])
        
        df[['ax', 'ay', 'az']] *= ACCEL_SCALE
        df[['gx', 'gy', 'gz']] *= GYRO_SCALE
        df = df.iloc[::2, :].reset_index(drop=True)
        
        rel_path = file_path.relative_to(INPUT_DIR)
        out_file = OUTPUT_DIR / rel_path.parent / (file_path.stem + '.csv')
        out_file.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(out_file, index=False)
    except Exception as e:
        pass
print("Hoàn tất Step 1!")
# Out:
# Preprocessing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Step 1!

# %% [markdown]
# # 3. Cắt Window (Windowing - Step 2) — bản chỉnh cho Trans/D18/D19
#
# - **D18 (vấp khi đi)** & **D19 (nhảy nhẹ)**: chỉ lấy **1 cửa sổ Trans** tại đỉnh SVM cao nhất; phần đi bộ còn lại **bỏ hết** (không Walk, không Idle).
# - **Trans augment ×3**: dịch trước/sau 20 mẫu — **chỉ cho subject TRAIN** (tránh thổi phồng Val/Test).
# - D01/D02/D05→Walk, D03/D04→Run (sliding window); D07…D17→Trans(≤2 đỉnh)+Idle.

# %%
import numpy as np
from pathlib import Path

WINDOW_OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Windowed_v30'
GYRO_RMS_TH = 20.0     # 20 dps (gyro trong CSV da o dps)

def rolling_rms(x, w=21):
    return np.sqrt(np.convolve(x**2, np.ones(w)/w, mode='same'))

def extract_window(df, center, window_size=200):
    start, end = center - window_size // 2, center + window_size // 2
    if start < 0: start, end = 0, window_size
    if end > len(df): end, start = len(df), max(0, len(df) - window_size)
    return df.iloc[start:end]

def classify_idle(win_df):
    ax_m, ay_m, az_m = win_df['ax'].abs().mean(), win_df['ay'].abs().mean(), win_df['az'].abs().mean()
    return 'Idle_StandSit' if (ay_m > ax_m and ay_m > az_m) else 'Idle_Lie'

def gyro_event_peaks(df, min_len=10, gap=10):
    """Moi vung gyro-RMS > nguong lien tuc = 1 su kien transition; tra ve dinh cua moi su kien."""
    gmag = np.sqrt(df['gx'].values**2 + df['gy'].values**2 + df['gz'].values**2)
    grms = rolling_rms(gmag, 21)
    idx = np.where(grms > GYRO_RMS_TH)[0]
    peaks = []
    if len(idx):
        for grp in np.split(idx, np.where(np.diff(idx) > gap)[0] + 1):
            if len(grp) >= min_len:
                peaks.append(int(grp[0] + np.argmax(grms[grp[0]:grp[-1]+1])))
    return peaks

all_processed = list(OUTPUT_DIR.rglob('*.csv'))
trans_har    = {'D07','D08','D11','D12','D13','D15','D17'}   # ngoi/dung/nam -> Trans + Idle
stumble_jump = {'D18','D19'}                                  # vap/nhay -> 1 Trans tai dinh gyro
cont_har     = {'D01','D02','D03','D04','D05'}                # di/chay lien tuc

windows_generated = 0
for f in tqdm(all_processed, desc="Windowing v30 (gyro-Trans)"):
    df = pd.read_csv(f)
    if len(df) < 200: continue
    filename, prefix = f.stem, f.stem[:3]
    out_dir = WINDOW_OUTPUT_DIR / f.parent.name
    out_dir.mkdir(parents=True, exist_ok=True)

    if filename.startswith('F'):
        # Fall: 5 cua so quanh dinh va cham (accel)
        svm = np.sqrt(df['ax']**2 + df['ay']**2 + df['az']**2)
        peak_idx = int(svm.values.argmax())
        for w_idx, shift in enumerate([-60,-30,0,30,60]):
            win = extract_window(df, peak_idx+shift)
            if len(win)==200:
                win.to_csv(out_dir/f"{filename}_Fall_W{w_idx:03d}.csv", index=False); windows_generated+=1

    elif prefix in stumble_jump:
        # vap/nhay: 1 cua so Trans tai dinh gyro-RMS lon nhat
        gmag = np.sqrt(df['gx'].values**2 + df['gy'].values**2 + df['gz'].values**2)
        peak = int(rolling_rms(gmag,21).argmax())
        win = extract_window(df, peak)
        if len(win)==200:
            win.to_csv(out_dir/f"{filename}_Trans_P000.csv", index=False); windows_generated+=1

    elif prefix in trans_har:
        # TRANS theo SU KIEN gyro: moi vung RMS>20dps -> 1 cua so can dinh
        peaks = gyro_event_peaks(df)
        for i, p in enumerate(peaks):
            win = extract_window(df, p)
            if len(win)==200:
                win.to_csv(out_dir/f"{filename}_Trans_E{i:03d}.csv", index=False); windows_generated+=1
        # IDLE: sliding window co tam cach MOI su kien gyro >= 80 mau
        for start in range(0, len(df)-200+1, 100):
            center = start + 100
            if all(abs(center - p) >= 80 for p in peaks):
                win = df.iloc[start:start+200]
                win.to_csv(out_dir/f"{filename}_{classify_idle(win)}_W{start//100:03d}.csv", index=False); windows_generated+=1

    elif prefix in cont_har:
        for start in range(0, len(df)-200+1, 100):
            win = df.iloc[start:start+200]
            label = "Walk" if prefix in {'D01','D02','D05'} else "Run"
            win.to_csv(out_dir/f"{filename}_{label}_W{start//100:03d}.csv", index=False); windows_generated+=1

print(f"Hoan tat Windowing v30! Tong cua so: {windows_generated}")
# Out:
# Windowing v30 (gyro-Trans):   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoan tat Windowing v30! Tong cua so: 43615

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782105617.814871  610461 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — v30 (CNN thuần ESP-NN, head avg+max)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, Flatten, Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # STUDENT = kien truc CNN v30 NGUYEN BAN (ESP-NN, head avg+max) -> firmware khong doi.
    #   Khac duy nhat: tach Dense(softmax) -> Dense(logits, linear) + Activation(softmax).
    #   Ly do: KD can LOGITS (pre-softmax) de ap temperature. Graph tflite KHONG doi
    #   (van la FULLY_CONNECTED + SOFTMAX nhu v30) -> size/latency/arena giong het v30.
    inp = Input(shape=input_shape)

    x = Conv1D(24, 3, strides=2, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    x = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 100->50

    x = SeparableConv1D(48, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 50->25

    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 25->12

    # Head: avg (MEAN) + max-over-time (MAX_POOL_2D) -> bat dinh xung gyro cua Trans
    a = GlobalAveragePooling1D()(x)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x)
    m = Flatten()(m)
    x = Concatenate()([a, m])
    x = Dropout(0.3)(x)
    logits = Dense(n_classes, name='logits')(x)                      # pre-softmax (cho KD temperature)
    outputs = Activation('softmax', name='output_softmax')(logits)   # graph deploy = giong v30

    model = Model(inp, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# ============================================================
# KD v3 -- SELECTIVE: tin teacher theo tung lop (cao o Trans, thap o Fall/Run)
# Ly do: teacher TCN YEU hon baseline o Fall (97.07 < 97.60) & Run -> KD toan cuc keo Fall xuong.
KD_ALPHA       = 0.5
KD_TEMPERATURE = 2.0
### SELECTIVE KD: trust soft-label theo nhan that  [Walk, Run, Idle, Trans, Fall]
KD_CLASS_TRUST = [1.0, 0.6, 1.0, 1.3, 0.25]   # Fall 0.25 = gan nhu chi hoc hard label (bao ve Fall recall)
TEACHER_PATH   = f'{WORKSPACE}/output_v30_tcn/best_model_v30_tcn.keras'
# ============================================================

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_kd'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_kd"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nap + augment Trans + tien xu ly (GIONG HET v30)
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')
X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phan bo nhan train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. TEACHER precompute soft-label
print(f"[*] Load teacher TCN: {TEACHER_PATH}")
teacher = tf.keras.models.load_model(TEACHER_PATH, compile=False)
print("[*] Teacher predict soft-label...")
teacher_prob_train = teacher.predict(X_train, batch_size=256, verbose=1).astype(np.float32)
teacher_prob_val   = teacher.predict(X_val,   batch_size=256, verbose=1).astype(np.float32)

# 3. Target ghep  Y = [y_onehot(5) | teacher_prob(5)]
y_train_oh = to_categorical(y_train, num_classes=5).astype(np.float32)
y_val_oh   = to_categorical(y_val,   num_classes=5).astype(np.float32)
Y_train = np.concatenate([y_train_oh, teacher_prob_train], axis=1)
Y_val   = np.concatenate([y_val_oh,   teacher_prob_val],   axis=1)

# 4. Class weights hard-CE (GIONG v30: Fall x3, Trans x0.55)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
cw_dict = trainer.get_balanced_class_weights(y_train, weight_modifiers)
class_weight_vec = np.array([cw_dict.get(i, 1.0) for i in range(5)], dtype=np.float32)
print("Class weight vector:", class_weight_vec, "| KD trust:", KD_CLASS_TRUST)

# 5. Distiller (hard CE class-weight + soft KL co per-class TRUST)
class Distiller(tf.keras.Model):
    def __init__(self, student, n_classes=5, alpha=0.5, temperature=2.0,
                 class_weight_vec=None, kd_class_trust=None):
        super().__init__()
        self.student = student
        self.logits_model = tf.keras.Model(student.input, student.get_layer('logits').output)
        self.n = n_classes; self.alpha = float(alpha); self.T = float(temperature)
        self.cw = tf.constant(class_weight_vec, dtype=tf.float32) if class_weight_vec is not None else None
        self.kd_trust = tf.constant(kd_class_trust, dtype=tf.float32) if kd_class_trust is not None else None
        self.loss_tracker = tf.keras.metrics.Mean(name='loss')
        self.hard_tracker = tf.keras.metrics.Mean(name='hard')
        self.soft_tracker = tf.keras.metrics.Mean(name='soft')
        self.acc_tracker  = tf.keras.metrics.CategoricalAccuracy(name='accuracy')

    def call(self, x, training=False):
        return self.student(x, training=training)

    def _loss(self, x, y, training):
        y_true = y[:, :self.n]; teacher_prob = y[:, self.n:]
        student_logits = self.logits_model(x, training=training)
        student_prob   = tf.nn.softmax(student_logits)
        # hard
        hard = tf.keras.losses.categorical_crossentropy(y_true, student_prob, label_smoothing=0.1)
        if self.cw is not None:
            hard = hard * tf.reduce_sum(y_true * self.cw, axis=1)
        hard = tf.reduce_mean(hard)
        # soft (KL) co per-class trust theo nhan that
        teacher_logits = tf.math.log(teacher_prob + 1e-8)
        t_soft = tf.nn.softmax(teacher_logits / self.T)
        s_soft = tf.nn.softmax(student_logits / self.T)
        soft_ps = tf.keras.losses.kl_divergence(t_soft, s_soft)            # (B,)
        if self.kd_trust is not None:
            soft_ps = soft_ps * tf.reduce_sum(y_true * self.kd_trust, axis=1)   ### SELECTIVE KD
        soft = tf.reduce_mean(soft_ps) * (self.T ** 2)
        total = self.alpha * hard + (1.0 - self.alpha) * soft
        return total, hard, soft, y_true, student_prob

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            total, hard, soft, y_true, sp = self._loss(x, y, training=True)
        grads = tape.gradient(total, self.student.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.student.trainable_variables))
        self.loss_tracker.update_state(total); self.hard_tracker.update_state(hard)
        self.soft_tracker.update_state(soft);  self.acc_tracker.update_state(y_true, sp)
        return {'loss': self.loss_tracker.result(), 'hard': self.hard_tracker.result(),
                'soft': self.soft_tracker.result(), 'accuracy': self.acc_tracker.result()}

    def test_step(self, data):
        x, y = data
        total, hard, soft, y_true, sp = self._loss(x, y, training=False)
        self.loss_tracker.update_state(total); self.hard_tracker.update_state(hard)
        self.soft_tracker.update_state(soft);  self.acc_tracker.update_state(y_true, sp)
        return {'loss': self.loss_tracker.result(), 'hard': self.hard_tracker.result(),
                'soft': self.soft_tracker.result(), 'accuracy': self.acc_tracker.result()}

    @property
    def metrics(self):
        return [self.loss_tracker, self.hard_tracker, self.soft_tracker, self.acc_tracker]

# 6. Build student CNN v30 + Distiller
model = build_model(input_shape=(200, 6), n_classes=5)   # 'model' = STUDENT -> cell EXPORT
model.summary()
distiller = Distiller(model, n_classes=5, alpha=KD_ALPHA, temperature=KD_TEMPERATURE,
                      class_weight_vec=class_weight_vec, kd_class_trust=KD_CLASS_TRUST)
distiller.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3))

# 7. Callbacks -> monitor val_accuracy
callbacks = [
    EarlyStopping(monitor='val_accuracy', mode='max', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_accuracy', mode='max', factor=0.5, patience=5, min_lr=1e-6),
]

# 8. Train
history = distiller.fit(X_train, Y_train, validation_data=(X_val, Y_val),
                        epochs=100, batch_size=64, callbacks=callbacks, verbose=1)

# 9. Luu student
model.save(str(checkpoint_path))
print(f"[*] Da luu student tai {checkpoint_path}")

# 10. Danh gia
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phan bo nhan train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# [*] Load teacher TCN: /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn/best_model_v30_tcn.keras
# I0000 00:00:1782105620.066184  610461 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# [*] Teacher predict soft-label...
# I0000 00:00:1782105621.310946  612769 cuda_dnn.cc:461] Loaded cuDNN version 92200
# 143/143 [==============================] - 1s 3ms/step
# 26/26 [==============================] - 0s 6ms/step
# Class weight vector: [0.8628219  1.3937129  0.96470743 0.49683812 3.0614736 ] | KD trust: [1.0, 0.6, 1.0, 1.3, 0.25]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]             0         []
#
#  conv1d (Conv1D)             (None, 100, 24)              432       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 100, 24)              96        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 100, 24)              0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 100, 32)              840       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 100, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 100, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 50, 32)               0         ['activation_1[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 50, 48)               1632      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 50, 48)               192       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 50, 48)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 48)               0         ['activation_2[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 25, 64)               3216      ['max_pooling1d_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 25, 64)               256       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 25, 64)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 12, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)                0         ['max_pooling1d_2[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['max_pooling1d_2[0][0]']
#  GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 64)                   0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['concatenate[0][0]']
#
#  logits (Dense)              (None, 5)                    645       ['dropout[0][0]']
#
#  output_softmax (Activation  (None, 5)                    0         ['logits[0][0]']
#  )
#
# ==================================================================================================
# Total params: 7437 (29.05 KB)
# Trainable params: 7101 (27.74 KB)
# Non-trainable params: 336 (1.31 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# I0000 00:00:1782105625.581359  612771 service.cc:153] XLA service 0x7fa8f8320b20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782105625.581376  612771 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1782105625.585814  612771 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1782105625.660788  612771 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 569/569 [==============================] - 7s 6ms/step - loss: 0.8175 - hard: 0.9756 - soft: 0.6594 - accuracy: 0.8081 - val_loss: 0.6519 - val_hard: 0.9390 - val_soft: 0.3648 - val_accuracy: 0.8521 - lr: 0.0010
# Epoch 2/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.5591 - hard: 0.7555 - soft: 0.3627 - accuracy: 0.9063 - val_loss: 0.4741 - val_hard: 0.7357 - val_soft: 0.2124 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 3/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.5140 - hard: 0.7187 - soft: 0.3094 - accuracy: 0.9176 - val_loss: 0.4543 - val_hard: 0.7149 - val_soft: 0.1938 - val_accuracy: 0.9213 - lr: 0.0010
# Epoch 4/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4932 - hard: 0.7032 - soft: 0.2832 - accuracy: 0.9260 - val_loss: 0.4444 - val_hard: 0.7103 - val_soft: 0.1785 - val_accuracy: 0.9232 - lr: 0.0010
# Epoch 5/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4817 - hard: 0.6941 - soft: 0.2693 - accuracy: 0.9277 - val_loss: 0.4508 - val_hard: 0.7178 - val_soft: 0.1839 - val_accuracy: 0.9221 - lr: 0.0010
# Epoch 6/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4715 - hard: 0.6857 - soft: 0.2572 - accuracy: 0.9319 - val_loss: 0.4385 - val_hard: 0.7098 - val_soft: 0.1672 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 7/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4608 - hard: 0.6798 - soft: 0.2417 - accuracy: 0.9358 - val_loss: 0.4360 - val_hard: 0.7042 - val_soft: 0.1678 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 8/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4532 - hard: 0.6713 - soft: 0.2352 - accuracy: 0.9380 - val_loss: 0.4334 - val_hard: 0.6982 - val_soft: 0.1686 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 9/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4446 - hard: 0.6637 - soft: 0.2255 - accuracy: 0.9385 - val_loss: 0.4344 - val_hard: 0.7034 - val_soft: 0.1654 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 10/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4413 - hard: 0.6622 - soft: 0.2205 - accuracy: 0.9408 - val_loss: 0.4273 - val_hard: 0.6941 - val_soft: 0.1604 - val_accuracy: 0.9294 - lr: 0.0010
# Epoch 11/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4346 - hard: 0.6559 - soft: 0.2133 - accuracy: 0.9425 - val_loss: 0.4238 - val_hard: 0.6908 - val_soft: 0.1568 - val_accuracy: 0.9273 - lr: 0.0010
# Epoch 12/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4322 - hard: 0.6542 - soft: 0.2101 - accuracy: 0.9428 - val_loss: 0.4308 - val_hard: 0.7015 - val_soft: 0.1601 - val_accuracy: 0.9271 - lr: 0.0010
# Epoch 13/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4295 - hard: 0.6523 - soft: 0.2067 - accuracy: 0.9437 - val_loss: 0.4363 - val_hard: 0.6995 - val_soft: 0.1732 - val_accuracy: 0.9271 - lr: 0.0010
# Epoch 14/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4244 - hard: 0.6476 - soft: 0.2012 - accuracy: 0.9458 - val_loss: 0.4318 - val_hard: 0.7059 - val_soft: 0.1578 - val_accuracy: 0.9270 - lr: 0.0010
# Epoch 15/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4278 - hard: 0.6526 - soft: 0.2030 - accuracy: 0.9458 - val_loss: 0.4205 - val_hard: 0.6864 - val_soft: 0.1545 - val_accuracy: 0.9293 - lr: 0.0010
# Epoch 16/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4170 - hard: 0.6425 - soft: 0.1915 - accuracy: 0.9480 - val_loss: 0.4157 - val_hard: 0.6889 - val_soft: 0.1425 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 17/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4149 - hard: 0.6389 - soft: 0.1908 - accuracy: 0.9497 - val_loss: 0.4143 - val_hard: 0.6870 - val_soft: 0.1416 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 18/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4134 - hard: 0.6399 - soft: 0.1868 - accuracy: 0.9488 - val_loss: 0.4159 - val_hard: 0.6874 - val_soft: 0.1445 - val_accuracy: 0.9316 - lr: 5.0000e-04
# Epoch 19/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4118 - hard: 0.6379 - soft: 0.1857 - accuracy: 0.9492 - val_loss: 0.4108 - val_hard: 0.6839 - val_soft: 0.1376 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 20/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4101 - hard: 0.6373 - soft: 0.1829 - accuracy: 0.9498 - val_loss: 0.4128 - val_hard: 0.6896 - val_soft: 0.1360 - val_accuracy: 0.9321 - lr: 5.0000e-04
# Epoch 21/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4082 - hard: 0.6351 - soft: 0.1813 - accuracy: 0.9504 - val_loss: 0.4090 - val_hard: 0.6823 - val_soft: 0.1357 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 22/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4086 - hard: 0.6354 - soft: 0.1817 - accuracy: 0.9505 - val_loss: 0.4088 - val_hard: 0.6817 - val_soft: 0.1360 - val_accuracy: 0.9327 - lr: 5.0000e-04
# Epoch 23/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4112 - hard: 0.6382 - soft: 0.1842 - accuracy: 0.9504 - val_loss: 0.4109 - val_hard: 0.6862 - val_soft: 0.1355 - val_accuracy: 0.9307 - lr: 5.0000e-04
# Epoch 24/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4072 - hard: 0.6342 - soft: 0.1801 - accuracy: 0.9512 - val_loss: 0.4075 - val_hard: 0.6823 - val_soft: 0.1326 - val_accuracy: 0.9324 - lr: 5.0000e-04
# Epoch 25/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4050 - hard: 0.6331 - soft: 0.1769 - accuracy: 0.9515 - val_loss: 0.4078 - val_hard: 0.6842 - val_soft: 0.1315 - val_accuracy: 0.9314 - lr: 5.0000e-04
# Epoch 26/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4023 - hard: 0.6305 - soft: 0.1741 - accuracy: 0.9528 - val_loss: 0.4086 - val_hard: 0.6832 - val_soft: 0.1339 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 27/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4042 - hard: 0.6319 - soft: 0.1764 - accuracy: 0.9525 - val_loss: 0.4092 - val_hard: 0.6844 - val_soft: 0.1341 - val_accuracy: 0.9307 - lr: 5.0000e-04
# Epoch 28/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4008 - hard: 0.6299 - soft: 0.1717 - accuracy: 0.9538 - val_loss: 0.4050 - val_hard: 0.6799 - val_soft: 0.1301 - val_accuracy: 0.9337 - lr: 2.5000e-04
# Epoch 29/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4012 - hard: 0.6303 - soft: 0.1721 - accuracy: 0.9531 - val_loss: 0.4034 - val_hard: 0.6784 - val_soft: 0.1284 - val_accuracy: 0.9321 - lr: 2.5000e-04
# Epoch 30/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.4003 - hard: 0.6290 - soft: 0.1715 - accuracy: 0.9531 - val_loss: 0.4060 - val_hard: 0.6825 - val_soft: 0.1295 - val_accuracy: 0.9313 - lr: 2.5000e-04
# Epoch 31/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3998 - hard: 0.6301 - soft: 0.1695 - accuracy: 0.9533 - val_loss: 0.4082 - val_hard: 0.6859 - val_soft: 0.1306 - val_accuracy: 0.9305 - lr: 2.5000e-04
# Epoch 32/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3990 - hard: 0.6282 - soft: 0.1698 - accuracy: 0.9538 - val_loss: 0.4083 - val_hard: 0.6863 - val_soft: 0.1304 - val_accuracy: 0.9310 - lr: 2.5000e-04
# Epoch 33/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3985 - hard: 0.6291 - soft: 0.1680 - accuracy: 0.9548 - val_loss: 0.4036 - val_hard: 0.6795 - val_soft: 0.1276 - val_accuracy: 0.9328 - lr: 2.5000e-04
# Epoch 34/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3989 - hard: 0.6276 - soft: 0.1701 - accuracy: 0.9543 - val_loss: 0.4051 - val_hard: 0.6821 - val_soft: 0.1280 - val_accuracy: 0.9317 - lr: 1.2500e-04
# Epoch 35/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3955 - hard: 0.6260 - soft: 0.1649 - accuracy: 0.9545 - val_loss: 0.4052 - val_hard: 0.6825 - val_soft: 0.1279 - val_accuracy: 0.9321 - lr: 1.2500e-04
# Epoch 36/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3971 - hard: 0.6263 - soft: 0.1678 - accuracy: 0.9546 - val_loss: 0.4039 - val_hard: 0.6808 - val_soft: 0.1269 - val_accuracy: 0.9328 - lr: 1.2500e-04
# Epoch 37/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3957 - hard: 0.6252 - soft: 0.1662 - accuracy: 0.9544 - val_loss: 0.4041 - val_hard: 0.6808 - val_soft: 0.1275 - val_accuracy: 0.9321 - lr: 1.2500e-04
# Epoch 38/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3938 - hard: 0.6246 - soft: 0.1630 - accuracy: 0.9569 - val_loss: 0.4037 - val_hard: 0.6805 - val_soft: 0.1269 - val_accuracy: 0.9331 - lr: 1.2500e-04
# Epoch 39/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3977 - hard: 0.6314 - soft: 0.1640 - accuracy: 0.9553 - val_loss: 0.4029 - val_hard: 0.6791 - val_soft: 0.1267 - val_accuracy: 0.9339 - lr: 6.2500e-05
# Epoch 40/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3950 - hard: 0.6253 - soft: 0.1648 - accuracy: 0.9560 - val_loss: 0.4027 - val_hard: 0.6792 - val_soft: 0.1263 - val_accuracy: 0.9333 - lr: 6.2500e-05
# Epoch 41/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3938 - hard: 0.6242 - soft: 0.1633 - accuracy: 0.9553 - val_loss: 0.4028 - val_hard: 0.6797 - val_soft: 0.1260 - val_accuracy: 0.9337 - lr: 6.2500e-05
# Epoch 42/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3941 - hard: 0.6240 - soft: 0.1642 - accuracy: 0.9554 - val_loss: 0.4032 - val_hard: 0.6804 - val_soft: 0.1261 - val_accuracy: 0.9328 - lr: 6.2500e-05
# Epoch 43/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3942 - hard: 0.6248 - soft: 0.1637 - accuracy: 0.9551 - val_loss: 0.4031 - val_hard: 0.6798 - val_soft: 0.1264 - val_accuracy: 0.9327 - lr: 6.2500e-05
# Epoch 44/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3941 - hard: 0.6241 - soft: 0.1642 - accuracy: 0.9552 - val_loss: 0.4036 - val_hard: 0.6813 - val_soft: 0.1260 - val_accuracy: 0.9331 - lr: 6.2500e-05
# Epoch 45/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3956 - hard: 0.6264 - soft: 0.1648 - accuracy: 0.9559 - val_loss: 0.4023 - val_hard: 0.6793 - val_soft: 0.1254 - val_accuracy: 0.9336 - lr: 3.1250e-05
# Epoch 46/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3937 - hard: 0.6245 - soft: 0.1628 - accuracy: 0.9560 - val_loss: 0.4027 - val_hard: 0.6796 - val_soft: 0.1257 - val_accuracy: 0.9336 - lr: 3.1250e-05
# Epoch 47/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3948 - hard: 0.6252 - soft: 0.1645 - accuracy: 0.9553 - val_loss: 0.4028 - val_hard: 0.6799 - val_soft: 0.1257 - val_accuracy: 0.9331 - lr: 3.1250e-05
# Epoch 48/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3936 - hard: 0.6239 - soft: 0.1633 - accuracy: 0.9555 - val_loss: 0.4025 - val_hard: 0.6796 - val_soft: 0.1253 - val_accuracy: 0.9333 - lr: 3.1250e-05
# Epoch 49/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3944 - hard: 0.6242 - soft: 0.1646 - accuracy: 0.9558 - val_loss: 0.4024 - val_hard: 0.6795 - val_soft: 0.1253 - val_accuracy: 0.9336 - lr: 3.1250e-05
# Epoch 50/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3938 - hard: 0.6238 - soft: 0.1638 - accuracy: 0.9555 - val_loss: 0.4023 - val_hard: 0.6794 - val_soft: 0.1253 - val_accuracy: 0.9331 - lr: 1.5625e-05
# Epoch 51/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3931 - hard: 0.6241 - soft: 0.1621 - accuracy: 0.9555 - val_loss: 0.4026 - val_hard: 0.6797 - val_soft: 0.1256 - val_accuracy: 0.9333 - lr: 1.5625e-05
# Epoch 52/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3944 - hard: 0.6249 - soft: 0.1639 - accuracy: 0.9551 - val_loss: 0.4024 - val_hard: 0.6795 - val_soft: 0.1253 - val_accuracy: 0.9330 - lr: 1.5625e-05
# Epoch 53/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3939 - hard: 0.6247 - soft: 0.1630 - accuracy: 0.9555 - val_loss: 0.4028 - val_hard: 0.6798 - val_soft: 0.1258 - val_accuracy: 0.9328 - lr: 1.5625e-05
# Epoch 54/100
# 569/569 [==============================] - 3s 5ms/step - loss: 0.3929 - hard: 0.6233 - soft: 0.1626 - accuracy: 0.9560 - val_loss: 0.4025 - val_hard: 0.6796 - val_soft: 0.1253 - val_accuracy: 0.9328 - lr: 1.5625e-05
# [*] Da luu student tai /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_kd/best_model_v30_kd.keras
# 24/24 [==============================] - 0s 3ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_kd (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9605    0.9323    0.9462      1906
#          Run     0.9820    0.9576    0.9697      1085
#         Idle     0.9097    0.9082    0.9090      1798
#        Trans     0.7474    0.8818    0.8091       567
#         Fall     0.9946    0.9733    0.9838       750
#
#     accuracy                         0.9301      6106
#    macro avg     0.9189    0.9307    0.9236      6106
# weighted avg     0.9338    0.9301    0.9313      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 730
#   - TỶ LỆ RECALL TÉ NGÃ: 97.33%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_kd/report_v30_kd.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpccwuwlup/assets
# INFO:tensorflow:Assets written to: /tmp/tmpccwuwlup/assets
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_kd/model_v30_kd_int8.tflite  (25088 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v30_kd.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1782105786.847823  610461 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1782105786.847834  610461 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1782105786.848010  610461 reader.cc:83] Reading SavedModel from: /tmp/tmpccwuwlup
# I0000 00:00:1782105786.850247  610461 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1782105786.850253  610461 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpccwuwlup
# I0000 00:00:1782105786.859993  610461 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1782105786.861544  610461 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1782105786.890296  610461 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpccwuwlup
# I0000 00:00:1782105786.903246  610461 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 55249 microseconds.
# I0000 00:00:1782105786.999762  610461 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1782105787.082413  610461 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# W0000 00:00:1782105787.082425  610461 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
