# %% [markdown]
# # v32_w128 — CNN ESP-NN (từ v30) · window **128 mẫu** (~1.28s @100Hz)
#
# Kiến trúc = **v30/v29** (CNN thuần ESP-NN, head avg+max; gyro **dps clip±500/500**; Trans weight 0.55) — **GIỮ NGUYÊN để so apples-to-apples**. Chỉ đổi:
# - **Window size 200 → 128** (1.28s).
# - **Fall cắt event-centered** quanh đỉnh accel-SVM, **căn lệch `FALL_LEFT_RATIO=0.45`** (chừa chỗ cho pha settle), augment vị trí qua `FALL_SHIFTS`.
#
# **Mọi tham số window gom ở cell cấu hình kế tiếp** (`WINDOW_SIZE / VTAG / FALL_SHIFTS / FALL_LEFT_RATIO`) — đổi window chỉ sửa 1 chỗ.
#
# **Cache riêng `cache_v32_w128`** (windowing khác → cắt lại 1 lần). Step1 `SisFall_dataset_Processed_v32` dùng chung w128/w256.

# %% [markdown]
# ## 📌 Tài liệu: đơn vị gyro & chuẩn hóa (v32)
#
# - **Accel** (ADXL345): `raw×32/8192` → **g**; normalize `clip(±8g)/8` → ~[-1,1].
# - **Gyro** (ITG3200): `raw×4000/65536` → **dps** (KHÔNG ×π/180); normalize **`clip(±500 dps)/500`** → ~[-1,1].
#
# **Vì sao /500:** rà soát dataset → per-axis gyro p99.9 ≈ **349 dps**, max hoạt động ~366 dps (run), sensor bão hòa 2000. Clip **500** phủ đủ + headroom, dùng hết dải [-1,1] (so với /2000 cũ làm gyro bé tí → **chết khi quantize INT8**).
#
# **Gyro zero-centered** (đứng yên ≈ 0) → chỉ chia, không trừ offset.
#
# **KHỚP firmware:** firmware cũng `clip(dps,±500)/500` → train-space = deploy-space, gyro sống trên cả PC lẫn MCU.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

# ============================================================
# CẤU HÌNH THÍ NGHIỆM v32 — chỉ sửa block này khi đổi window size.
# Mọi cell sau (step1/windowing/pipeline/train/export) đọc các biến này.
# ============================================================
WINDOW_SIZE     = 128                       # 1.28s @100Hz — gọn, nhanh; biên Fall mỏng hơn 200 nên cắt event-centered
VTAG            = 'v32_w128'
FALL_SHIFTS     = [-24, -12, 0, 12, 24]     # augment vị trí cú ngã (scale nhỏ theo window 128)
FALL_LEFT_RATIO = 0.45                      # đặt đỉnh va chạm ở ~45% cửa sổ -> chừa thêm chỗ cho pha settle/post-impact
# ----- dẫn xuất (không cần sửa) -----
IDLE_STRIDE = WINDOW_SIZE // 2
IDLE_DIST   = int(round(WINDOW_SIZE * 0.4))
print(f'[CFG] {VTAG} | WINDOW_SIZE={WINDOW_SIZE} | FALL_SHIFTS={FALL_SHIFTS} | FALL_LEFT_RATIO={FALL_LEFT_RATIO} | IDLE_STRIDE={IDLE_STRIDE} | IDLE_DIST={IDLE_DIST}')

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# [CFG] v32_w128 | WINDOW_SIZE=128 | FALL_SHIFTS=[-24, -12, 0, 12, 24] | FALL_LEFT_RATIO=0.45 | IDLE_STRIDE=64 | IDLE_DIST=51
# Workspace đã tồn tại!

# %% [markdown]
# # 2. Tiền xử lý (Extract & Preprocess - Step 1)
# Chuyển gia tốc → **g** (`×32/8192`), gyro → **dps** (`×4000/65536`, **KHÔNG ×π/180** — khớp firmware), và downsample 200→100Hz (`iloc[::2]`).
# Output `SisFall_dataset_Processed_v32` **độc lập window-size** → dùng chung w128/w256 (có skip-if-exists).

# %%
import glob
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm

INPUT_DIR  = Path(WORKSPACE) / 'SisFall_dataset'
OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Processed_v32'   # độc lập window-size -> dùng chung w128/w256

target_har = {'D01', 'D02', 'D03', 'D04', 'D05', 'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17', 'D18', 'D19'}
ACCEL_SCALE = 32.0 / 8192.0
GYRO_SCALE = 4000.0 / 65536.0   # raw -> dps (KHONG nhan pi/180), khop firmware

if OUTPUT_DIR.exists() and any(OUTPUT_DIR.rglob('*.csv')):
    print(f"[*] Đã có {OUTPUT_DIR} (downsample+convert không phụ thuộc window) -> BỎ QUA Step 1.")
else:
    all_files = list(INPUT_DIR.rglob('*.txt'))
    files_to_process = [f for f in all_files if f.name.startswith('F') or f.name[:3] in target_har]
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    for file_path in tqdm(files_to_process, desc="Preprocessing"):
        try:
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                lines = f.readlines()
            data = []
            for line in lines:
                line = line.strip().rstrip(';')
                if not line: continue
                parts = line.split(',')
                if len(parts) >= 6:
                    data.append([float(x) for x in parts[:6]])
            if not data: continue
            df = pd.DataFrame(data, columns=['ax', 'ay', 'az', 'gx', 'gy', 'gz'])
            df[['ax', 'ay', 'az']] *= ACCEL_SCALE
            df[['gx', 'gy', 'gz']] *= GYRO_SCALE
            df = df.iloc[::2, :].reset_index(drop=True)
            rel_path = file_path.relative_to(INPUT_DIR)
            out_file = OUTPUT_DIR / rel_path.parent / (file_path.stem + '.csv')
            out_file.parent.mkdir(parents=True, exist_ok=True)
            df.to_csv(out_file, index=False)
        except Exception as e:
            pass
    print("Hoàn tất Step 1!")
# Out:
# Preprocessing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Step 1!

# %% [markdown]
# # 3. Cắt Window (Windowing - Step 2) — parameterized theo `WINDOW_SIZE`
#
# - **Fall**: chùm cửa sổ quanh **đỉnh accel-SVM** (impact), **căn lệch `FALL_LEFT_RATIO`** (đẩy đỉnh va chạm về ~L% cửa sổ để chừa chỗ pha settle), augment vị trí bằng `FALL_SHIFTS`.
# - **D18 (vấp)/D19 (nhảy)**: 1 cửa sổ Trans tại đỉnh gyro-RMS; phần đi bộ còn lại **bỏ hết**.
# - **D07…D17**: Trans theo **sự kiện gyro-RMS > 20 dps** (mỗi vùng liên tục = 1 cửa sổ căn đỉnh) + Idle (tâm cách mọi sự kiện ≥ `IDLE_DIST`).
# - **D01/D02/D05 → Walk**, **D03/D04 → Run**: sliding window stride `WINDOW_SIZE//2`.
# - Output namespace riêng **`SisFall_dataset_Windowed_<VTAG>`** (không trộn cache windowing khác).

# %%
import numpy as np
from pathlib import Path

# Windowing v32 — parameterized theo WINDOW_SIZE/FALL_* (định nghĩa ở cell cấu hình).
# Fall: cắt quanh ĐỈNH va chạm (accel SVM), căn lệch FALL_LEFT_RATIO để ôm free-fall + impact + settle.
# Trans: cắt theo SỰ KIỆN gyro-RMS (>20 dps). Idle/Walk/Run: sliding stride = WINDOW_SIZE//2.
WINDOW_OUTPUT_DIR = Path(WORKSPACE) / f'SisFall_dataset_Windowed_{VTAG}'
GYRO_RMS_TH = 20.0     # 20 dps (gyro trong CSV da o dps)

def rolling_rms(x, w=21):
    return np.sqrt(np.convolve(x**2, np.ones(w)/w, mode='same'))

def extract_window(df, center, window_size=WINDOW_SIZE, left_ratio=0.5):
    """Cắt cửa sổ quanh center. left_ratio=0.5 -> căn giữa; <0.5 -> đẩy center sang trái (chừa nhiều mẫu phía sau)."""
    left = int(round(window_size * left_ratio))
    start, end = center - left, center - left + window_size
    if start < 0: start, end = 0, window_size
    if end > len(df): end, start = len(df), max(0, len(df) - window_size)
    return df.iloc[start:end]

def classify_idle(win_df):
    ax_m, ay_m, az_m = win_df['ax'].abs().mean(), win_df['ay'].abs().mean(), win_df['az'].abs().mean()
    return 'Idle_StandSit' if (ay_m > ax_m and ay_m > az_m) else 'Idle_Lie'

def gyro_event_peaks(df, min_len=10, gap=10):
    """Moi vung gyro-RMS > nguong lien tuc = 1 su kien transition; tra ve dinh cua moi su kien."""
    gmag = np.sqrt(df['gx'].values**2 + df['gy'].values**2 + df['gz'].values**2)
    grms = rolling_rms(gmag, 21)
    idx = np.where(grms > GYRO_RMS_TH)[0]
    peaks = []
    if len(idx):
        for grp in np.split(idx, np.where(np.diff(idx) > gap)[0] + 1):
            if len(grp) >= min_len:
                peaks.append(int(grp[0] + np.argmax(grms[grp[0]:grp[-1]+1])))
    return peaks

all_processed = list(OUTPUT_DIR.rglob('*.csv'))
trans_har    = {'D07','D08','D11','D12','D13','D15','D17'}   # ngoi/dung/nam -> Trans + Idle
stumble_jump = {'D18','D19'}                                  # vap/nhay -> 1 Trans tai dinh gyro
cont_har     = {'D01','D02','D03','D04','D05'}                # di/chay lien tuc

windows_generated = 0
for f in tqdm(all_processed, desc=f"Windowing {VTAG} (W={WINDOW_SIZE})"):
    df = pd.read_csv(f)
    if len(df) < WINDOW_SIZE: continue
    filename, prefix = f.stem, f.stem[:3]
    out_dir = WINDOW_OUTPUT_DIR / f.parent.name
    out_dir.mkdir(parents=True, exist_ok=True)

    if filename.startswith('F'):
        # Fall: cat quanh dinh va cham (accel SVM), can lech FALL_LEFT_RATIO + augment vi tri
        svm = np.sqrt(df['ax']**2 + df['ay']**2 + df['az']**2)
        peak_idx = int(svm.values.argmax())
        for w_idx, shift in enumerate(FALL_SHIFTS):
            win = extract_window(df, peak_idx + shift, WINDOW_SIZE, FALL_LEFT_RATIO)
            if len(win) == WINDOW_SIZE:
                win.to_csv(out_dir/f"{filename}_Fall_W{w_idx:03d}.csv", index=False); windows_generated += 1

    elif prefix in stumble_jump:
        # vap/nhay: 1 cua so Trans tai dinh gyro-RMS lon nhat
        gmag = np.sqrt(df['gx'].values**2 + df['gy'].values**2 + df['gz'].values**2)
        peak = int(rolling_rms(gmag, 21).argmax())
        win = extract_window(df, peak, WINDOW_SIZE)
        if len(win) == WINDOW_SIZE:
            win.to_csv(out_dir/f"{filename}_Trans_P000.csv", index=False); windows_generated += 1

    elif prefix in trans_har:
        # TRANS theo SU KIEN gyro: moi vung RMS>20dps -> 1 cua so can dinh
        peaks = gyro_event_peaks(df)
        for i, p in enumerate(peaks):
            win = extract_window(df, p, WINDOW_SIZE)
            if len(win) == WINDOW_SIZE:
                win.to_csv(out_dir/f"{filename}_Trans_E{i:03d}.csv", index=False); windows_generated += 1
        # IDLE: sliding window co tam cach MOI su kien gyro >= IDLE_DIST mau
        for start in range(0, len(df)-WINDOW_SIZE+1, IDLE_STRIDE):
            center = start + WINDOW_SIZE//2
            if all(abs(center - p) >= IDLE_DIST for p in peaks):
                win = df.iloc[start:start+WINDOW_SIZE]
                win.to_csv(out_dir/f"{filename}_{classify_idle(win)}_W{start//IDLE_STRIDE:03d}.csv", index=False); windows_generated += 1

    elif prefix in cont_har:
        for start in range(0, len(df)-WINDOW_SIZE+1, IDLE_STRIDE):
            win = df.iloc[start:start+WINDOW_SIZE]
            label = "Walk" if prefix in {'D01','D02','D05'} else "Run"
            win.to_csv(out_dir/f"{filename}_{label}_W{start//IDLE_STRIDE:03d}.csv", index=False); windows_generated += 1

print(f"Hoan tat Windowing {VTAG}! Tong cua so: {windows_generated}")
# Out:
# Windowing v32_w128 (W=128):   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoan tat Windowing v32_w128! Tong cua so: 63514

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != WINDOW_SIZE: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782098146.394983  488822 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — v32 (CNN thuần ESP-NN, head avg+max — y hệt v30/v29)
# `build_model` **length-agnostic**: stem Conv1D stride2 → 3×(SeparableConv1D + MaxPool) → head GAP ⊕ MaxPool(full)+Flatten → Dense. Chỉ cần truyền `input_shape=(WINDOW_SIZE, 6)`; pooling `pool_size=x.shape[1]` tự thích nghi độ dài.

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, Flatten, Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # v29 = kien truc v28 (CNN thuan ESP-NN, head avg+max). Chi khac o apply_preprocessing (gyro scale).
    #   Head avg+max: GAP pha loang xung gyro cua Trans -> them nhanh max-over-time giu dinh.
    #   Dung MaxPooling1D(full)+Flatten (op MAX_POOL_2D, ESP-NN 7.83x) thay GlobalMaxPooling (REDUCE_MAX, khong tang toc).
    inp = Input(shape=input_shape)

    x = Conv1D(24, 3, strides=2, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    x = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 100->50

    x = SeparableConv1D(48, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 50->25

    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 25->12

    # Head: avg (MEAN) + max-over-time (MAX_POOL_2D) -> bat dinh xung gyro cua Trans
    a = GlobalAveragePooling1D()(x)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x)
    m = Flatten()(m)
    x = Concatenate()([a, m])
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inp, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_{VTAG}'
        cache_dir = f'{WORKSPACE}/cache_{VTAG}'
        out_dir   = f'{WORKSPACE}/output_{VTAG}'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = VTAG

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(WINDOW_SIZE, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Đang đọc file CSV từ /media/data3/users/hungvm/dataset/sisfall/workspace/SisFall_dataset_Windowed_v32_w128...
#   0%|          | 0/63514 [00:00<?, ?it/s]
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 13249, 'Run': 8170, 'Idle': 13418, 'Trans': 8049, 'Fall': 7125}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 6)]             0         []
#
#  conv1d (Conv1D)             (None, 64, 24)               432       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 64, 24)               96        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 64, 24)               0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 64, 32)               840       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 64, 32)               128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 64, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 32, 32)               0         ['activation_1[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 32, 48)               1632      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 32, 48)               192       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 48)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 16, 48)               0         ['activation_2[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 16, 64)               3216      ['max_pooling1d_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 16, 64)               256       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 16, 64)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 8, 64)                0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)                0         ['max_pooling1d_2[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['max_pooling1d_2[0][0]']
#  GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 64)                   0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 5)                    645       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7437 (29.05 KB)
# Trainable params: 7101 (27.74 KB)
# Non-trainable params: 336 (1.31 KB)
# __________________________________________________________________________________________________
# I0000 00:00:1782098202.211252  488822 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/100
# I0000 00:00:1782098203.882579  491734 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1782098205.178974  491734 service.cc:153] XLA service 0x7fd4d241c860 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782098205.179004  491734 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1782098205.183408  491734 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1782098205.256649  491734 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 [==============================] - ETA: 0s - loss: 0.9899 - accuracy: 0.7807
# Epoch 1: val_loss improved from inf to 0.63917, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 8s 5ms/step - loss: 0.9899 - accuracy: 0.7807 - val_loss: 0.6392 - val_accuracy: 0.9009 - lr: 0.0010
# Epoch 2/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.7611 - accuracy: 0.8754
# Epoch 2: val_loss improved from 0.63917 to 0.61721, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7611 - accuracy: 0.8754 - val_loss: 0.6172 - val_accuracy: 0.9038 - lr: 0.0010
# Epoch 3/100
# 775/782 [============================>.] - ETA: 0s - loss: 0.7231 - accuracy: 0.8905
# Epoch 3: val_loss improved from 0.61721 to 0.60667, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7228 - accuracy: 0.8906 - val_loss: 0.6067 - val_accuracy: 0.9049 - lr: 0.0010
# Epoch 4/100
# 776/782 [============================>.] - ETA: 0s - loss: 0.7037 - accuracy: 0.8995
# Epoch 4: val_loss improved from 0.60667 to 0.60195, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7038 - accuracy: 0.8996 - val_loss: 0.6020 - val_accuracy: 0.9029 - lr: 0.0010
# Epoch 5/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.6914 - accuracy: 0.9053
# Epoch 5: val_loss improved from 0.60195 to 0.59253, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6918 - accuracy: 0.9053 - val_loss: 0.5925 - val_accuracy: 0.9074 - lr: 0.0010
# Epoch 6/100
# 776/782 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.9093
# Epoch 6: val_loss improved from 0.59253 to 0.58234, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6824 - accuracy: 0.9094 - val_loss: 0.5823 - val_accuracy: 0.9112 - lr: 0.0010
# Epoch 7/100
# 778/782 [============================>.] - ETA: 0s - loss: 0.6745 - accuracy: 0.9136
# Epoch 7: val_loss did not improve from 0.58234
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6744 - accuracy: 0.9136 - val_loss: 0.5884 - val_accuracy: 0.9130 - lr: 0.0010
# Epoch 8/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.6675 - accuracy: 0.9183
# Epoch 8: val_loss improved from 0.58234 to 0.58058, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6676 - accuracy: 0.9184 - val_loss: 0.5806 - val_accuracy: 0.9138 - lr: 0.0010
# Epoch 9/100
# 774/782 [============================>.] - ETA: 0s - loss: 0.6644 - accuracy: 0.9202
# Epoch 9: val_loss improved from 0.58058 to 0.57939, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6643 - accuracy: 0.9201 - val_loss: 0.5794 - val_accuracy: 0.9115 - lr: 0.0010
# Epoch 10/100
# 777/782 [============================>.] - ETA: 0s - loss: 0.6589 - accuracy: 0.9217
# Epoch 10: val_loss improved from 0.57939 to 0.57467, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6588 - accuracy: 0.9219 - val_loss: 0.5747 - val_accuracy: 0.9153 - lr: 0.0010
# Epoch 11/100
# 776/782 [============================>.] - ETA: 0s - loss: 0.6541 - accuracy: 0.9249
# Epoch 11: val_loss did not improve from 0.57467
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6541 - accuracy: 0.9250 - val_loss: 0.5845 - val_accuracy: 0.9124 - lr: 0.0010
# Epoch 12/100
# 774/782 [============================>.] - ETA: 0s - loss: 0.6518 - accuracy: 0.9270
# Epoch 12: val_loss did not improve from 0.57467
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6516 - accuracy: 0.9271 - val_loss: 0.5764 - val_accuracy: 0.9182 - lr: 0.0010
# Epoch 13/100
# 779/782 [============================>.] - ETA: 0s - loss: 0.6486 - accuracy: 0.9294
# Epoch 13: val_loss improved from 0.57467 to 0.57086, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6488 - accuracy: 0.9294 - val_loss: 0.5709 - val_accuracy: 0.9231 - lr: 0.0010
# Epoch 14/100
# 777/782 [============================>.] - ETA: 0s - loss: 0.6446 - accuracy: 0.9313
# Epoch 14: val_loss improved from 0.57086 to 0.55664, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 6ms/step - loss: 0.6446 - accuracy: 0.9313 - val_loss: 0.5566 - val_accuracy: 0.9273 - lr: 0.0010
# Epoch 15/100
# 778/782 [============================>.] - ETA: 0s - loss: 0.6436 - accuracy: 0.9318
# Epoch 15: val_loss did not improve from 0.55664
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6437 - accuracy: 0.9318 - val_loss: 0.5648 - val_accuracy: 0.9237 - lr: 0.0010
# Epoch 16/100
# 775/782 [============================>.] - ETA: 0s - loss: 0.6421 - accuracy: 0.9332
# Epoch 16: val_loss did not improve from 0.55664
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6420 - accuracy: 0.9332 - val_loss: 0.5707 - val_accuracy: 0.9223 - lr: 0.0010
# Epoch 17/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.6398 - accuracy: 0.9349
# Epoch 17: val_loss improved from 0.55664 to 0.55658, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6399 - accuracy: 0.9348 - val_loss: 0.5566 - val_accuracy: 0.9283 - lr: 0.0010
# Epoch 18/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.6382 - accuracy: 0.9354
# Epoch 18: val_loss did not improve from 0.55658
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6381 - accuracy: 0.9355 - val_loss: 0.5593 - val_accuracy: 0.9257 - lr: 0.0010
# Epoch 19/100
# 773/782 [============================>.] - ETA: 0s - loss: 0.6381 - accuracy: 0.9354
# Epoch 19: val_loss did not improve from 0.55658
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6376 - accuracy: 0.9355 - val_loss: 0.5602 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 20/100
# 777/782 [============================>.] - ETA: 0s - loss: 0.6317 - accuracy: 0.9384
# Epoch 20: val_loss improved from 0.55658 to 0.55447, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6320 - accuracy: 0.9383 - val_loss: 0.5545 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 21/100
# 778/782 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.9383
# Epoch 21: val_loss did not improve from 0.55447
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6311 - accuracy: 0.9384 - val_loss: 0.5565 - val_accuracy: 0.9301 - lr: 5.0000e-04
# Epoch 22/100
# 780/782 [============================>.] - ETA: 0s - loss: 0.6303 - accuracy: 0.9389
# Epoch 22: val_loss did not improve from 0.55447
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6304 - accuracy: 0.9389 - val_loss: 0.5552 - val_accuracy: 0.9289 - lr: 5.0000e-04
# Epoch 23/100
# 778/782 [============================>.] - ETA: 0s - loss: 0.6296 - accuracy: 0.9398
# Epoch 23: val_loss did not improve from 0.55447
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6298 - accuracy: 0.9397 - val_loss: 0.5646 - val_accuracy: 0.9270 - lr: 5.0000e-04
# Epoch 24/100
# 771/782 [============================>.] - ETA: 0s - loss: 0.6285 - accuracy: 0.9401
# Epoch 24: val_loss improved from 0.55447 to 0.55317, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6288 - accuracy: 0.9399 - val_loss: 0.5532 - val_accuracy: 0.9303 - lr: 5.0000e-04
# Epoch 25/100
# 772/782 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.9412
# Epoch 25: val_loss did not improve from 0.55317
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6279 - accuracy: 0.9411 - val_loss: 0.5553 - val_accuracy: 0.9296 - lr: 5.0000e-04
# Epoch 26/100
# 775/782 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.9413
# Epoch 26: val_loss improved from 0.55317 to 0.55112, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/best_model_v32_w128.keras
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6280 - accuracy: 0.9412 - val_loss: 0.5511 - val_accuracy: 0.9313 - lr: 5.0000e-04
# Epoch 27/100
# 781/782 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.9403
# Epoch 27: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6275 - accuracy: 0.9404 - val_loss: 0.5581 - val_accuracy: 0.9275 - lr: 5.0000e-04
# Epoch 28/100
# 777/782 [============================>.] - ETA: 0s - loss: 0.6266 - accuracy: 0.9415
# Epoch 28: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6266 - accuracy: 0.9416 - val_loss: 0.5544 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 29/100
# 782/782 [==============================] - ETA: 0s - loss: 0.6261 - accuracy: 0.9417
# Epoch 29: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6261 - accuracy: 0.9417 - val_loss: 0.5567 - val_accuracy: 0.9297 - lr: 5.0000e-04
# Epoch 30/100
# 776/782 [============================>.] - ETA: 0s - loss: 0.6264 - accuracy: 0.9415
# Epoch 30: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6267 - accuracy: 0.9416 - val_loss: 0.5530 - val_accuracy: 0.9298 - lr: 5.0000e-04
# Epoch 31/100
# 782/782 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.9425
# Epoch 31: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6258 - accuracy: 0.9425 - val_loss: 0.5523 - val_accuracy: 0.9317 - lr: 5.0000e-04
# Epoch 32/100
# 776/782 [============================>.] - ETA: 0s - loss: 0.6238 - accuracy: 0.9428
# Epoch 32: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6240 - accuracy: 0.9428 - val_loss: 0.5549 - val_accuracy: 0.9306 - lr: 2.5000e-04
# Epoch 33/100
# 779/782 [============================>.] - ETA: 0s - loss: 0.6228 - accuracy: 0.9444
# Epoch 33: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6229 - accuracy: 0.9444 - val_loss: 0.5539 - val_accuracy: 0.9296 - lr: 2.5000e-04
# Epoch 34/100
# 774/782 [============================>.] - ETA: 0s - loss: 0.6228 - accuracy: 0.9452
# Epoch 34: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6226 - accuracy: 0.9451 - val_loss: 0.5543 - val_accuracy: 0.9304 - lr: 2.5000e-04
# Epoch 35/100
# 782/782 [==============================] - ETA: 0s - loss: 0.6225 - accuracy: 0.9450
# Epoch 35: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6225 - accuracy: 0.9450 - val_loss: 0.5539 - val_accuracy: 0.9321 - lr: 2.5000e-04
# Epoch 36/100
# 773/782 [============================>.] - ETA: 0s - loss: 0.6228 - accuracy: 0.9430
# Epoch 36: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6231 - accuracy: 0.9431 - val_loss: 0.5580 - val_accuracy: 0.9284 - lr: 2.5000e-04
# Epoch 37/100
# 771/782 [============================>.] - ETA: 0s - loss: 0.6204 - accuracy: 0.9452
# Epoch 37: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6211 - accuracy: 0.9452 - val_loss: 0.5516 - val_accuracy: 0.9326 - lr: 1.2500e-04
# Epoch 38/100
# 773/782 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.9446
# Epoch 38: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6209 - accuracy: 0.9445 - val_loss: 0.5528 - val_accuracy: 0.9318 - lr: 1.2500e-04
# Epoch 39/100
# 778/782 [============================>.] - ETA: 0s - loss: 0.6208 - accuracy: 0.9459
# Epoch 39: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6207 - accuracy: 0.9458 - val_loss: 0.5542 - val_accuracy: 0.9304 - lr: 1.2500e-04
# Epoch 40/100
# 780/782 [============================>.] - ETA: 0s - loss: 0.6212 - accuracy: 0.9443
# Epoch 40: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6211 - accuracy: 0.9444 - val_loss: 0.5531 - val_accuracy: 0.9316 - lr: 1.2500e-04
# Epoch 41/100
# 779/782 [============================>.] - ETA: 0s - loss: 0.6201 - accuracy: 0.9441
# Epoch 41: val_loss did not improve from 0.55112
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6201 - accuracy: 0.9441 - val_loss: 0.5517 - val_accuracy: 0.9317 - lr: 1.2500e-04
# 37/37 [==============================] - 0s 2ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v32_w128 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9678    0.9127    0.9394      3000
#          Run     0.9823    0.9748    0.9785      1705
#         Idle     0.8990    0.9340    0.9161      3211
#        Trans     0.6812    0.7725    0.7240       567
#         Fall     0.9877    0.9653    0.9764       750
#
#     accuracy                         0.9272      9233
#    macro avg     0.9036    0.9118    0.9069      9233
# weighted avg     0.9306    0.9272    0.9283      9233
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 724
#   - TỶ LỆ RECALL TÉ NGÃ: 96.53%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/report_v32_w128.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v32_w128.cc/.h` (nhúng sẵn ops + quant cho TFLM wrapper)

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, WINDOW_SIZE, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpdumsktnj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpdumsktnj/assets
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v32_w128/model_v32_w128_int8.tflite  (25080 bytes)
# [*] Input : [  1 128   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v32_w128.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1782098373.660553  488822 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1782098373.660569  488822 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1782098373.660781  488822 reader.cc:83] Reading SavedModel from: /tmp/tmpdumsktnj
# I0000 00:00:1782098373.663200  488822 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1782098373.663208  488822 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpdumsktnj
# I0000 00:00:1782098373.671187  488822 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1782098373.672941  488822 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1782098373.702394  488822 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpdumsktnj
# I0000 00:00:1782098373.714730  488822 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 53964 microseconds.
# I0000 00:00:1782098373.797735  488822 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.386 M  ops, equivalently 0.193 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1782098373.857275  488822 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.386 M  ops, equivalently 0.193 M  MACs
# W0000 00:00:1782098373.857292  488822 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
