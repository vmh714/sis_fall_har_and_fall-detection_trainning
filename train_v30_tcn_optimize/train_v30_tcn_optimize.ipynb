# %% [markdown]
# # v30_tcn_optimize — TCN tối ưu ESP-NN (giữ dilation + SE)
#
# = v30_tcn NHƯNG **tối ưu ESP-NN**: Conv k7 thường → **SeparableConv** (pointwise 1×1 14×), relu → **relu6** (11×), head GMP(`REDUCE_MAX`) → **MaxPool(full)+Flatten** (`MAX_POOL_2D` 7.83×).
#
# **GIỮ dilation + SE** (nguồn sức mạnh Trans — bỏ là sụp, đã thấy ở v22_optimize). Dilated depthwise vẫn chạy reference (ESP-NN không tăng tốc dilation), nhưng nhẹ hơn conv thường + phần pointwise/head/relu6 được tăng tốc. Reuse `cache_v30`.

# %% [markdown]
# ## 📌 Ghi chú
# - Kiến trúc = **TCN v22** (dilated Conv1D d=1,2,4,8 + SE + residual causal, head GAP+GMP).
# - Pipeline = **v30** (gyro dps clip±500/500, Trans gyro-event, augment ×0.9/1.1, w0.55).
# - Dilation/SE giữ nguyên (nguồn sức mạnh Trans). Dilation không tăng tốc ESP-NN — chấp nhận.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781791691.324830 1184323 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — TCN v22 (dilated + SE)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, GlobalAveragePooling1D,
                                     MaxPooling1D, Flatten, Concatenate, Dense, Dropout,
                                     BatchNormalization, Activation, Add, Cropping1D, Multiply, Reshape)
from tensorflow.keras.models import Model

def se_block(input_tensor, c=32, ratio=4):
    se = GlobalAveragePooling1D()(input_tensor)
    se = Dense(c // ratio, activation='relu', use_bias=False)(se)
    se = Dense(c, activation='sigmoid', use_bias=False)(se)
    se = Reshape((1, c))(se)
    return Multiply()([input_tensor, se])

def build_model(input_shape=(200, 6), n_classes=5):
    # TCN TOI UU ESP-NN: Conv k7 thuong -> SeparableConv (depthwise dilated + pointwise 1x1 14x);
    #   relu -> relu6 (11x); head GMP(REDUCE_MAX) -> MaxPool(full)+Flatten (MAX_POOL_2D 7.83x).
    #   GIU dilation + SE (nguon suc manh Trans). Dilated depthwise van reference nhung nhe hon conv thuong.
    inputs = Input(shape=input_shape, name='input_layer')
    x = BatchNormalization()(inputs)
    for stack in range(2):
        for d in [1, 2, 4, 8]:
            residual = x
            x = SeparableConv1D(32, kernel_size=7, dilation_rate=d, padding='valid', use_bias=False)(x)
            x = BatchNormalization()(x); x = Activation('relu6')(x)
            x = Dropout(0.2)(x)
            crop_size = 6 * d
            residual = Cropping1D(cropping=(crop_size, 0))(residual)
            if residual.shape[-1] != 32:
                residual = Conv1D(32, 1, padding='valid', use_bias=False)(residual)
            x = se_block(x, c=32, ratio=4)
            x = Add()([x, residual]); x = Activation('relu6')(x)
    gap = GlobalAveragePooling1D()(x); gap = Dropout(0.2)(gap)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x); m = Flatten()(m); m = Dropout(0.4)(m)
    x = Concatenate()([gap, m])
    outputs = Dense(n_classes, activation='softmax', name='output_layer')(x)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_tcn_optimize'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_tcn_optimize"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# E0000 00:00:1781791694.437632 1184323 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I0000 00:00:1781791694.437674 1184323 cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# I0000 00:00:1781791694.437684 1184323 cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# I0000 00:00:1781791694.437696 1184323 cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# I0000 00:00:1781791694.437699 1184323 cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: quangnh
# I0000 00:00:1781791694.437703 1184323 cuda_diagnostics.cc:183] hostname: quangnh
# I0000 00:00:1781791694.437842 1184323 cuda_diagnostics.cc:190] libcuda reported version is: 550.54.15
# I0000 00:00:1781791694.437865 1184323 cuda_diagnostics.cc:194] kernel reported version is: 550.54.15
# I0000 00:00:1781791694.437869 1184323 cuda_diagnostics.cc:284] kernel version seems to match DSO: 550.54.15
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 200, 6)]             0         []
#
#  batch_normalization (Batch  (None, 200, 6)               24        ['input_layer[0][0]']
#  Normalization)
#
#  separable_conv1d (Separabl  (None, 194, 32)              234       ['batch_normalization[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 194, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 194, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 194, 32)              0         ['activation[0][0]']
#
#  global_average_pooling1d (  (None, 32)                   0         ['dropout[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                    256       ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 32)                   256       ['dense[0][0]']
#
#  reshape (Reshape)           (None, 1, 32)                0         ['dense_1[0][0]']
#
#  cropping1d (Cropping1D)     (None, 194, 6)               0         ['batch_normalization[0][0]']
#
#  multiply (Multiply)         (None, 194, 32)              0         ['dropout[0][0]',
#                                                                      'reshape[0][0]']
#
#  conv1d (Conv1D)             (None, 194, 32)              192       ['cropping1d[0][0]']
#
#  add (Add)                   (None, 194, 32)              0         ['multiply[0][0]',
#                                                                      'conv1d[0][0]']
#
#  activation_1 (Activation)   (None, 194, 32)              0         ['add[0][0]']
#
#  separable_conv1d_1 (Separa  (None, 182, 32)              1248      ['activation_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 182, 32)              128       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 182, 32)              0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 182, 32)              0         ['activation_2[0][0]']
#
#  global_average_pooling1d_1  (None, 32)                   0         ['dropout_1[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 8)                    256       ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 32)                   256       ['dense_2[0][0]']
#
#  reshape_1 (Reshape)         (None, 1, 32)                0         ['dense_3[0][0]']
#
#  multiply_1 (Multiply)       (None, 182, 32)              0         ['dropout_1[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  cropping1d_1 (Cropping1D)   (None, 182, 32)              0         ['activation_1[0][0]']
#
#  add_1 (Add)                 (None, 182, 32)              0         ['multiply_1[0][0]',
#                                                                      'cropping1d_1[0][0]']
#
#  activation_3 (Activation)   (None, 182, 32)              0         ['add_1[0][0]']
#
#  separable_conv1d_2 (Separa  (None, 158, 32)              1248      ['activation_3[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 158, 32)              128       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 158, 32)              0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 158, 32)              0         ['activation_4[0][0]']
#
#  global_average_pooling1d_2  (None, 32)                   0         ['dropout_2[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 8)                    256       ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 32)                   256       ['dense_4[0][0]']
#
#  reshape_2 (Reshape)         (None, 1, 32)                0         ['dense_5[0][0]']
#
#  multiply_2 (Multiply)       (None, 158, 32)              0         ['dropout_2[0][0]',
#                                                                      'reshape_2[0][0]']
#
#  cropping1d_2 (Cropping1D)   (None, 158, 32)              0         ['activation_3[0][0]']
#
#  add_2 (Add)                 (None, 158, 32)              0         ['multiply_2[0][0]',
#                                                                      'cropping1d_2[0][0]']
#
#  activation_5 (Activation)   (None, 158, 32)              0         ['add_2[0][0]']
#
#  separable_conv1d_3 (Separa  (None, 110, 32)              1248      ['activation_5[0][0]']
#  bleConv1D)
#
#  batch_normalization_4 (Bat  (None, 110, 32)              128       ['separable_conv1d_3[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 110, 32)              0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 110, 32)              0         ['activation_6[0][0]']
#
#  global_average_pooling1d_3  (None, 32)                   0         ['dropout_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 8)                    256       ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 32)                   256       ['dense_6[0][0]']
#
#  reshape_3 (Reshape)         (None, 1, 32)                0         ['dense_7[0][0]']
#
#  multiply_3 (Multiply)       (None, 110, 32)              0         ['dropout_3[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  cropping1d_3 (Cropping1D)   (None, 110, 32)              0         ['activation_5[0][0]']
#
#  add_3 (Add)                 (None, 110, 32)              0         ['multiply_3[0][0]',
#                                                                      'cropping1d_3[0][0]']
#
#  activation_7 (Activation)   (None, 110, 32)              0         ['add_3[0][0]']
#
#  separable_conv1d_4 (Separa  (None, 104, 32)              1248      ['activation_7[0][0]']
#  bleConv1D)
#
#  batch_normalization_5 (Bat  (None, 104, 32)              128       ['separable_conv1d_4[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 104, 32)              0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 104, 32)              0         ['activation_8[0][0]']
#
#  global_average_pooling1d_4  (None, 32)                   0         ['dropout_4[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_8 (Dense)             (None, 8)                    256       ['global_average_pooling1d_4[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 32)                   256       ['dense_8[0][0]']
#
#  reshape_4 (Reshape)         (None, 1, 32)                0         ['dense_9[0][0]']
#
#  multiply_4 (Multiply)       (None, 104, 32)              0         ['dropout_4[0][0]',
#                                                                      'reshape_4[0][0]']
#
#  cropping1d_4 (Cropping1D)   (None, 104, 32)              0         ['activation_7[0][0]']
#
#  add_4 (Add)                 (None, 104, 32)              0         ['multiply_4[0][0]',
#                                                                      'cropping1d_4[0][0]']
#
#  activation_9 (Activation)   (None, 104, 32)              0         ['add_4[0][0]']
#
#  separable_conv1d_5 (Separa  (None, 92, 32)               1248      ['activation_9[0][0]']
#  bleConv1D)
#
#  batch_normalization_6 (Bat  (None, 92, 32)               128       ['separable_conv1d_5[0][0]']
#  chNormalization)
#
#  activation_10 (Activation)  (None, 92, 32)               0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 92, 32)               0         ['activation_10[0][0]']
#
#  global_average_pooling1d_5  (None, 32)                   0         ['dropout_5[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_10 (Dense)            (None, 8)                    256       ['global_average_pooling1d_5[0
#                                                                     ][0]']
#
#  dense_11 (Dense)            (None, 32)                   256       ['dense_10[0][0]']
#
#  reshape_5 (Reshape)         (None, 1, 32)                0         ['dense_11[0][0]']
#
#  multiply_5 (Multiply)       (None, 92, 32)               0         ['dropout_5[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  cropping1d_5 (Cropping1D)   (None, 92, 32)               0         ['activation_9[0][0]']
#
#  add_5 (Add)                 (None, 92, 32)               0         ['multiply_5[0][0]',
#                                                                      'cropping1d_5[0][0]']
#
#  activation_11 (Activation)  (None, 92, 32)               0         ['add_5[0][0]']
#
#  separable_conv1d_6 (Separa  (None, 68, 32)               1248      ['activation_11[0][0]']
#  bleConv1D)
#
#  batch_normalization_7 (Bat  (None, 68, 32)               128       ['separable_conv1d_6[0][0]']
#  chNormalization)
#
#  activation_12 (Activation)  (None, 68, 32)               0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 68, 32)               0         ['activation_12[0][0]']
#
#  global_average_pooling1d_6  (None, 32)                   0         ['dropout_6[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_12 (Dense)            (None, 8)                    256       ['global_average_pooling1d_6[0
#                                                                     ][0]']
#
#  dense_13 (Dense)            (None, 32)                   256       ['dense_12[0][0]']
#
#  reshape_6 (Reshape)         (None, 1, 32)                0         ['dense_13[0][0]']
#
#  multiply_6 (Multiply)       (None, 68, 32)               0         ['dropout_6[0][0]',
#                                                                      'reshape_6[0][0]']
#
#  cropping1d_6 (Cropping1D)   (None, 68, 32)               0         ['activation_11[0][0]']
#
#  add_6 (Add)                 (None, 68, 32)               0         ['multiply_6[0][0]',
#                                                                      'cropping1d_6[0][0]']
#
#  activation_13 (Activation)  (None, 68, 32)               0         ['add_6[0][0]']
#
#  separable_conv1d_7 (Separa  (None, 20, 32)               1248      ['activation_13[0][0]']
#  bleConv1D)
#
#  batch_normalization_8 (Bat  (None, 20, 32)               128       ['separable_conv1d_7[0][0]']
#  chNormalization)
#
#  activation_14 (Activation)  (None, 20, 32)               0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 20, 32)               0         ['activation_14[0][0]']
#
#  global_average_pooling1d_7  (None, 32)                   0         ['dropout_7[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_14 (Dense)            (None, 8)                    256       ['global_average_pooling1d_7[0
#                                                                     ][0]']
#
#  dense_15 (Dense)            (None, 32)                   256       ['dense_14[0][0]']
#
#  reshape_7 (Reshape)         (None, 1, 32)                0         ['dense_15[0][0]']
#
#  multiply_7 (Multiply)       (None, 20, 32)               0         ['dropout_7[0][0]',
#                                                                      'reshape_7[0][0]']
#
#  cropping1d_7 (Cropping1D)   (None, 20, 32)               0         ['activation_13[0][0]']
#
#  add_7 (Add)                 (None, 20, 32)               0         ['multiply_7[0][0]',
#                                                                      'cropping1d_7[0][0]']
#
#  activation_15 (Activation)  (None, 20, 32)               0         ['add_7[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 1, 32)                0         ['activation_15[0][0]']
#  D)
#
#  global_average_pooling1d_8  (None, 32)                   0         ['activation_15[0][0]']
#   (GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 32)                   0         ['max_pooling1d[0][0]']
#
#  dropout_8 (Dropout)         (None, 32)                   0         ['global_average_pooling1d_8[0
#                                                                     ][0]']
#
#  dropout_9 (Dropout)         (None, 32)                   0         ['flatten[0][0]']
#
#  concatenate (Concatenate)   (None, 64)                   0         ['dropout_8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  output_layer (Dense)        (None, 5)                    325       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 14631 (57.15 KB)
# Trainable params: 14107 (55.11 KB)
# Non-trainable params: 524 (2.05 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 569/569 [==============================] - ETA: 0s - loss: 1.5183 - accuracy: 0.6193
# Epoch 1: val_loss improved from inf to 0.83356, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 34s 50ms/step - loss: 1.5183 - accuracy: 0.6193 - val_loss: 0.8336 - val_accuracy: 0.8032 - lr: 0.0010
# Epoch 2/100
# 569/569 [==============================] - ETA: 0s - loss: 0.8148 - accuracy: 0.8622
# Epoch 2: val_loss improved from 0.83356 to 0.60068, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 28s 49ms/step - loss: 0.8148 - accuracy: 0.8622 - val_loss: 0.6007 - val_accuracy: 0.9113 - lr: 0.0010
# Epoch 3/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.7154 - accuracy: 0.9067
# Epoch 3: val_loss improved from 0.60068 to 0.55725, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 52ms/step - loss: 0.7155 - accuracy: 0.9067 - val_loss: 0.5572 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 4/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6797 - accuracy: 0.9214
# Epoch 4: val_loss improved from 0.55725 to 0.54732, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 51ms/step - loss: 0.6797 - accuracy: 0.9214 - val_loss: 0.5473 - val_accuracy: 0.9294 - lr: 0.0010
# Epoch 5/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6576 - accuracy: 0.9338
# Epoch 5: val_loss improved from 0.54732 to 0.53805, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 28s 50ms/step - loss: 0.6577 - accuracy: 0.9337 - val_loss: 0.5381 - val_accuracy: 0.9357 - lr: 0.0010
# Epoch 6/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6433 - accuracy: 0.9401
# Epoch 6: val_loss improved from 0.53805 to 0.53210, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 27s 47ms/step - loss: 0.6434 - accuracy: 0.9401 - val_loss: 0.5321 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 7/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6355 - accuracy: 0.9440
# Epoch 7: val_loss did not improve from 0.53210
# 569/569 [==============================] - 34s 60ms/step - loss: 0.6356 - accuracy: 0.9439 - val_loss: 0.5402 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 8/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.9493
# Epoch 8: val_loss improved from 0.53210 to 0.51713, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 36s 62ms/step - loss: 0.6276 - accuracy: 0.9493 - val_loss: 0.5171 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 9/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6216 - accuracy: 0.9516
# Epoch 9: val_loss improved from 0.51713 to 0.51480, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 34s 60ms/step - loss: 0.6217 - accuracy: 0.9516 - val_loss: 0.5148 - val_accuracy: 0.9492 - lr: 0.0010
# Epoch 10/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6143 - accuracy: 0.9557
# Epoch 10: val_loss improved from 0.51480 to 0.50998, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 24s 41ms/step - loss: 0.6141 - accuracy: 0.9558 - val_loss: 0.5100 - val_accuracy: 0.9498 - lr: 0.0010
# Epoch 11/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6115 - accuracy: 0.9578
# Epoch 11: val_loss did not improve from 0.50998
# 569/569 [==============================] - 24s 42ms/step - loss: 0.6115 - accuracy: 0.9578 - val_loss: 0.5153 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 12/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6092 - accuracy: 0.9584
# Epoch 12: val_loss did not improve from 0.50998
# 569/569 [==============================] - 26s 47ms/step - loss: 0.6092 - accuracy: 0.9584 - val_loss: 0.5136 - val_accuracy: 0.9523 - lr: 0.0010
# Epoch 13/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6043 - accuracy: 0.9612
# Epoch 13: val_loss did not improve from 0.50998
# 569/569 [==============================] - 25s 44ms/step - loss: 0.6044 - accuracy: 0.9612 - val_loss: 0.5139 - val_accuracy: 0.9523 - lr: 0.0010
# Epoch 14/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.9615
# Epoch 14: val_loss did not improve from 0.50998
# 569/569 [==============================] - 25s 44ms/step - loss: 0.6026 - accuracy: 0.9615 - val_loss: 0.5146 - val_accuracy: 0.9497 - lr: 0.0010
# Epoch 15/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5981 - accuracy: 0.9636
# Epoch 15: val_loss improved from 0.50998 to 0.50501, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 27s 47ms/step - loss: 0.5981 - accuracy: 0.9636 - val_loss: 0.5050 - val_accuracy: 0.9520 - lr: 0.0010
# Epoch 16/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5957 - accuracy: 0.9659
# Epoch 16: val_loss did not improve from 0.50501
# 569/569 [==============================] - 27s 48ms/step - loss: 0.5957 - accuracy: 0.9659 - val_loss: 0.5090 - val_accuracy: 0.9500 - lr: 0.0010
# Epoch 17/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5958 - accuracy: 0.9651
# Epoch 17: val_loss did not improve from 0.50501
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5959 - accuracy: 0.9650 - val_loss: 0.5087 - val_accuracy: 0.9520 - lr: 0.0010
# Epoch 18/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5948 - accuracy: 0.9667
# Epoch 18: val_loss did not improve from 0.50501
# 569/569 [==============================] - 28s 50ms/step - loss: 0.5949 - accuracy: 0.9666 - val_loss: 0.5115 - val_accuracy: 0.9523 - lr: 0.0010
# Epoch 19/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5932 - accuracy: 0.9664
# Epoch 19: val_loss improved from 0.50501 to 0.50481, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 52ms/step - loss: 0.5932 - accuracy: 0.9664 - val_loss: 0.5048 - val_accuracy: 0.9540 - lr: 0.0010
# Epoch 20/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5916 - accuracy: 0.9671
# Epoch 20: val_loss improved from 0.50481 to 0.50363, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 52ms/step - loss: 0.5916 - accuracy: 0.9671 - val_loss: 0.5036 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 21/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5878 - accuracy: 0.9689
# Epoch 21: val_loss improved from 0.50363 to 0.50175, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 52ms/step - loss: 0.5878 - accuracy: 0.9689 - val_loss: 0.5017 - val_accuracy: 0.9552 - lr: 0.0010
# Epoch 22/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5877 - accuracy: 0.9683
# Epoch 22: val_loss improved from 0.50175 to 0.49980, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 32s 56ms/step - loss: 0.5877 - accuracy: 0.9683 - val_loss: 0.4998 - val_accuracy: 0.9575 - lr: 0.0010
# Epoch 23/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5907 - accuracy: 0.9674
# Epoch 23: val_loss did not improve from 0.49980
# 569/569 [==============================] - 33s 58ms/step - loss: 0.5908 - accuracy: 0.9673 - val_loss: 0.5003 - val_accuracy: 0.9563 - lr: 0.0010
# Epoch 24/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5848 - accuracy: 0.9706
# Epoch 24: val_loss improved from 0.49980 to 0.49904, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 33s 58ms/step - loss: 0.5848 - accuracy: 0.9706 - val_loss: 0.4990 - val_accuracy: 0.9567 - lr: 0.0010
# Epoch 25/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.9695
# Epoch 25: val_loss did not improve from 0.49904
# 569/569 [==============================] - 32s 57ms/step - loss: 0.5846 - accuracy: 0.9696 - val_loss: 0.5003 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 26/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5841 - accuracy: 0.9701
# Epoch 26: val_loss improved from 0.49904 to 0.49690, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 33s 57ms/step - loss: 0.5842 - accuracy: 0.9701 - val_loss: 0.4969 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 27/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5835 - accuracy: 0.9716
# Epoch 27: val_loss improved from 0.49690 to 0.49384, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 33s 57ms/step - loss: 0.5836 - accuracy: 0.9716 - val_loss: 0.4938 - val_accuracy: 0.9575 - lr: 0.0010
# Epoch 28/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5814 - accuracy: 0.9717
# Epoch 28: val_loss did not improve from 0.49384
# 569/569 [==============================] - 31s 54ms/step - loss: 0.5814 - accuracy: 0.9717 - val_loss: 0.4977 - val_accuracy: 0.9586 - lr: 0.0010
# Epoch 29/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5798 - accuracy: 0.9716
# Epoch 29: val_loss improved from 0.49384 to 0.49223, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 28s 49ms/step - loss: 0.5798 - accuracy: 0.9716 - val_loss: 0.4922 - val_accuracy: 0.9574 - lr: 0.0010
# Epoch 30/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5814 - accuracy: 0.9718
# Epoch 30: val_loss did not improve from 0.49223
# 569/569 [==============================] - 25s 44ms/step - loss: 0.5816 - accuracy: 0.9717 - val_loss: 0.4969 - val_accuracy: 0.9581 - lr: 0.0010
# Epoch 31/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5786 - accuracy: 0.9730
# Epoch 31: val_loss did not improve from 0.49223
# 569/569 [==============================] - 26s 46ms/step - loss: 0.5786 - accuracy: 0.9730 - val_loss: 0.4992 - val_accuracy: 0.9571 - lr: 0.0010
# Epoch 32/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5804 - accuracy: 0.9729
# Epoch 32: val_loss improved from 0.49223 to 0.49191, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5804 - accuracy: 0.9729 - val_loss: 0.4919 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 33/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.9734
# Epoch 33: val_loss did not improve from 0.49191
# 569/569 [==============================] - 26s 46ms/step - loss: 0.5771 - accuracy: 0.9734 - val_loss: 0.5043 - val_accuracy: 0.9551 - lr: 0.0010
# Epoch 34/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5783 - accuracy: 0.9730
# Epoch 34: val_loss did not improve from 0.49191
# 569/569 [==============================] - 26s 46ms/step - loss: 0.5783 - accuracy: 0.9730 - val_loss: 0.4954 - val_accuracy: 0.9584 - lr: 0.0010
# Epoch 35/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.9713
# Epoch 35: val_loss did not improve from 0.49191
# 569/569 [==============================] - 27s 47ms/step - loss: 0.5816 - accuracy: 0.9713 - val_loss: 0.4941 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 36/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5750 - accuracy: 0.9757
# Epoch 36: val_loss did not improve from 0.49191
# 569/569 [==============================] - 28s 49ms/step - loss: 0.5751 - accuracy: 0.9756 - val_loss: 0.5002 - val_accuracy: 0.9563 - lr: 0.0010
# Epoch 37/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5742 - accuracy: 0.9756
# Epoch 37: val_loss did not improve from 0.49191
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5742 - accuracy: 0.9756 - val_loss: 0.4986 - val_accuracy: 0.9571 - lr: 0.0010
# Epoch 38/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5709 - accuracy: 0.9768
# Epoch 38: val_loss did not improve from 0.49191
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5710 - accuracy: 0.9768 - val_loss: 0.4947 - val_accuracy: 0.9601 - lr: 5.0000e-04
# Epoch 39/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.9778
# Epoch 39: val_loss did not improve from 0.49191
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5692 - accuracy: 0.9778 - val_loss: 0.4920 - val_accuracy: 0.9615 - lr: 5.0000e-04
# Epoch 40/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5695 - accuracy: 0.9772
# Epoch 40: val_loss improved from 0.49191 to 0.48792, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/best_model_v30_tcn_optimize.keras
# 569/569 [==============================] - 27s 48ms/step - loss: 0.5696 - accuracy: 0.9772 - val_loss: 0.4879 - val_accuracy: 0.9612 - lr: 5.0000e-04
# Epoch 41/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5692 - accuracy: 0.9776
# Epoch 41: val_loss did not improve from 0.48792
# 569/569 [==============================] - 27s 47ms/step - loss: 0.5693 - accuracy: 0.9775 - val_loss: 0.4907 - val_accuracy: 0.9595 - lr: 5.0000e-04
# Epoch 42/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5696 - accuracy: 0.9774
# Epoch 42: val_loss did not improve from 0.48792
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5697 - accuracy: 0.9774 - val_loss: 0.4956 - val_accuracy: 0.9598 - lr: 5.0000e-04
# Epoch 43/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.9782
# Epoch 43: val_loss did not improve from 0.48792
# 569/569 [==============================] - 43s 75ms/step - loss: 0.5691 - accuracy: 0.9781 - val_loss: 0.4912 - val_accuracy: 0.9609 - lr: 5.0000e-04
# Epoch 44/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5684 - accuracy: 0.9780
# Epoch 44: val_loss did not improve from 0.48792
# 569/569 [==============================] - 42s 73ms/step - loss: 0.5684 - accuracy: 0.9780 - val_loss: 0.4942 - val_accuracy: 0.9590 - lr: 5.0000e-04
# Epoch 45/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.9794
# Epoch 45: val_loss did not improve from 0.48792
# 569/569 [==============================] - 37s 65ms/step - loss: 0.5668 - accuracy: 0.9794 - val_loss: 0.4979 - val_accuracy: 0.9601 - lr: 5.0000e-04
# Epoch 46/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5664 - accuracy: 0.9792
# Epoch 46: val_loss did not improve from 0.48792
# 569/569 [==============================] - 27s 47ms/step - loss: 0.5664 - accuracy: 0.9792 - val_loss: 0.4901 - val_accuracy: 0.9612 - lr: 2.5000e-04
# Epoch 47/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5663 - accuracy: 0.9790
# Epoch 47: val_loss did not improve from 0.48792
# 569/569 [==============================] - 27s 47ms/step - loss: 0.5663 - accuracy: 0.9790 - val_loss: 0.4897 - val_accuracy: 0.9615 - lr: 2.5000e-04
# Epoch 48/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5650 - accuracy: 0.9799
# Epoch 48: val_loss did not improve from 0.48792
# 569/569 [==============================] - 28s 49ms/step - loss: 0.5650 - accuracy: 0.9799 - val_loss: 0.4928 - val_accuracy: 0.9613 - lr: 2.5000e-04
# Epoch 49/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5643 - accuracy: 0.9802
# Epoch 49: val_loss did not improve from 0.48792
# 569/569 [==============================] - 30s 52ms/step - loss: 0.5643 - accuracy: 0.9802 - val_loss: 0.4917 - val_accuracy: 0.9618 - lr: 2.5000e-04
# Epoch 50/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5648 - accuracy: 0.9803
# Epoch 50: val_loss did not improve from 0.48792
# 569/569 [==============================] - 30s 52ms/step - loss: 0.5648 - accuracy: 0.9803 - val_loss: 0.4913 - val_accuracy: 0.9613 - lr: 2.5000e-04
# Epoch 51/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5621 - accuracy: 0.9813
# Epoch 51: val_loss did not improve from 0.48792
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5621 - accuracy: 0.9814 - val_loss: 0.4923 - val_accuracy: 0.9621 - lr: 1.2500e-04
# Epoch 52/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5629 - accuracy: 0.9806
# Epoch 52: val_loss did not improve from 0.48792
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5629 - accuracy: 0.9806 - val_loss: 0.4916 - val_accuracy: 0.9613 - lr: 1.2500e-04
# Epoch 53/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5642 - accuracy: 0.9807
# Epoch 53: val_loss did not improve from 0.48792
# 569/569 [==============================] - 29s 51ms/step - loss: 0.5643 - accuracy: 0.9806 - val_loss: 0.4923 - val_accuracy: 0.9606 - lr: 1.2500e-04
# Epoch 54/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5621 - accuracy: 0.9815
# Epoch 54: val_loss did not improve from 0.48792
# 569/569 [==============================] - 30s 53ms/step - loss: 0.5621 - accuracy: 0.9815 - val_loss: 0.4934 - val_accuracy: 0.9597 - lr: 1.2500e-04
# Epoch 55/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5624 - accuracy: 0.9811
# Epoch 55: val_loss did not improve from 0.48792
# 569/569 [==============================] - 35s 62ms/step - loss: 0.5624 - accuracy: 0.9811 - val_loss: 0.4924 - val_accuracy: 0.9612 - lr: 1.2500e-04
# 24/24 [==============================] - 1s 44ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_tcn_optimize (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9737    0.9307    0.9517      1906
#          Run     0.9788    0.9770    0.9779      1085
#         Idle     0.9263    0.9650    0.9452      1798
#        Trans     0.8945    0.9418    0.9175       567
#         Fall     0.9973    0.9720    0.9845       750
#
#     accuracy                         0.9551      6106
#    macro avg     0.9541    0.9573    0.9554      6106
# weighted avg     0.9562    0.9551    0.9553      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 729
#   - TỶ LỆ RECALL TÉ NGÃ: 97.20%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/report_v30_tcn_optimize.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpb7ccwaxz/assets
# INFO:tensorflow:Assets written to: /tmp/tmpb7ccwaxz/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781793355.931079 1184323 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781793355.931114 1184323 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781793355.931481 1184323 reader.cc:83] Reading SavedModel from: /tmp/tmpb7ccwaxz
# I0000 00:00:1781793355.946983 1184323 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781793355.947034 1184323 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpb7ccwaxz
# I0000 00:00:1781793356.012661 1184323 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781793356.024919 1184323 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781793356.194294 1184323 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpb7ccwaxz
# I0000 00:00:1781793356.275778 1184323 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 344347 microseconds.
# I0000 00:00:1781793356.383774 1184323 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781793356.657239 1184323 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 2.146 M  ops, equivalently 1.073 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781793357.340838 1184323 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 2.146 M  ops, equivalently 1.073 M  MACs
# W0000 00:00:1781793357.340870 1184323 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize/model_v30_tcn_optimize_int8.tflite  (66568 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['ADD', 'CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'LOGISTIC', 'MAX_POOL_2D', 'MEAN', 'MUL', 'RESHAPE', 'SOFTMAX', 'STRIDED_SLICE']
# [*] Da sinh model_data_v30_tcn_optimize.cc / .h
