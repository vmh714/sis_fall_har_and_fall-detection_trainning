# %% [markdown]
# # v30_tcn_optimize — TCN tối ưu ESP-NN (giữ dilation + SE)
#
# = v30_tcn NHƯNG **tối ưu ESP-NN**: Conv k7 thường → **SeparableConv** (pointwise 1×1 14×), relu → **relu6** (11×), head GMP(`REDUCE_MAX`) → **MaxPool(full)+Flatten** (`MAX_POOL_2D` 7.83×).
#
# **GIỮ dilation + SE** (nguồn sức mạnh Trans — bỏ là sụp, đã thấy ở v22_optimize). Dilated depthwise vẫn chạy reference (ESP-NN không tăng tốc dilation), nhưng nhẹ hơn conv thường + phần pointwise/head/relu6 được tăng tốc. Reuse `cache_v30`.

# %% [markdown]
# ## 📌 Ghi chú
# - Kiến trúc = **TCN v22** (dilated Conv1D d=1,2,4,8 + SE + residual causal, head GAP+GMP).
# - Pipeline = **v30** (gyro dps clip±500/500, Trans gyro-event, augment ×0.9/1.1, w0.55).
# - Dilation/SE giữ nguyên (nguồn sức mạnh Trans). Dilation không tăng tốc ESP-NN — chấp nhận.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781858636.567039 2271575 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — TCN v22 (dilated + SE)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, GlobalAveragePooling1D,
                                     MaxPooling1D, Flatten, Concatenate, Dense, Dropout,
                                     BatchNormalization, Activation, Add, Cropping1D, Multiply, Reshape)
from tensorflow.keras.models import Model

def se_block_v25(x, c, ratio=4):
    """SE Block tối ưu hóa hoàn toàn bằng Conv1D 1x1 (Pointwise) cho ESP-NN"""
    se = GlobalAveragePooling1D()(x)
    se = Reshape((1, c))(se)
    # Tăng tốc pointwise 14.2x
    se = Conv1D(c // ratio, kernel_size=1, use_bias=False)(se)
    se = Activation('relu6')(se) # Tăng tốc 11.5x
    se = Conv1D(c, kernel_size=1, use_bias=False)(se)
    se = Activation('sigmoid')(se)
    return Multiply()([x, se])

def build_model(input_shape=(200, 6), n_classes=5):
    # TCN v30 Optimize V2: 
    # 1. kernel_size=3 de kich hoat depthwise conv 3x3 optimized cua ESP-NN
    # 2. se_block dung Conv1D 1x1 (tham khao tu v25) thay vi Dense de tranh overhead
    inputs = Input(shape=input_shape, name='input_layer')
    x = BatchNormalization()(inputs)
    for stack in range(2):
        for d in [1, 2, 4, 8]:
            residual = x
            # separable conv k=3, dilation d (Depthwise k=3 optimized 6.3x)
            x = SeparableConv1D(32, kernel_size=3, dilation_rate=d, padding='valid', use_bias=False)(x)
            x = BatchNormalization()(x); x = Activation('relu6')(x)
            x = Dropout(0.2)(x)
            
            # crop_size = (k-1)*d = 2*d
            crop_size = 2 * d
            residual = Cropping1D(cropping=(crop_size, 0))(residual)
            if residual.shape[-1] != 32:
                # pointwise 1x1 conv tang toc 14.24x
                residual = Conv1D(32, 1, padding='valid', use_bias=False)(residual)
            
            # Dung se_block_v25 thay vi se_block cu
            x = se_block_v25(x, c=32, ratio=4)
            x = Add()([x, residual]); x = Activation('relu6')(x)
            
    gap = GlobalAveragePooling1D()(x); gap = Dropout(0.2)(gap)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x); m = Flatten()(m); m = Dropout(0.4)(m)
    x = Concatenate()([gap, m])
    outputs = Dense(n_classes, activation='softmax', name='output_layer')(x)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_tcn_optimize_v2'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_tcn_optimize_v2"
trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# I0000 00:00:1781858639.415501 2271575 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 200, 6)]             0         []
#
#  batch_normalization (Batch  (None, 200, 6)               24        ['input_layer[0][0]']
#  Normalization)
#
#  separable_conv1d (Separabl  (None, 198, 32)              210       ['batch_normalization[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 198, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 198, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 198, 32)              0         ['activation[0][0]']
#
#  global_average_pooling1d (  (None, 32)                   0         ['dropout[0][0]']
#  GlobalAveragePooling1D)
#
#  reshape (Reshape)           (None, 1, 32)                0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  conv1d_1 (Conv1D)           (None, 1, 8)                 256       ['reshape[0][0]']
#
#  activation_1 (Activation)   (None, 1, 8)                 0         ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 1, 32)                256       ['activation_1[0][0]']
#
#  activation_2 (Activation)   (None, 1, 32)                0         ['conv1d_2[0][0]']
#
#  cropping1d (Cropping1D)     (None, 198, 6)               0         ['batch_normalization[0][0]']
#
#  multiply (Multiply)         (None, 198, 32)              0         ['dropout[0][0]',
#                                                                      'activation_2[0][0]']
#
#  conv1d (Conv1D)             (None, 198, 32)              192       ['cropping1d[0][0]']
#
#  add (Add)                   (None, 198, 32)              0         ['multiply[0][0]',
#                                                                      'conv1d[0][0]']
#
#  activation_3 (Activation)   (None, 198, 32)              0         ['add[0][0]']
#
#  separable_conv1d_1 (Separa  (None, 194, 32)              1120      ['activation_3[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 194, 32)              128       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 194, 32)              0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 194, 32)              0         ['activation_4[0][0]']
#
#  global_average_pooling1d_1  (None, 32)                   0         ['dropout_1[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_1 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  conv1d_3 (Conv1D)           (None, 1, 8)                 256       ['reshape_1[0][0]']
#
#  activation_5 (Activation)   (None, 1, 8)                 0         ['conv1d_3[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 1, 32)                256       ['activation_5[0][0]']
#
#  activation_6 (Activation)   (None, 1, 32)                0         ['conv1d_4[0][0]']
#
#  multiply_1 (Multiply)       (None, 194, 32)              0         ['dropout_1[0][0]',
#                                                                      'activation_6[0][0]']
#
#  cropping1d_1 (Cropping1D)   (None, 194, 32)              0         ['activation_3[0][0]']
#
#  add_1 (Add)                 (None, 194, 32)              0         ['multiply_1[0][0]',
#                                                                      'cropping1d_1[0][0]']
#
#  activation_7 (Activation)   (None, 194, 32)              0         ['add_1[0][0]']
#
#  separable_conv1d_2 (Separa  (None, 186, 32)              1120      ['activation_7[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 186, 32)              128       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 186, 32)              0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 186, 32)              0         ['activation_8[0][0]']
#
#  global_average_pooling1d_2  (None, 32)                   0         ['dropout_2[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_2 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  conv1d_5 (Conv1D)           (None, 1, 8)                 256       ['reshape_2[0][0]']
#
#  activation_9 (Activation)   (None, 1, 8)                 0         ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 1, 32)                256       ['activation_9[0][0]']
#
#  activation_10 (Activation)  (None, 1, 32)                0         ['conv1d_6[0][0]']
#
#  multiply_2 (Multiply)       (None, 186, 32)              0         ['dropout_2[0][0]',
#                                                                      'activation_10[0][0]']
#
#  cropping1d_2 (Cropping1D)   (None, 186, 32)              0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 186, 32)              0         ['multiply_2[0][0]',
#                                                                      'cropping1d_2[0][0]']
#
#  activation_11 (Activation)  (None, 186, 32)              0         ['add_2[0][0]']
#
#  separable_conv1d_3 (Separa  (None, 170, 32)              1120      ['activation_11[0][0]']
#  bleConv1D)
#
#  batch_normalization_4 (Bat  (None, 170, 32)              128       ['separable_conv1d_3[0][0]']
#  chNormalization)
#
#  activation_12 (Activation)  (None, 170, 32)              0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 170, 32)              0         ['activation_12[0][0]']
#
#  global_average_pooling1d_3  (None, 32)                   0         ['dropout_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_3 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  conv1d_7 (Conv1D)           (None, 1, 8)                 256       ['reshape_3[0][0]']
#
#  activation_13 (Activation)  (None, 1, 8)                 0         ['conv1d_7[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 1, 32)                256       ['activation_13[0][0]']
#
#  activation_14 (Activation)  (None, 1, 32)                0         ['conv1d_8[0][0]']
#
#  multiply_3 (Multiply)       (None, 170, 32)              0         ['dropout_3[0][0]',
#                                                                      'activation_14[0][0]']
#
#  cropping1d_3 (Cropping1D)   (None, 170, 32)              0         ['activation_11[0][0]']
#
#  add_3 (Add)                 (None, 170, 32)              0         ['multiply_3[0][0]',
#                                                                      'cropping1d_3[0][0]']
#
#  activation_15 (Activation)  (None, 170, 32)              0         ['add_3[0][0]']
#
#  separable_conv1d_4 (Separa  (None, 168, 32)              1120      ['activation_15[0][0]']
#  bleConv1D)
#
#  batch_normalization_5 (Bat  (None, 168, 32)              128       ['separable_conv1d_4[0][0]']
#  chNormalization)
#
#  activation_16 (Activation)  (None, 168, 32)              0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 168, 32)              0         ['activation_16[0][0]']
#
#  global_average_pooling1d_4  (None, 32)                   0         ['dropout_4[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_4 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_4[0
#                                                                     ][0]']
#
#  conv1d_9 (Conv1D)           (None, 1, 8)                 256       ['reshape_4[0][0]']
#
#  activation_17 (Activation)  (None, 1, 8)                 0         ['conv1d_9[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 1, 32)                256       ['activation_17[0][0]']
#
#  activation_18 (Activation)  (None, 1, 32)                0         ['conv1d_10[0][0]']
#
#  multiply_4 (Multiply)       (None, 168, 32)              0         ['dropout_4[0][0]',
#                                                                      'activation_18[0][0]']
#
#  cropping1d_4 (Cropping1D)   (None, 168, 32)              0         ['activation_15[0][0]']
#
#  add_4 (Add)                 (None, 168, 32)              0         ['multiply_4[0][0]',
#                                                                      'cropping1d_4[0][0]']
#
#  activation_19 (Activation)  (None, 168, 32)              0         ['add_4[0][0]']
#
#  separable_conv1d_5 (Separa  (None, 164, 32)              1120      ['activation_19[0][0]']
#  bleConv1D)
#
#  batch_normalization_6 (Bat  (None, 164, 32)              128       ['separable_conv1d_5[0][0]']
#  chNormalization)
#
#  activation_20 (Activation)  (None, 164, 32)              0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 164, 32)              0         ['activation_20[0][0]']
#
#  global_average_pooling1d_5  (None, 32)                   0         ['dropout_5[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_5 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_5[0
#                                                                     ][0]']
#
#  conv1d_11 (Conv1D)          (None, 1, 8)                 256       ['reshape_5[0][0]']
#
#  activation_21 (Activation)  (None, 1, 8)                 0         ['conv1d_11[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 1, 32)                256       ['activation_21[0][0]']
#
#  activation_22 (Activation)  (None, 1, 32)                0         ['conv1d_12[0][0]']
#
#  multiply_5 (Multiply)       (None, 164, 32)              0         ['dropout_5[0][0]',
#                                                                      'activation_22[0][0]']
#
#  cropping1d_5 (Cropping1D)   (None, 164, 32)              0         ['activation_19[0][0]']
#
#  add_5 (Add)                 (None, 164, 32)              0         ['multiply_5[0][0]',
#                                                                      'cropping1d_5[0][0]']
#
#  activation_23 (Activation)  (None, 164, 32)              0         ['add_5[0][0]']
#
#  separable_conv1d_6 (Separa  (None, 156, 32)              1120      ['activation_23[0][0]']
#  bleConv1D)
#
#  batch_normalization_7 (Bat  (None, 156, 32)              128       ['separable_conv1d_6[0][0]']
#  chNormalization)
#
#  activation_24 (Activation)  (None, 156, 32)              0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 156, 32)              0         ['activation_24[0][0]']
#
#  global_average_pooling1d_6  (None, 32)                   0         ['dropout_6[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_6 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_6[0
#                                                                     ][0]']
#
#  conv1d_13 (Conv1D)          (None, 1, 8)                 256       ['reshape_6[0][0]']
#
#  activation_25 (Activation)  (None, 1, 8)                 0         ['conv1d_13[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 1, 32)                256       ['activation_25[0][0]']
#
#  activation_26 (Activation)  (None, 1, 32)                0         ['conv1d_14[0][0]']
#
#  multiply_6 (Multiply)       (None, 156, 32)              0         ['dropout_6[0][0]',
#                                                                      'activation_26[0][0]']
#
#  cropping1d_6 (Cropping1D)   (None, 156, 32)              0         ['activation_23[0][0]']
#
#  add_6 (Add)                 (None, 156, 32)              0         ['multiply_6[0][0]',
#                                                                      'cropping1d_6[0][0]']
#
#  activation_27 (Activation)  (None, 156, 32)              0         ['add_6[0][0]']
#
#  separable_conv1d_7 (Separa  (None, 140, 32)              1120      ['activation_27[0][0]']
#  bleConv1D)
#
#  batch_normalization_8 (Bat  (None, 140, 32)              128       ['separable_conv1d_7[0][0]']
#  chNormalization)
#
#  activation_28 (Activation)  (None, 140, 32)              0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 140, 32)              0         ['activation_28[0][0]']
#
#  global_average_pooling1d_7  (None, 32)                   0         ['dropout_7[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_7 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_7[0
#                                                                     ][0]']
#
#  conv1d_15 (Conv1D)          (None, 1, 8)                 256       ['reshape_7[0][0]']
#
#  activation_29 (Activation)  (None, 1, 8)                 0         ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 1, 32)                256       ['activation_29[0][0]']
#
#  activation_30 (Activation)  (None, 1, 32)                0         ['conv1d_16[0][0]']
#
#  multiply_7 (Multiply)       (None, 140, 32)              0         ['dropout_7[0][0]',
#                                                                      'activation_30[0][0]']
#
#  cropping1d_7 (Cropping1D)   (None, 140, 32)              0         ['activation_27[0][0]']
#
#  add_7 (Add)                 (None, 140, 32)              0         ['multiply_7[0][0]',
#                                                                      'cropping1d_7[0][0]']
#
#  activation_31 (Activation)  (None, 140, 32)              0         ['add_7[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 1, 32)                0         ['activation_31[0][0]']
#  D)
#
#  global_average_pooling1d_8  (None, 32)                   0         ['activation_31[0][0]']
#   (GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 32)                   0         ['max_pooling1d[0][0]']
#
#  dropout_8 (Dropout)         (None, 32)                   0         ['global_average_pooling1d_8[0
#                                                                     ][0]']
#
#  dropout_9 (Dropout)         (None, 32)                   0         ['flatten[0][0]']
#
#  concatenate (Concatenate)   (None, 64)                   0         ['dropout_8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  output_layer (Dense)        (None, 5)                    325       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 13711 (53.56 KB)
# Trainable params: 13187 (51.51 KB)
# Non-trainable params: 524 (2.05 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# I0000 00:00:1781858646.140803 2271808 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781858647.510004 2271809 service.cc:153] XLA service 0x7f7cb87c7380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781858647.510025 2271809 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781858647.516868 2271809 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781858647.620772 2271809 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 569/569 [==============================] - ETA: 0s - loss: 2.1103 - accuracy: 0.5820
# Epoch 1: val_loss improved from inf to 0.95244, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 23s 19ms/step - loss: 2.1103 - accuracy: 0.5820 - val_loss: 0.9524 - val_accuracy: 0.6911 - lr: 0.0010
# Epoch 2/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.9270 - accuracy: 0.8150
# Epoch 2: val_loss improved from 0.95244 to 0.65326, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.9270 - accuracy: 0.8149 - val_loss: 0.6533 - val_accuracy: 0.8791 - lr: 0.0010
# Epoch 3/100
# 569/569 [==============================] - ETA: 0s - loss: 0.7514 - accuracy: 0.8875
# Epoch 3: val_loss improved from 0.65326 to 0.62194, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 9s 16ms/step - loss: 0.7514 - accuracy: 0.8875 - val_loss: 0.6219 - val_accuracy: 0.9035 - lr: 0.0010
# Epoch 4/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6999 - accuracy: 0.9090
# Epoch 4: val_loss improved from 0.62194 to 0.57124, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6999 - accuracy: 0.9091 - val_loss: 0.5712 - val_accuracy: 0.9222 - lr: 0.0010
# Epoch 5/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6781 - accuracy: 0.9194
# Epoch 5: val_loss did not improve from 0.57124
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6781 - accuracy: 0.9194 - val_loss: 0.5960 - val_accuracy: 0.9126 - lr: 0.0010
# Epoch 6/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.9233
# Epoch 6: val_loss improved from 0.57124 to 0.56484, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6646 - accuracy: 0.9233 - val_loss: 0.5648 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 7/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6512 - accuracy: 0.9309
# Epoch 7: val_loss did not improve from 0.56484
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6513 - accuracy: 0.9307 - val_loss: 0.5738 - val_accuracy: 0.9201 - lr: 0.0010
# Epoch 8/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6449 - accuracy: 0.9331
# Epoch 8: val_loss did not improve from 0.56484
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6449 - accuracy: 0.9331 - val_loss: 0.5705 - val_accuracy: 0.9183 - lr: 0.0010
# Epoch 9/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6369 - accuracy: 0.9385
# Epoch 9: val_loss improved from 0.56484 to 0.55594, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 18ms/step - loss: 0.6369 - accuracy: 0.9385 - val_loss: 0.5559 - val_accuracy: 0.9253 - lr: 0.0010
# Epoch 10/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6315 - accuracy: 0.9399
# Epoch 10: val_loss did not improve from 0.55594
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6316 - accuracy: 0.9399 - val_loss: 0.5570 - val_accuracy: 0.9261 - lr: 0.0010
# Epoch 11/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6278 - accuracy: 0.9426
# Epoch 11: val_loss improved from 0.55594 to 0.55441, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6278 - accuracy: 0.9426 - val_loss: 0.5544 - val_accuracy: 0.9276 - lr: 0.0010
# Epoch 12/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6246 - accuracy: 0.9430
# Epoch 12: val_loss did not improve from 0.55441
# 569/569 [==============================] - 10s 18ms/step - loss: 0.6247 - accuracy: 0.9430 - val_loss: 0.5603 - val_accuracy: 0.9241 - lr: 0.0010
# Epoch 13/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6212 - accuracy: 0.9456
# Epoch 13: val_loss improved from 0.55441 to 0.55430, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6213 - accuracy: 0.9456 - val_loss: 0.5543 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 14/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6189 - accuracy: 0.9455
# Epoch 14: val_loss improved from 0.55430 to 0.53363, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.6189 - accuracy: 0.9455 - val_loss: 0.5336 - val_accuracy: 0.9340 - lr: 0.0010
# Epoch 15/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6164 - accuracy: 0.9486
# Epoch 15: val_loss did not improve from 0.53363
# 569/569 [==============================] - 9s 17ms/step - loss: 0.6165 - accuracy: 0.9486 - val_loss: 0.5374 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 16/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.9480
# Epoch 16: val_loss did not improve from 0.53363
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6152 - accuracy: 0.9480 - val_loss: 0.5476 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 17/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6094 - accuracy: 0.9521
# Epoch 17: val_loss did not improve from 0.53363
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6095 - accuracy: 0.9521 - val_loss: 0.5468 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 18/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6082 - accuracy: 0.9515
# Epoch 18: val_loss did not improve from 0.53363
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6085 - accuracy: 0.9515 - val_loss: 0.5505 - val_accuracy: 0.9305 - lr: 0.0010
# Epoch 19/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6100 - accuracy: 0.9523
# Epoch 19: val_loss did not improve from 0.53363
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6100 - accuracy: 0.9522 - val_loss: 0.5413 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 20/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6002 - accuracy: 0.9558
# Epoch 20: val_loss improved from 0.53363 to 0.53210, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 9s 16ms/step - loss: 0.6003 - accuracy: 0.9558 - val_loss: 0.5321 - val_accuracy: 0.9360 - lr: 5.0000e-04
# Epoch 21/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5969 - accuracy: 0.9585
# Epoch 21: val_loss improved from 0.53210 to 0.52778, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5970 - accuracy: 0.9584 - val_loss: 0.5278 - val_accuracy: 0.9365 - lr: 5.0000e-04
# Epoch 22/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.5983 - accuracy: 0.9571
# Epoch 22: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5983 - accuracy: 0.9571 - val_loss: 0.5294 - val_accuracy: 0.9350 - lr: 5.0000e-04
# Epoch 23/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5959 - accuracy: 0.9588
# Epoch 23: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5959 - accuracy: 0.9588 - val_loss: 0.5287 - val_accuracy: 0.9363 - lr: 5.0000e-04
# Epoch 24/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5959 - accuracy: 0.9578
# Epoch 24: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5961 - accuracy: 0.9578 - val_loss: 0.5407 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 25/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.9591
# Epoch 25: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5959 - accuracy: 0.9591 - val_loss: 0.5337 - val_accuracy: 0.9344 - lr: 5.0000e-04
# Epoch 26/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5954 - accuracy: 0.9590
# Epoch 26: val_loss did not improve from 0.52778
# 569/569 [==============================] - 9s 17ms/step - loss: 0.5954 - accuracy: 0.9590 - val_loss: 0.5308 - val_accuracy: 0.9348 - lr: 5.0000e-04
# Epoch 27/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.9602
# Epoch 27: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5916 - accuracy: 0.9602 - val_loss: 0.5327 - val_accuracy: 0.9331 - lr: 2.5000e-04
# Epoch 28/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5895 - accuracy: 0.9625
# Epoch 28: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5895 - accuracy: 0.9625 - val_loss: 0.5312 - val_accuracy: 0.9340 - lr: 2.5000e-04
# Epoch 29/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5899 - accuracy: 0.9617
# Epoch 29: val_loss did not improve from 0.52778
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5899 - accuracy: 0.9617 - val_loss: 0.5329 - val_accuracy: 0.9351 - lr: 2.5000e-04
# Epoch 30/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5892 - accuracy: 0.9627
# Epoch 30: val_loss improved from 0.52778 to 0.52419, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/best_model_v30_tcn_optimize_v2.keras
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5892 - accuracy: 0.9627 - val_loss: 0.5242 - val_accuracy: 0.9383 - lr: 2.5000e-04
# Epoch 31/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.9626
# Epoch 31: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5888 - accuracy: 0.9626 - val_loss: 0.5324 - val_accuracy: 0.9345 - lr: 2.5000e-04
# Epoch 32/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.9627
# Epoch 32: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5890 - accuracy: 0.9627 - val_loss: 0.5308 - val_accuracy: 0.9359 - lr: 2.5000e-04
# Epoch 33/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.9633
# Epoch 33: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5882 - accuracy: 0.9632 - val_loss: 0.5290 - val_accuracy: 0.9373 - lr: 2.5000e-04
# Epoch 34/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.9633
# Epoch 34: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5876 - accuracy: 0.9633 - val_loss: 0.5285 - val_accuracy: 0.9373 - lr: 2.5000e-04
# Epoch 35/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.5868 - accuracy: 0.9639
# Epoch 35: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5867 - accuracy: 0.9639 - val_loss: 0.5261 - val_accuracy: 0.9397 - lr: 2.5000e-04
# Epoch 36/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5862 - accuracy: 0.9642
# Epoch 36: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5862 - accuracy: 0.9642 - val_loss: 0.5321 - val_accuracy: 0.9357 - lr: 1.2500e-04
# Epoch 37/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5848 - accuracy: 0.9652
# Epoch 37: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5849 - accuracy: 0.9651 - val_loss: 0.5307 - val_accuracy: 0.9368 - lr: 1.2500e-04
# Epoch 38/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5836 - accuracy: 0.9656
# Epoch 38: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 16ms/step - loss: 0.5836 - accuracy: 0.9655 - val_loss: 0.5307 - val_accuracy: 0.9362 - lr: 1.2500e-04
# Epoch 39/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5841 - accuracy: 0.9658
# Epoch 39: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5842 - accuracy: 0.9657 - val_loss: 0.5293 - val_accuracy: 0.9363 - lr: 1.2500e-04
# Epoch 40/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5844 - accuracy: 0.9654
# Epoch 40: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5844 - accuracy: 0.9654 - val_loss: 0.5290 - val_accuracy: 0.9360 - lr: 1.2500e-04
# Epoch 41/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.9660
# Epoch 41: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 18ms/step - loss: 0.5847 - accuracy: 0.9660 - val_loss: 0.5309 - val_accuracy: 0.9360 - lr: 6.2500e-05
# Epoch 42/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5840 - accuracy: 0.9651
# Epoch 42: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5841 - accuracy: 0.9652 - val_loss: 0.5330 - val_accuracy: 0.9351 - lr: 6.2500e-05
# Epoch 43/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5842 - accuracy: 0.9658
# Epoch 43: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5843 - accuracy: 0.9658 - val_loss: 0.5281 - val_accuracy: 0.9377 - lr: 6.2500e-05
# Epoch 44/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.9661
# Epoch 44: val_loss did not improve from 0.52419
# 569/569 [==============================] - 9s 17ms/step - loss: 0.5836 - accuracy: 0.9661 - val_loss: 0.5297 - val_accuracy: 0.9363 - lr: 6.2500e-05
# Epoch 45/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.9667
# Epoch 45: val_loss did not improve from 0.52419
# 569/569 [==============================] - 10s 17ms/step - loss: 0.5833 - accuracy: 0.9667 - val_loss: 0.5310 - val_accuracy: 0.9354 - lr: 6.2500e-05
# 24/24 [==============================] - 2s 16ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_tcn_optimize_v2 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9783    0.9244    0.9506      1906
#          Run     0.9790    0.9871    0.9830      1085
#         Idle     0.8839    0.9566    0.9188      1798
#        Trans     0.8542    0.8060    0.8294       567
#         Fall     0.9986    0.9720    0.9851       750
#
#     accuracy                         0.9399      6106
#    macro avg     0.9388    0.9292    0.9334      6106
# weighted avg     0.9416    0.9399    0.9400      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 729
#   - TỶ LỆ RECALL TÉ NGÃ: 97.20%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/report_v30_tcn_optimize_v2.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)
np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpv9a_1oph/assets
# INFO:tensorflow:Assets written to: /tmp/tmpv9a_1oph/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781861192.046871 2271575 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781861192.046892 2271575 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781861192.047021 2271575 reader.cc:83] Reading SavedModel from: /tmp/tmpv9a_1oph
# I0000 00:00:1781861192.057294 2271575 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781861192.057318 2271575 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpv9a_1oph
# I0000 00:00:1781861192.114869 2271575 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781861192.218068 2271575 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpv9a_1oph
# I0000 00:00:1781861192.286203 2271575 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 239200 microseconds.
# I0000 00:00:1781861192.602014 2271575 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 3.008 M  ops, equivalently 1.504 M  MACs
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_tcn_optimize_v2/model_v30_tcn_optimize_v2_int8.tflite  (75040 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['ADD', 'CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'LOGISTIC', 'MAX_POOL_2D', 'MEAN', 'MUL', 'RESHAPE', 'SOFTMAX', 'STRIDED_SLICE']
# [*] Da sinh model_data_v30_tcn_optimize_v2.cc / .h
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781861193.495273 2271575 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 3.008 M  ops, equivalently 1.504 M  MACs
# W0000 00:00:1781861193.495290 2271575 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
