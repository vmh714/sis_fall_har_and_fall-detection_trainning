# %% [markdown]
# # v30_resnet1d — ResNet-1D (v25: SE + residual) trên PIPELINE v30
#
# **Giữ nguyên kiến trúc ResNet-1D của v25** (Conv stem + 4 ResNet block SeparableConv + SE + residual, head GAP+GMP) NHƯNG chạy trên **pipeline data v30**:
# - gyro **dps clip±500/500** (gyro **sống trên INT8** — v25 pipeline cũ /2000 gyro chết).
# - **Trans cắt theo sự kiện gyro RMS>20** (nhãn sạch), augment ×0.9/1.1, Trans weight 0.55.
# - Reuse **`cache_v30`** → KHÔNG windowing lại.
#
# Mục đích: so công bằng **ResNet vs CNN-v30 vs LSTM** trên cùng data v30; và đo tác động fix gyro trên ResNet.

# %% [markdown]
# ## 📌 Ghi chú
# - Kiến trúc = **ResNet-1D v25** (SeparableConv + SE block + residual, head GAP+GMP).
# - Pipeline data = **v30** (gyro dps clip±500/500, Trans theo sự kiện gyro, augment ×0.9/1.1).
# - SE block dùng sigmoid (ESP-NN không tăng tốc) + GMP→REDUCE_MAX — giữ nguyên như v25 để so công bằng.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # v30: gyro o dps -> normalize = clip +-500 roi /500 (KHOP firmware: firmware cung clip+-500/500).
                # Range thuc p99.9 ~349 dps -> clip 500 phu du; gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781891304.816955 2725280 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — ResNet-1D v25 (SE + residual)
# Cải tiến dùng hard-sigmoid và bỏ GMP để tối ưu tốc độ trên mô hình AI

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     Multiply, Add, GlobalAveragePooling1D, GlobalMaxPooling1D,
                                     Concatenate, Dropout, Dense, Reshape)
from tensorflow.keras.models import Model

# Kỹ thuật Hard-Sigmoid hỗ trợ tăng tốc trên phần cứng ESP-NN
def hard_sigmoid(x):
    return tf.nn.relu6(x + 3.) * 0.16666667

def se_block_v25(x, c, ratio=4):
    # SE block (Conv1D pointwise) — nhu v25
    se = GlobalAveragePooling1D()(x)
    se = Reshape((1, c))(se)
    se = Conv1D(c // ratio, kernel_size=1, use_bias=False)(se)
    se = Activation('relu6')(se)
    se = Conv1D(c, kernel_size=1, use_bias=False)(se)
    # TỐI ƯU: Thay thế Sigmoid (chậm) bằng Hard-Sigmoid (tăng tốc bằng relu6)
    se = Activation(hard_sigmoid)(se)
    return Multiply()([x, se])

def resnet1d_block(x, filters, kernel_size, strides, apply_se=True):
    residual = x
    y = SeparableConv1D(filters, kernel_size, strides=strides, padding='same', use_bias=False)(x)
    y = BatchNormalization()(y); y = Activation('relu6')(y)
    y = SeparableConv1D(filters, kernel_size, strides=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    if residual.shape[-1] != filters or strides != 1:
        residual = Conv1D(filters, kernel_size=1, strides=strides, padding='same', use_bias=False)(residual)
        residual = BatchNormalization()(residual)
    if apply_se:
        y = se_block_v25(y, c=filters, ratio=4)
    y = Add()([y, residual]); y = Activation('relu6')(y)
    return Dropout(0.2)(y)

def build_model(input_shape=(200, 6), n_classes=5):
    # ResNet-1D v25 nguyen ban: stem Conv16 + 4 block (16,32,32,64) + GAP+GMP + Dense
    inputs = Input(shape=input_shape)
    x = Conv1D(16, kernel_size=3, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = resnet1d_block(x, filters=16, kernel_size=3, strides=1)
    x = resnet1d_block(x, filters=32, kernel_size=3, strides=2)
    x = resnet1d_block(x, filters=32, kernel_size=3, strides=1)
    x = resnet1d_block(x, filters=64, kernel_size=3, strides=2)
    
    # TỐI ƯU: Bỏ GlobalMaxPooling1D vì hàm REDUCE_MAX rớt xuống Reference (không được ESP-NN tăng tốc)
    # Ta chỉ dùng GAP (GlobalAveragePooling1D) vì MEAN được tăng tốc phần cứng
    gap = GlobalAveragePooling1D()(x)
    x = Dropout(0.3)(gap)
    
    outputs = Dense(n_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v30'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_resnet1d_optimize'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_resnet1d"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# === Augment Trans: nhan bien do x0.9 va x1.1 (CHI train, TRUOC preprocessing) ===
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]
    print('Da augment Trans x0.9/x1.1 ->', len(tmask), 'x3')

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Da augment Trans x0.9/x1.1 -> 2683 x3
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# I0000 00:00:1781891310.908047 2725280 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]             0         []
#
#  conv1d (Conv1D)             (None, 100, 16)              288       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 100, 16)              64        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 100, 16)              0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 100, 16)              304       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 100, 16)              64        ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 100, 16)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  separable_conv1d_1 (Separa  (None, 100, 16)              304       ['activation_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 100, 16)              64        ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  global_average_pooling1d (  (None, 16)                   0         ['batch_normalization_2[0][0]'
#  GlobalAveragePooling1D)                                            ]
#
#  reshape (Reshape)           (None, 1, 16)                0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  conv1d_1 (Conv1D)           (None, 1, 4)                 64        ['reshape[0][0]']
#
#  activation_2 (Activation)   (None, 1, 4)                 0         ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 1, 16)                64        ['activation_2[0][0]']
#
#  activation_3 (Activation)   (None, 1, 16)                0         ['conv1d_2[0][0]']
#
#  multiply (Multiply)         (None, 100, 16)              0         ['batch_normalization_2[0][0]'
#                                                                     , 'activation_3[0][0]']
#
#  add (Add)                   (None, 100, 16)              0         ['multiply[0][0]',
#                                                                      'activation[0][0]']
#
#  activation_4 (Activation)   (None, 100, 16)              0         ['add[0][0]']
#
#  dropout (Dropout)           (None, 100, 16)              0         ['activation_4[0][0]']
#
#  separable_conv1d_2 (Separa  (None, 50, 32)               560       ['dropout[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 50, 32)               128       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 50, 32)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  separable_conv1d_3 (Separa  (None, 50, 32)               1120      ['activation_5[0][0]']
#  bleConv1D)
#
#  batch_normalization_4 (Bat  (None, 50, 32)               128       ['separable_conv1d_3[0][0]']
#  chNormalization)
#
#  global_average_pooling1d_1  (None, 32)                   0         ['batch_normalization_4[0][0]'
#   (GlobalAveragePooling1D)                                          ]
#
#  reshape_1 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  conv1d_4 (Conv1D)           (None, 1, 8)                 256       ['reshape_1[0][0]']
#
#  activation_6 (Activation)   (None, 1, 8)                 0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 1, 32)                256       ['activation_6[0][0]']
#
#  activation_7 (Activation)   (None, 1, 32)                0         ['conv1d_5[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 50, 32)               512       ['dropout[0][0]']
#
#  multiply_1 (Multiply)       (None, 50, 32)               0         ['batch_normalization_4[0][0]'
#                                                                     , 'activation_7[0][0]']
#
#  batch_normalization_5 (Bat  (None, 50, 32)               128       ['conv1d_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 50, 32)               0         ['multiply_1[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 50, 32)               0         ['add_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 50, 32)               0         ['activation_8[0][0]']
#
#  separable_conv1d_4 (Separa  (None, 50, 32)               1120      ['dropout_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_6 (Bat  (None, 50, 32)               128       ['separable_conv1d_4[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 50, 32)               0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  separable_conv1d_5 (Separa  (None, 50, 32)               1120      ['activation_9[0][0]']
#  bleConv1D)
#
#  batch_normalization_7 (Bat  (None, 50, 32)               128       ['separable_conv1d_5[0][0]']
#  chNormalization)
#
#  global_average_pooling1d_2  (None, 32)                   0         ['batch_normalization_7[0][0]'
#   (GlobalAveragePooling1D)                                          ]
#
#  reshape_2 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  conv1d_6 (Conv1D)           (None, 1, 8)                 256       ['reshape_2[0][0]']
#
#  activation_10 (Activation)  (None, 1, 8)                 0         ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 1, 32)                256       ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 1, 32)                0         ['conv1d_7[0][0]']
#
#  multiply_2 (Multiply)       (None, 50, 32)               0         ['batch_normalization_7[0][0]'
#                                                                     , 'activation_11[0][0]']
#
#  add_2 (Add)                 (None, 50, 32)               0         ['multiply_2[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  activation_12 (Activation)  (None, 50, 32)               0         ['add_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 50, 32)               0         ['activation_12[0][0]']
#
#  separable_conv1d_6 (Separa  (None, 25, 64)               2144      ['dropout_2[0][0]']
#  bleConv1D)
#
#  batch_normalization_8 (Bat  (None, 25, 64)               256       ['separable_conv1d_6[0][0]']
#  chNormalization)
#
#  activation_13 (Activation)  (None, 25, 64)               0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv1d_7 (Separa  (None, 25, 64)               4288      ['activation_13[0][0]']
#  bleConv1D)
#
#  batch_normalization_9 (Bat  (None, 25, 64)               256       ['separable_conv1d_7[0][0]']
#  chNormalization)
#
#  global_average_pooling1d_3  (None, 64)                   0         ['batch_normalization_9[0][0]'
#   (GlobalAveragePooling1D)                                          ]
#
#  reshape_3 (Reshape)         (None, 1, 64)                0         ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  conv1d_9 (Conv1D)           (None, 1, 16)                1024      ['reshape_3[0][0]']
#
#  activation_14 (Activation)  (None, 1, 16)                0         ['conv1d_9[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 1, 64)                1024      ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 1, 64)                0         ['conv1d_10[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 25, 64)               2048      ['dropout_2[0][0]']
#
#  multiply_3 (Multiply)       (None, 25, 64)               0         ['batch_normalization_9[0][0]'
#                                                                     , 'activation_15[0][0]']
#
#  batch_normalization_10 (Ba  (None, 25, 64)               256       ['conv1d_8[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 25, 64)               0         ['multiply_3[0][0]',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 25, 64)               0         ['add_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 25, 64)               0         ['activation_16[0][0]']
#
#  global_average_pooling1d_4  (None, 64)                   0         ['dropout_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['global_average_pooling1d_4[0
#                                                                     ][0]']
#
#  dense (Dense)               (None, 5)                    325       ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 18933 (73.96 KB)
# Trainable params: 18133 (70.83 KB)
# Non-trainable params: 800 (3.12 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# I0000 00:00:1781891318.903113 2725777 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781891321.414530 2725777 service.cc:153] XLA service 0x7fa7687dff40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781891321.414549 2725777 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781891321.422090 2725777 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781891321.527870 2725777 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 569/569 [==============================] - ETA: 0s - loss: 0.9376 - accuracy: 0.7719
# Epoch 1: val_loss improved from inf to 0.86103, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 25s 19ms/step - loss: 0.9376 - accuracy: 0.7719 - val_loss: 0.8610 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 2/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.8864
# Epoch 2: val_loss improved from 0.86103 to 0.65256, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 11s 20ms/step - loss: 0.7303 - accuracy: 0.8863 - val_loss: 0.6526 - val_accuracy: 0.8856 - lr: 0.0010
# Epoch 3/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6925 - accuracy: 0.9060
# Epoch 3: val_loss improved from 0.65256 to 0.58161, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6925 - accuracy: 0.9060 - val_loss: 0.5816 - val_accuracy: 0.9172 - lr: 0.0010
# Epoch 4/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.9154
# Epoch 4: val_loss did not improve from 0.58161
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6758 - accuracy: 0.9154 - val_loss: 0.5940 - val_accuracy: 0.9126 - lr: 0.0010
# Epoch 5/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.9206
# Epoch 5: val_loss did not improve from 0.58161
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6637 - accuracy: 0.9206 - val_loss: 0.5821 - val_accuracy: 0.9158 - lr: 0.0010
# Epoch 6/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6568 - accuracy: 0.9240
# Epoch 6: val_loss did not improve from 0.58161
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6568 - accuracy: 0.9239 - val_loss: 0.5887 - val_accuracy: 0.9156 - lr: 0.0010
# Epoch 7/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6533 - accuracy: 0.9246
# Epoch 7: val_loss improved from 0.58161 to 0.56935, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6534 - accuracy: 0.9245 - val_loss: 0.5693 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 8/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.9283
# Epoch 8: val_loss did not improve from 0.56935
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6483 - accuracy: 0.9283 - val_loss: 0.5715 - val_accuracy: 0.9201 - lr: 0.0010
# Epoch 9/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6423 - accuracy: 0.9298
# Epoch 9: val_loss did not improve from 0.56935
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6424 - accuracy: 0.9297 - val_loss: 0.5740 - val_accuracy: 0.9163 - lr: 0.0010
# Epoch 10/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.9343
# Epoch 10: val_loss did not improve from 0.56935
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6388 - accuracy: 0.9342 - val_loss: 0.5707 - val_accuracy: 0.9218 - lr: 0.0010
# Epoch 11/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6365 - accuracy: 0.9337
# Epoch 11: val_loss improved from 0.56935 to 0.55986, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 21ms/step - loss: 0.6366 - accuracy: 0.9337 - val_loss: 0.5599 - val_accuracy: 0.9212 - lr: 0.0010
# Epoch 12/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6337 - accuracy: 0.9352
# Epoch 12: val_loss improved from 0.55986 to 0.54591, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 21ms/step - loss: 0.6337 - accuracy: 0.9352 - val_loss: 0.5459 - val_accuracy: 0.9291 - lr: 0.0010
# Epoch 13/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6321 - accuracy: 0.9363
# Epoch 13: val_loss did not improve from 0.54591
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6321 - accuracy: 0.9363 - val_loss: 0.5605 - val_accuracy: 0.9250 - lr: 0.0010
# Epoch 14/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6289 - accuracy: 0.9374
# Epoch 14: val_loss did not improve from 0.54591
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6291 - accuracy: 0.9374 - val_loss: 0.5726 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 15/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.9374
# Epoch 15: val_loss did not improve from 0.54591
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6295 - accuracy: 0.9374 - val_loss: 0.5561 - val_accuracy: 0.9229 - lr: 0.0010
# Epoch 16/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6249 - accuracy: 0.9396
# Epoch 16: val_loss did not improve from 0.54591
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6252 - accuracy: 0.9396 - val_loss: 0.5506 - val_accuracy: 0.9279 - lr: 0.0010
# Epoch 17/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.9381
# Epoch 17: val_loss did not improve from 0.54591
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6258 - accuracy: 0.9381 - val_loss: 0.5542 - val_accuracy: 0.9276 - lr: 0.0010
# Epoch 18/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.9428
# Epoch 18: val_loss did not improve from 0.54591
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6181 - accuracy: 0.9428 - val_loss: 0.5497 - val_accuracy: 0.9281 - lr: 5.0000e-04
# Epoch 19/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6152 - accuracy: 0.9455
# Epoch 19: val_loss improved from 0.54591 to 0.54350, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 21ms/step - loss: 0.6153 - accuracy: 0.9455 - val_loss: 0.5435 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 20/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6121 - accuracy: 0.9466
# Epoch 20: val_loss did not improve from 0.54350
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6121 - accuracy: 0.9466 - val_loss: 0.5479 - val_accuracy: 0.9305 - lr: 5.0000e-04
# Epoch 21/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6133 - accuracy: 0.9458
# Epoch 21: val_loss improved from 0.54350 to 0.54231, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6133 - accuracy: 0.9457 - val_loss: 0.5423 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 22/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6112 - accuracy: 0.9459
# Epoch 22: val_loss did not improve from 0.54231
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6113 - accuracy: 0.9458 - val_loss: 0.5513 - val_accuracy: 0.9285 - lr: 5.0000e-04
# Epoch 23/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6127 - accuracy: 0.9457
# Epoch 23: val_loss did not improve from 0.54231
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6127 - accuracy: 0.9457 - val_loss: 0.5468 - val_accuracy: 0.9293 - lr: 5.0000e-04
# Epoch 24/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6117 - accuracy: 0.9472
# Epoch 24: val_loss did not improve from 0.54231
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6117 - accuracy: 0.9472 - val_loss: 0.5483 - val_accuracy: 0.9293 - lr: 5.0000e-04
# Epoch 25/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6095 - accuracy: 0.9479
# Epoch 25: val_loss did not improve from 0.54231
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6095 - accuracy: 0.9479 - val_loss: 0.5467 - val_accuracy: 0.9293 - lr: 5.0000e-04
# Epoch 26/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6083 - accuracy: 0.9470
# Epoch 26: val_loss improved from 0.54231 to 0.54103, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 21ms/step - loss: 0.6083 - accuracy: 0.9470 - val_loss: 0.5410 - val_accuracy: 0.9365 - lr: 5.0000e-04
# Epoch 27/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6088 - accuracy: 0.9480
# Epoch 27: val_loss did not improve from 0.54103
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6089 - accuracy: 0.9479 - val_loss: 0.5492 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 28/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.9479
# Epoch 28: val_loss did not improve from 0.54103
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6082 - accuracy: 0.9479 - val_loss: 0.5456 - val_accuracy: 0.9308 - lr: 5.0000e-04
# Epoch 29/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6075 - accuracy: 0.9487
# Epoch 29: val_loss did not improve from 0.54103
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6075 - accuracy: 0.9487 - val_loss: 0.5445 - val_accuracy: 0.9331 - lr: 5.0000e-04
# Epoch 30/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.9497
# Epoch 30: val_loss improved from 0.54103 to 0.54041, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6068 - accuracy: 0.9497 - val_loss: 0.5404 - val_accuracy: 0.9322 - lr: 5.0000e-04
# Epoch 31/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6056 - accuracy: 0.9489
# Epoch 31: val_loss did not improve from 0.54041
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6057 - accuracy: 0.9488 - val_loss: 0.5480 - val_accuracy: 0.9304 - lr: 5.0000e-04
# Epoch 32/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6059 - accuracy: 0.9491
# Epoch 32: val_loss did not improve from 0.54041
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6059 - accuracy: 0.9491 - val_loss: 0.5510 - val_accuracy: 0.9291 - lr: 5.0000e-04
# Epoch 33/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6066 - accuracy: 0.9479
# Epoch 33: val_loss improved from 0.54041 to 0.53856, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6067 - accuracy: 0.9479 - val_loss: 0.5386 - val_accuracy: 0.9345 - lr: 5.0000e-04
# Epoch 34/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.9494
# Epoch 34: val_loss improved from 0.53856 to 0.53828, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6040 - accuracy: 0.9494 - val_loss: 0.5383 - val_accuracy: 0.9347 - lr: 5.0000e-04
# Epoch 35/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.9493
# Epoch 35: val_loss improved from 0.53828 to 0.53532, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/best_model_v30_resnet1d.keras
# 569/569 [==============================] - 12s 20ms/step - loss: 0.6038 - accuracy: 0.9493 - val_loss: 0.5353 - val_accuracy: 0.9351 - lr: 5.0000e-04
# Epoch 36/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6035 - accuracy: 0.9511
# Epoch 36: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6035 - accuracy: 0.9511 - val_loss: 0.5415 - val_accuracy: 0.9351 - lr: 5.0000e-04
# Epoch 37/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6027 - accuracy: 0.9498
# Epoch 37: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6027 - accuracy: 0.9498 - val_loss: 0.5494 - val_accuracy: 0.9310 - lr: 5.0000e-04
# Epoch 38/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6027 - accuracy: 0.9492
# Epoch 38: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6027 - accuracy: 0.9492 - val_loss: 0.5504 - val_accuracy: 0.9256 - lr: 5.0000e-04
# Epoch 39/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6022 - accuracy: 0.9506
# Epoch 39: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6022 - accuracy: 0.9506 - val_loss: 0.5468 - val_accuracy: 0.9317 - lr: 5.0000e-04
# Epoch 40/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6017 - accuracy: 0.9505
# Epoch 40: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.6017 - accuracy: 0.9505 - val_loss: 0.5382 - val_accuracy: 0.9331 - lr: 5.0000e-04
# Epoch 41/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5989 - accuracy: 0.9515
# Epoch 41: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5990 - accuracy: 0.9514 - val_loss: 0.5424 - val_accuracy: 0.9347 - lr: 2.5000e-04
# Epoch 42/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5998 - accuracy: 0.9510
# Epoch 42: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5999 - accuracy: 0.9510 - val_loss: 0.5394 - val_accuracy: 0.9331 - lr: 2.5000e-04
# Epoch 43/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5971 - accuracy: 0.9533
# Epoch 43: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 19ms/step - loss: 0.5971 - accuracy: 0.9533 - val_loss: 0.5397 - val_accuracy: 0.9319 - lr: 2.5000e-04
# Epoch 44/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5961 - accuracy: 0.9542
# Epoch 44: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5962 - accuracy: 0.9542 - val_loss: 0.5442 - val_accuracy: 0.9340 - lr: 2.5000e-04
# Epoch 45/100
# 569/569 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.9529
# Epoch 45: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5977 - accuracy: 0.9529 - val_loss: 0.5397 - val_accuracy: 0.9340 - lr: 2.5000e-04
# Epoch 46/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5981 - accuracy: 0.9539
# Epoch 46: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5981 - accuracy: 0.9539 - val_loss: 0.5432 - val_accuracy: 0.9324 - lr: 1.2500e-04
# Epoch 47/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5957 - accuracy: 0.9554
# Epoch 47: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5958 - accuracy: 0.9553 - val_loss: 0.5377 - val_accuracy: 0.9345 - lr: 1.2500e-04
# Epoch 48/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5956 - accuracy: 0.9558
# Epoch 48: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5957 - accuracy: 0.9557 - val_loss: 0.5384 - val_accuracy: 0.9348 - lr: 1.2500e-04
# Epoch 49/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.5961 - accuracy: 0.9550
# Epoch 49: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5960 - accuracy: 0.9550 - val_loss: 0.5384 - val_accuracy: 0.9336 - lr: 1.2500e-04
# Epoch 50/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.5946 - accuracy: 0.9539
# Epoch 50: val_loss did not improve from 0.53532
# 569/569 [==============================] - 11s 20ms/step - loss: 0.5946 - accuracy: 0.9539 - val_loss: 0.5399 - val_accuracy: 0.9333 - lr: 1.2500e-04
# 24/24 [==============================] - 1s 12ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_resnet1d (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9816    0.9218    0.9508      1906
#          Run     0.9834    0.9834    0.9834      1085
#         Idle     0.8854    0.9410    0.9124      1798
#        Trans     0.7688    0.8095    0.7887       567
#         Fall     0.9986    0.9627    0.9803       750
#
#     accuracy                         0.9330      6106
#    macro avg     0.9236    0.9237    0.9231      6106
# weighted avg     0.9359    0.9330    0.9338      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 722
#   - TỶ LỆ RECALL TÉ NGÃ: 96.27%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/report_v30_resnet1d.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp6tzzv6t4/assets
# INFO:tensorflow:Assets written to: /tmp/tmp6tzzv6t4/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781891904.457331 2725280 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781891904.457363 2725280 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781891904.457688 2725280 reader.cc:83] Reading SavedModel from: /tmp/tmp6tzzv6t4
# I0000 00:00:1781891904.466803 2725280 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781891904.466838 2725280 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp6tzzv6t4
# I0000 00:00:1781891904.508253 2725280 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781891904.523960 2725280 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781891904.657996 2725280 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp6tzzv6t4
# I0000 00:00:1781891904.726634 2725280 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 268970 microseconds.
# I0000 00:00:1781891905.162767 2725280 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 1.096 M  ops, equivalently 0.548 M  MACs
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_resnet1d_optimize/model_v30_resnet1d_int8.tflite  (71584 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['ADD', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MEAN', 'MINIMUM', 'MUL', 'RELU', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v30_resnet1d.cc / .h
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781891905.383422 2725280 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 1.096 M  ops, equivalently 0.548 M  MACs
# W0000 00:00:1781891905.383446 2725280 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
