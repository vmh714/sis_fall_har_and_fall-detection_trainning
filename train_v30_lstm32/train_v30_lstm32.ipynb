# %% [markdown]
# # v30_lstm32 — model resize_32 (1 lớp LSTM) + PIPELINE v30 xịn
#
# **Giữ nguyên model** của `train_v1_5label_resize_32` (CNN 64,64 + MaxPool + **LSTM(32)** + Dense). **Chỉ đổi pipeline data** sang v30:
# - gyro = **dps**, normalize **`clip(±500)/500`** (thay `/2000` cũ).
# - Dùng lại **`cache_v30`** = windowing **Trans theo sự kiện gyro RMS>20 dps** + dps (khỏi cắt lại).
# - Augment Trans **×0.9/×1.1** (train), Trans weight **0.55**.
#
# Keras 2 (`TF_USE_LEGACY_KERAS=1`, cell đầu) để LSTM fuse cho TFLM. **Cần `cache_v30` đã có trên server.**

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                X[:, :, 3:6] = np.clip(X[:, :, 3:6], -500.0, 500.0) / 500.0   # v30: gyro dps clip +-500/500
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781781920.508291 1007416 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — RESIZE (1 lớp LSTM 32)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Dropout, Dense
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # Thí nghiệm B: BO 1 lớp LSTM, chi con 1 lớp LSTM(32)
    inputs = Input(shape=input_shape)

    # CNN block (giữ nguyên)
    x = Conv1D(64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu', padding='same')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.3)(x)

    # LSTM block (BO 1 LOP: chi con LSTM(32))
    x = LSTM(32)(x)
    x = Dropout(0.4)(x)

    # Classification head
    x = Dense(32, activation='relu')(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_new'
        cache_dir = f'{WORKSPACE}/cache_v30'
        out_dir   = f'{WORKSPACE}/output_v30_lstm32'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v30_lstm32"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp cache_v30 (data pipeline v30: dps + gyro-event Trans)
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()

# Augment Trans x0.9/x1.1 (CHI train, TRUOC normalize)
ti = trainer.class_names.index('Trans')
tmask = np.where(y_train == ti)[0]
if len(tmask) > 0:
    Xt = X_train[tmask]
    X_train = np.concatenate([X_train, (Xt*0.9).astype(np.float32), (Xt*1.1).astype(np.float32)], axis=0)
    y_train = np.concatenate([y_train, np.full(len(Xt), ti, y_train.dtype), np.full(len(Xt), ti, y_train.dtype)])
    _p = np.random.RandomState(42).permutation(len(X_train)); X_train, y_train = X_train[_p], y_train[_p]

X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 1.0, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 7537, 'Trans': 8049, 'Fall': 7125}
# I0000 00:00:1781781922.887937 1007416 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]          0
#
#  conv1d (Conv1D)             (None, 200, 64)           1216
#
#  conv1d_1 (Conv1D)           (None, 200, 64)           12352
#
#  max_pooling1d (MaxPooling1  (None, 100, 64)           0
#  D)
#
#  dropout (Dropout)           (None, 100, 64)           0
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 27205 (106.27 KB)
# Trainable params: 27205 (106.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# I0000 00:00:1781781925.073796 1008464 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781781926.092572 1008462 service.cc:153] XLA service 0x7f3884eb6110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781781926.092597 1008462 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781781926.099846 1008462 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781781926.195892 1008462 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 569/569 [==============================] - ETA: 0s - loss: 1.3512 - accuracy: 0.5235
# Epoch 1: val_loss improved from inf to 1.01874, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 8s 8ms/step - loss: 1.3512 - accuracy: 0.5235 - val_loss: 1.0187 - val_accuracy: 0.5943 - lr: 0.0010
# Epoch 2/100
# 567/569 [============================>.] - ETA: 0s - loss: 1.0730 - accuracy: 0.7012
# Epoch 2: val_loss improved from 1.01874 to 0.77777, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 1.0728 - accuracy: 0.7013 - val_loss: 0.7778 - val_accuracy: 0.8574 - lr: 0.0010
# Epoch 3/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.9662 - accuracy: 0.8088
# Epoch 3: val_loss did not improve from 0.77777
# 569/569 [==============================] - 4s 7ms/step - loss: 0.9654 - accuracy: 0.8094 - val_loss: 0.8236 - val_accuracy: 0.8115 - lr: 0.0010
# Epoch 4/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.8880 - accuracy: 0.8670
# Epoch 4: val_loss improved from 0.77777 to 0.69945, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.8879 - accuracy: 0.8671 - val_loss: 0.6995 - val_accuracy: 0.8752 - lr: 0.0010
# Epoch 5/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.9052 - accuracy: 0.8420
# Epoch 5: val_loss did not improve from 0.69945
# 569/569 [==============================] - 4s 7ms/step - loss: 0.9055 - accuracy: 0.8419 - val_loss: 0.7579 - val_accuracy: 0.8534 - lr: 0.0010
# Epoch 6/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.8690 - accuracy: 0.8693
# Epoch 6: val_loss improved from 0.69945 to 0.67943, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.8688 - accuracy: 0.8696 - val_loss: 0.6794 - val_accuracy: 0.8702 - lr: 0.0010
# Epoch 7/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.8150 - accuracy: 0.8860
# Epoch 7: val_loss did not improve from 0.67943
# 569/569 [==============================] - 4s 7ms/step - loss: 0.8150 - accuracy: 0.8861 - val_loss: 0.6925 - val_accuracy: 0.8586 - lr: 0.0010
# Epoch 8/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.8241 - accuracy: 0.8967
# Epoch 8: val_loss improved from 0.67943 to 0.65345, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.8243 - accuracy: 0.8963 - val_loss: 0.6534 - val_accuracy: 0.8914 - lr: 0.0010
# Epoch 9/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.7650 - accuracy: 0.9185
# Epoch 9: val_loss improved from 0.65345 to 0.60635, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.7650 - accuracy: 0.9185 - val_loss: 0.6064 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 10/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.7542 - accuracy: 0.9178
# Epoch 10: val_loss did not improve from 0.60635
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7552 - accuracy: 0.9174 - val_loss: 0.6710 - val_accuracy: 0.8957 - lr: 0.0010
# Epoch 11/100
# 560/569 [============================>.] - ETA: 0s - loss: 0.7419 - accuracy: 0.9207
# Epoch 11: val_loss improved from 0.60635 to 0.58213, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7413 - accuracy: 0.9210 - val_loss: 0.5821 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 12/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.7547 - accuracy: 0.9223
# Epoch 12: val_loss improved from 0.58213 to 0.58007, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7545 - accuracy: 0.9225 - val_loss: 0.5801 - val_accuracy: 0.9202 - lr: 0.0010
# Epoch 13/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.7417 - accuracy: 0.9241
# Epoch 13: val_loss did not improve from 0.58007
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7417 - accuracy: 0.9242 - val_loss: 0.6122 - val_accuracy: 0.9066 - lr: 0.0010
# Epoch 14/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.7258 - accuracy: 0.9316
# Epoch 14: val_loss improved from 0.58007 to 0.56396, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7259 - accuracy: 0.9316 - val_loss: 0.5640 - val_accuracy: 0.9293 - lr: 0.0010
# Epoch 15/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.7211 - accuracy: 0.9330
# Epoch 15: val_loss did not improve from 0.56396
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7209 - accuracy: 0.9330 - val_loss: 0.5764 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 16/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.7325 - accuracy: 0.9238
# Epoch 16: val_loss did not improve from 0.56396
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7324 - accuracy: 0.9238 - val_loss: 0.5996 - val_accuracy: 0.9107 - lr: 0.0010
# Epoch 17/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.9341
# Epoch 17: val_loss did not improve from 0.56396
# 569/569 [==============================] - 4s 6ms/step - loss: 0.7091 - accuracy: 0.9339 - val_loss: 0.5711 - val_accuracy: 0.9235 - lr: 0.0010
# Epoch 18/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.6967 - accuracy: 0.9377
# Epoch 18: val_loss did not improve from 0.56396
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6968 - accuracy: 0.9377 - val_loss: 0.5921 - val_accuracy: 0.9135 - lr: 0.0010
# Epoch 19/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6885 - accuracy: 0.9428
# Epoch 19: val_loss improved from 0.56396 to 0.56325, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6881 - accuracy: 0.9429 - val_loss: 0.5633 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 20/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6943 - accuracy: 0.9387
# Epoch 20: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6943 - accuracy: 0.9388 - val_loss: 0.5794 - val_accuracy: 0.9193 - lr: 0.0010
# Epoch 21/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6810 - accuracy: 0.9432
# Epoch 21: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6812 - accuracy: 0.9431 - val_loss: 0.5751 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 22/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6783 - accuracy: 0.9449
# Epoch 22: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6785 - accuracy: 0.9448 - val_loss: 0.5740 - val_accuracy: 0.9224 - lr: 0.0010
# Epoch 23/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.9468
# Epoch 23: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6726 - accuracy: 0.9468 - val_loss: 0.5730 - val_accuracy: 0.9253 - lr: 0.0010
# Epoch 24/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6770 - accuracy: 0.9452
# Epoch 24: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6804 - accuracy: 0.9442 - val_loss: 0.7326 - val_accuracy: 0.8597 - lr: 0.0010
# Epoch 25/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.9439
# Epoch 25: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6808 - accuracy: 0.9439 - val_loss: 0.5635 - val_accuracy: 0.9284 - lr: 5.0000e-04
# Epoch 26/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.6610 - accuracy: 0.9521
# Epoch 26: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6608 - accuracy: 0.9521 - val_loss: 0.5706 - val_accuracy: 0.9265 - lr: 5.0000e-04
# Epoch 27/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6576 - accuracy: 0.9537
# Epoch 27: val_loss did not improve from 0.56325
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6579 - accuracy: 0.9535 - val_loss: 0.5648 - val_accuracy: 0.9278 - lr: 5.0000e-04
# Epoch 28/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6569 - accuracy: 0.9537
# Epoch 28: val_loss improved from 0.56325 to 0.55865, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6571 - accuracy: 0.9535 - val_loss: 0.5587 - val_accuracy: 0.9287 - lr: 5.0000e-04
# Epoch 29/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.9539
# Epoch 29: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6563 - accuracy: 0.9539 - val_loss: 0.5645 - val_accuracy: 0.9291 - lr: 5.0000e-04
# Epoch 30/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6510 - accuracy: 0.9554
# Epoch 30: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6513 - accuracy: 0.9554 - val_loss: 0.5632 - val_accuracy: 0.9290 - lr: 5.0000e-04
# Epoch 31/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6503 - accuracy: 0.9551
# Epoch 31: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6505 - accuracy: 0.9551 - val_loss: 0.5733 - val_accuracy: 0.9235 - lr: 5.0000e-04
# Epoch 32/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6505 - accuracy: 0.9557
# Epoch 32: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6503 - accuracy: 0.9558 - val_loss: 0.5805 - val_accuracy: 0.9233 - lr: 5.0000e-04
# Epoch 33/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6503 - accuracy: 0.9562
# Epoch 33: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6503 - accuracy: 0.9562 - val_loss: 0.5847 - val_accuracy: 0.9227 - lr: 5.0000e-04
# Epoch 34/100
# 566/569 [============================>.] - ETA: 0s - loss: 0.6422 - accuracy: 0.9595
# Epoch 34: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6420 - accuracy: 0.9595 - val_loss: 0.5591 - val_accuracy: 0.9313 - lr: 2.5000e-04
# Epoch 35/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6414 - accuracy: 0.9597
# Epoch 35: val_loss did not improve from 0.55865
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6414 - accuracy: 0.9597 - val_loss: 0.5626 - val_accuracy: 0.9291 - lr: 2.5000e-04
# Epoch 36/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.6383 - accuracy: 0.9608
# Epoch 36: val_loss improved from 0.55865 to 0.55645, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6383 - accuracy: 0.9608 - val_loss: 0.5564 - val_accuracy: 0.9330 - lr: 2.5000e-04
# Epoch 37/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6413 - accuracy: 0.9594
# Epoch 37: val_loss did not improve from 0.55645
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6412 - accuracy: 0.9594 - val_loss: 0.5628 - val_accuracy: 0.9290 - lr: 2.5000e-04
# Epoch 38/100
# 565/569 [============================>.] - ETA: 0s - loss: 0.6394 - accuracy: 0.9602
# Epoch 38: val_loss did not improve from 0.55645
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6393 - accuracy: 0.9601 - val_loss: 0.5576 - val_accuracy: 0.9308 - lr: 2.5000e-04
# Epoch 39/100
# 568/569 [============================>.] - ETA: 0s - loss: 0.6362 - accuracy: 0.9610
# Epoch 39: val_loss did not improve from 0.55645
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6362 - accuracy: 0.9610 - val_loss: 0.5635 - val_accuracy: 0.9293 - lr: 2.5000e-04
# Epoch 40/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.9614
# Epoch 40: val_loss improved from 0.55645 to 0.55625, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/best_model_v30_lstm32.keras
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6350 - accuracy: 0.9613 - val_loss: 0.5563 - val_accuracy: 0.9316 - lr: 2.5000e-04
# Epoch 41/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6347 - accuracy: 0.9622
# Epoch 41: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6345 - accuracy: 0.9623 - val_loss: 0.5705 - val_accuracy: 0.9273 - lr: 2.5000e-04
# Epoch 42/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6359 - accuracy: 0.9607
# Epoch 42: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6361 - accuracy: 0.9606 - val_loss: 0.5668 - val_accuracy: 0.9294 - lr: 2.5000e-04
# Epoch 43/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6356 - accuracy: 0.9613
# Epoch 43: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6354 - accuracy: 0.9612 - val_loss: 0.5686 - val_accuracy: 0.9293 - lr: 2.5000e-04
# Epoch 44/100
# 564/569 [============================>.] - ETA: 0s - loss: 0.6333 - accuracy: 0.9621
# Epoch 44: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6333 - accuracy: 0.9623 - val_loss: 0.5704 - val_accuracy: 0.9268 - lr: 2.5000e-04
# Epoch 45/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6326 - accuracy: 0.9623
# Epoch 45: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6326 - accuracy: 0.9623 - val_loss: 0.5615 - val_accuracy: 0.9293 - lr: 2.5000e-04
# Epoch 46/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.9642
# Epoch 46: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6288 - accuracy: 0.9643 - val_loss: 0.5654 - val_accuracy: 0.9288 - lr: 1.2500e-04
# Epoch 47/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6287 - accuracy: 0.9642
# Epoch 47: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6284 - accuracy: 0.9641 - val_loss: 0.5675 - val_accuracy: 0.9299 - lr: 1.2500e-04
# Epoch 48/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.6270 - accuracy: 0.9644
# Epoch 48: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6273 - accuracy: 0.9644 - val_loss: 0.5782 - val_accuracy: 0.9259 - lr: 1.2500e-04
# Epoch 49/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.9645
# Epoch 49: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6275 - accuracy: 0.9645 - val_loss: 0.5589 - val_accuracy: 0.9314 - lr: 1.2500e-04
# Epoch 50/100
# 569/569 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.9643
# Epoch 50: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6283 - accuracy: 0.9643 - val_loss: 0.5669 - val_accuracy: 0.9294 - lr: 1.2500e-04
# Epoch 51/100
# 561/569 [============================>.] - ETA: 0s - loss: 0.6262 - accuracy: 0.9652
# Epoch 51: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6259 - accuracy: 0.9652 - val_loss: 0.5661 - val_accuracy: 0.9294 - lr: 6.2500e-05
# Epoch 52/100
# 567/569 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.9660
# Epoch 52: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 6ms/step - loss: 0.6248 - accuracy: 0.9661 - val_loss: 0.5638 - val_accuracy: 0.9310 - lr: 6.2500e-05
# Epoch 53/100
# 562/569 [============================>.] - ETA: 0s - loss: 0.6252 - accuracy: 0.9654
# Epoch 53: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6253 - accuracy: 0.9654 - val_loss: 0.5607 - val_accuracy: 0.9314 - lr: 6.2500e-05
# Epoch 54/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6252 - accuracy: 0.9658
# Epoch 54: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6250 - accuracy: 0.9658 - val_loss: 0.5612 - val_accuracy: 0.9302 - lr: 6.2500e-05
# Epoch 55/100
# 563/569 [============================>.] - ETA: 0s - loss: 0.6244 - accuracy: 0.9664
# Epoch 55: val_loss did not improve from 0.55625
# 569/569 [==============================] - 4s 7ms/step - loss: 0.6243 - accuracy: 0.9663 - val_loss: 0.5630 - val_accuracy: 0.9308 - lr: 6.2500e-05
# 24/24 [==============================] - 0s 4ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v30_lstm32 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9569    0.9092    0.9325      1906
#          Run     0.9593    0.9567    0.9580      1085
#         Idle     0.9185    0.9149    0.9167      1798
#        Trans     0.7521    0.9312    0.8322       567
#         Fall     0.9986    0.9587    0.9782       750
#
#     accuracy                         0.9274      6106
#    macro avg     0.9171    0.9341    0.9235      6106
# weighted avg     0.9321    0.9274    0.9287      6106
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 719
#   - TỶ LỆ RECALL TÉ NGÃ: 95.87%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/report_v30_lstm32.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
# Notebook dang chay Keras 2 (legacy) nen LSTM fuse thang thanh UNIDIRECTIONAL_SEQUENCE_LSTM.
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

# Clone sang batch co dinh = 1 de chac chan LSTM fuse khi convert.
static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

# --- Doc metadata that tu interpreter ---
it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','FULLY_CONNECTED':'AddFullyConnected','SOFTMAX':'AddSoftmax',
    'LOGISTIC':'AddLogistic','TANH':'AddTanh','RELU':'AddRelu','RESHAPE':'AddReshape',
    'UNIDIRECTIONAL_SEQUENCE_LSTM':'AddUnidirectionalSequenceLSTM','QUANTIZE':'AddQuantize',
    'DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice','CONCATENATION':'AddConcatenation',
    'ADD':'AddAdd','MUL':'AddMul','PACK':'AddPack','UNPACK':'AddUnpack','SHAPE':'AddShape',
    'FILL':'AddFill','GATHER':'AddGather','SLICE':'AddSlice','SPLIT':'AddSplit','TRANSPOSE':'AddTranspose',
    'MEAN':'AddMean','PAD':'AddPad','EXPAND_DIMS':'AddExpandDims','SQUEEZE':'AddSqueeze',
}
res_lines = []
for o in reg_ops:
    m = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m}();" if m else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    "// Sinh tu notebook (KHONG sua tay).\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

# C array (12 byte/dong)
body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h (co nhung ops + quant + goi y resolver)")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpttzsixa7/assets
# INFO:tensorflow:Assets written to: /tmp/tmpttzsixa7/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781782136.726819 1007416 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781782136.726833 1007416 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781782136.727032 1007416 reader.cc:83] Reading SavedModel from: /tmp/tmpttzsixa7
# I0000 00:00:1781782136.732409 1007416 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781782136.732423 1007416 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpttzsixa7
# I0000 00:00:1781782136.757878 1007416 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781782136.763881 1007416 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781782136.803883 1007416 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpttzsixa7
# I0000 00:00:1781782136.833436 1007416 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 106416 microseconds.
# I0000 00:00:1781782137.024302 1007416 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.417 M  ops, equivalently 2.709 M  MACs
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v30_lstm32/model_v30_lstm32_int8.tflite  (39192 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'RESHAPE', 'SOFTMAX', 'STRIDED_SLICE', 'UNIDIRECTIONAL_SEQUENCE_LSTM']
# [*] Da sinh model_data_v30_lstm32.cc / .h (co nhung ops + quant + goi y resolver)
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781782137.278895 1007416 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.417 M  ops, equivalently 2.709 M  MACs
# W0000 00:00:1781782137.278913 1007416 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
