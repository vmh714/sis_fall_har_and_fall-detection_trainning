# %% [markdown]
# # v28 — v27 + HEAD avg+max (tách Idle/Trans bằng đỉnh xung gyro)
#
# Trans = xung gyro ngắn ~0.5s; GAP pha loãng → giống Idle. Thêm nhánh **max-over-time** (MaxPool full + Flatten → op `MAX_POOL_2D` được ESP-NN tăng tốc) để giữ đỉnh xung.
# Kèm `class_weight['Trans']=0.55` để hết over-fire (precision 0.57 ↑).
#
# **Dùng lại `cache_resize_64_32` — KHÔNG windowing lại.**

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                X[:, :, 3:6] = X[:, :, 3:6] / 34.9
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781774781.584627  794926 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Kiến trúc — v27 CNN thuần (ESP-NN friendly)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, Flatten, Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # v28 = v27 (CNN thuan ESP-NN) NHUNG doi HEAD: avg + max-over-time.
    #   Ly do: "danh tinh" cua Trans la 1 XUNG GYRO ngan (~0.5s). GlobalAveragePooling
    #   pha loang xung -> Trans giong Idle. Them nhanh MAX giu lai dinh xung -> tach idle/trans.
    #   Dung MaxPooling1D(full)+Flatten (op MAX_POOL_2D, ESP-NN 7.83x) thay GlobalMaxPooling
    #   (op REDUCE_MAX, KHONG duoc ESP-NN tang toc).
    inp = Input(shape=input_shape)

    x = Conv1D(24, 3, strides=2, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    x = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 100->50

    x = SeparableConv1D(48, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 50->25

    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 25->12

    # Head: avg (MEAN) + max-over-time (MAX_POOL_2D) -> bat dinh xung gyro cua Trans
    a = GlobalAveragePooling1D()(x)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x)   # global-max nhung map ra MAX_POOL_2D (tang toc)
    m = Flatten()(m)
    x = Concatenate()([a, m])
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inp, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_new'
        cache_dir = f'{WORKSPACE}/cache_resize_64_32'
        out_dir   = f'{WORKSPACE}/output_v28'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v28"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()
X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 8365, 'Trans': 5706, 'Fall': 7125}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]             0         []
#
#  conv1d (Conv1D)             (None, 100, 24)              432       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 100, 24)              96        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 100, 24)              0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 100, 32)              840       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 100, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 100, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 50, 32)               0         ['activation_1[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 50, 48)               1632      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 50, 48)               192       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 50, 48)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 48)               0         ['activation_2[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 25, 64)               3216      ['max_pooling1d_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 25, 64)               256       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 25, 64)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 12, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)                0         ['max_pooling1d_2[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['max_pooling1d_2[0][0]']
#  GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 64)                   0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 5)                    645       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7437 (29.05 KB)
# Trainable params: 7101 (27.74 KB)
# Non-trainable params: 336 (1.31 KB)
# __________________________________________________________________________________________________
# I0000 00:00:1781774783.835055  794926 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/100
# I0000 00:00:1781774785.755058  795329 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781774787.155325  795329 service.cc:153] XLA service 0x7f326e0c3f70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781774787.155343  795329 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781774787.159772  795329 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781774787.238690  795329 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 545/545 [==============================] - ETA: 0s - loss: 1.0047 - accuracy: 0.7685
# Epoch 1: val_loss improved from inf to 1.01998, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 8s 7ms/step - loss: 1.0047 - accuracy: 0.7685 - val_loss: 1.0200 - val_accuracy: 0.6752 - lr: 0.0010
# Epoch 2/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7959 - accuracy: 0.8590
# Epoch 2: val_loss improved from 1.01998 to 0.61409, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7959 - accuracy: 0.8590 - val_loss: 0.6141 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 3/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.7528 - accuracy: 0.8832
# Epoch 3: val_loss did not improve from 0.61409
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7527 - accuracy: 0.8834 - val_loss: 0.6182 - val_accuracy: 0.9072 - lr: 0.0010
# Epoch 4/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.7305 - accuracy: 0.8955
# Epoch 4: val_loss improved from 0.61409 to 0.59311, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7303 - accuracy: 0.8955 - val_loss: 0.5931 - val_accuracy: 0.9198 - lr: 0.0010
# Epoch 5/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.7126 - accuracy: 0.9041
# Epoch 5: val_loss improved from 0.59311 to 0.59046, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7127 - accuracy: 0.9038 - val_loss: 0.5905 - val_accuracy: 0.9186 - lr: 0.0010
# Epoch 6/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.7036 - accuracy: 0.9085
# Epoch 6: val_loss improved from 0.59046 to 0.58770, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7035 - accuracy: 0.9084 - val_loss: 0.5877 - val_accuracy: 0.9212 - lr: 0.0010
# Epoch 7/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6957 - accuracy: 0.9125
# Epoch 7: val_loss improved from 0.58770 to 0.57963, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6958 - accuracy: 0.9123 - val_loss: 0.5796 - val_accuracy: 0.9233 - lr: 0.0010
# Epoch 8/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.9147
# Epoch 8: val_loss did not improve from 0.57963
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6898 - accuracy: 0.9147 - val_loss: 0.5811 - val_accuracy: 0.9213 - lr: 0.0010
# Epoch 9/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.9201
# Epoch 9: val_loss improved from 0.57963 to 0.57235, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6833 - accuracy: 0.9197 - val_loss: 0.5724 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 10/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6781 - accuracy: 0.9214
# Epoch 10: val_loss improved from 0.57235 to 0.56556, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6785 - accuracy: 0.9214 - val_loss: 0.5656 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 11/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.9235
# Epoch 11: val_loss improved from 0.56556 to 0.56497, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6737 - accuracy: 0.9237 - val_loss: 0.5650 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 12/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.9247
# Epoch 12: val_loss did not improve from 0.56497
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6714 - accuracy: 0.9247 - val_loss: 0.5756 - val_accuracy: 0.9227 - lr: 0.0010
# Epoch 13/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6681 - accuracy: 0.9257
# Epoch 13: val_loss did not improve from 0.56497
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6676 - accuracy: 0.9259 - val_loss: 0.5674 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 14/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6646 - accuracy: 0.9276
# Epoch 14: val_loss did not improve from 0.56497
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6647 - accuracy: 0.9275 - val_loss: 0.5706 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 15/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6611 - accuracy: 0.9288
# Epoch 15: val_loss did not improve from 0.56497
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6611 - accuracy: 0.9288 - val_loss: 0.5671 - val_accuracy: 0.9242 - lr: 0.0010
# Epoch 16/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6590 - accuracy: 0.9303
# Epoch 16: val_loss improved from 0.56497 to 0.56097, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6586 - accuracy: 0.9305 - val_loss: 0.5610 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 17/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6568 - accuracy: 0.9300
# Epoch 17: val_loss did not improve from 0.56097
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6570 - accuracy: 0.9300 - val_loss: 0.5643 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 18/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6549 - accuracy: 0.9319
# Epoch 18: val_loss did not improve from 0.56097
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6551 - accuracy: 0.9319 - val_loss: 0.5783 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 19/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6539 - accuracy: 0.9327
# Epoch 19: val_loss did not improve from 0.56097
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6538 - accuracy: 0.9325 - val_loss: 0.5652 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 20/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6524 - accuracy: 0.9331
# Epoch 20: val_loss improved from 0.56097 to 0.55750, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6525 - accuracy: 0.9328 - val_loss: 0.5575 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 21/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6508 - accuracy: 0.9332
# Epoch 21: val_loss improved from 0.55750 to 0.54837, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6509 - accuracy: 0.9332 - val_loss: 0.5484 - val_accuracy: 0.9354 - lr: 0.0010
# Epoch 22/100
# 535/545 [============================>.] - ETA: 0s - loss: 0.6511 - accuracy: 0.9347
# Epoch 22: val_loss did not improve from 0.54837
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6507 - accuracy: 0.9346 - val_loss: 0.5743 - val_accuracy: 0.9233 - lr: 0.0010
# Epoch 23/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6485 - accuracy: 0.9357
# Epoch 23: val_loss did not improve from 0.54837
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6487 - accuracy: 0.9356 - val_loss: 0.5560 - val_accuracy: 0.9360 - lr: 0.0010
# Epoch 24/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6460 - accuracy: 0.9375
# Epoch 24: val_loss did not improve from 0.54837
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6461 - accuracy: 0.9375 - val_loss: 0.5622 - val_accuracy: 0.9284 - lr: 0.0010
# Epoch 25/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6451 - accuracy: 0.9363
# Epoch 25: val_loss did not improve from 0.54837
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6455 - accuracy: 0.9362 - val_loss: 0.5576 - val_accuracy: 0.9302 - lr: 0.0010
# Epoch 26/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6451 - accuracy: 0.9374
# Epoch 26: val_loss improved from 0.54837 to 0.54295, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6449 - accuracy: 0.9373 - val_loss: 0.5430 - val_accuracy: 0.9369 - lr: 0.0010
# Epoch 27/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6427 - accuracy: 0.9383
# Epoch 27: val_loss did not improve from 0.54295
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6426 - accuracy: 0.9384 - val_loss: 0.5591 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 28/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6431 - accuracy: 0.9383
# Epoch 28: val_loss did not improve from 0.54295
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6431 - accuracy: 0.9383 - val_loss: 0.5503 - val_accuracy: 0.9336 - lr: 0.0010
# Epoch 29/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6425 - accuracy: 0.9388
# Epoch 29: val_loss did not improve from 0.54295
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6427 - accuracy: 0.9386 - val_loss: 0.5604 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 30/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6408 - accuracy: 0.9400
# Epoch 30: val_loss improved from 0.54295 to 0.54283, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/best_model_v28.keras
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6409 - accuracy: 0.9400 - val_loss: 0.5428 - val_accuracy: 0.9382 - lr: 0.0010
# Epoch 31/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6386 - accuracy: 0.9405
# Epoch 31: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6387 - accuracy: 0.9406 - val_loss: 0.5745 - val_accuracy: 0.9255 - lr: 0.0010
# Epoch 32/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6400 - accuracy: 0.9402
# Epoch 32: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6401 - accuracy: 0.9400 - val_loss: 0.5713 - val_accuracy: 0.9264 - lr: 0.0010
# Epoch 33/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.9403
# Epoch 33: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6388 - accuracy: 0.9402 - val_loss: 0.5744 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 34/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.9405
# Epoch 34: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6381 - accuracy: 0.9403 - val_loss: 0.5556 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 35/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6382 - accuracy: 0.9407
# Epoch 35: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6385 - accuracy: 0.9407 - val_loss: 0.5544 - val_accuracy: 0.9331 - lr: 0.0010
# Epoch 36/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6350 - accuracy: 0.9416
# Epoch 36: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6341 - accuracy: 0.9418 - val_loss: 0.5477 - val_accuracy: 0.9340 - lr: 5.0000e-04
# Epoch 37/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6330 - accuracy: 0.9433
# Epoch 37: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6332 - accuracy: 0.9432 - val_loss: 0.5500 - val_accuracy: 0.9336 - lr: 5.0000e-04
# Epoch 38/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6327 - accuracy: 0.9430
# Epoch 38: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6324 - accuracy: 0.9430 - val_loss: 0.5523 - val_accuracy: 0.9348 - lr: 5.0000e-04
# Epoch 39/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6310 - accuracy: 0.9453
# Epoch 39: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6312 - accuracy: 0.9452 - val_loss: 0.5551 - val_accuracy: 0.9331 - lr: 5.0000e-04
# Epoch 40/100
# 535/545 [============================>.] - ETA: 0s - loss: 0.6315 - accuracy: 0.9446
# Epoch 40: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6313 - accuracy: 0.9445 - val_loss: 0.5478 - val_accuracy: 0.9359 - lr: 5.0000e-04
# Epoch 41/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6303 - accuracy: 0.9447
# Epoch 41: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6303 - accuracy: 0.9446 - val_loss: 0.5485 - val_accuracy: 0.9342 - lr: 2.5000e-04
# Epoch 42/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6289 - accuracy: 0.9458
# Epoch 42: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6289 - accuracy: 0.9458 - val_loss: 0.5485 - val_accuracy: 0.9330 - lr: 2.5000e-04
# Epoch 43/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6290 - accuracy: 0.9458
# Epoch 43: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6294 - accuracy: 0.9458 - val_loss: 0.5514 - val_accuracy: 0.9331 - lr: 2.5000e-04
# Epoch 44/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6286 - accuracy: 0.9453
# Epoch 44: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6286 - accuracy: 0.9453 - val_loss: 0.5515 - val_accuracy: 0.9349 - lr: 2.5000e-04
# Epoch 45/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.9459
# Epoch 45: val_loss did not improve from 0.54283
# 545/545 [==============================] - 3s 5ms/step - loss: 0.6288 - accuracy: 0.9460 - val_loss: 0.5487 - val_accuracy: 0.9348 - lr: 2.5000e-04
# 24/24 [==============================] - 0s 3ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v28 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9589    0.9292    0.9438      1906
#          Run     0.9822    0.9650    0.9735      1085
#         Idle     0.8992    0.9268    0.9128      1982
#        Trans     0.7156    0.7610    0.7376       410
#         Fall     0.9906    0.9787    0.9846       750
#
#     accuracy                         0.9296      6133
#    macro avg     0.9093    0.9121    0.9104      6133
# weighted avg     0.9313    0.9296    0.9302      6133
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 734
#   - TỶ LỆ RECALL TÉ NGÃ: 97.87%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/report_v28.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
    'UNIDIRECTIONAL_SEQUENCE_LSTM':'AddUnidirectionalSequenceLSTM',
}
res_lines = []
for o in reg_ops:
    m = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m}();" if m else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp2thi_lk8/assets
# INFO:tensorflow:Assets written to: /tmp/tmp2thi_lk8/assets
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v28/model_v28_int8.tflite  (25080 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v28.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781774927.252133  794926 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781774927.252151  794926 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781774927.252413  794926 reader.cc:83] Reading SavedModel from: /tmp/tmp2thi_lk8
# I0000 00:00:1781774927.254966  794926 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781774927.254975  794926 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp2thi_lk8
# I0000 00:00:1781774927.263605  794926 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781774927.265771  794926 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781774927.296675  794926 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp2thi_lk8
# I0000 00:00:1781774927.313936  794926 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 61543 microseconds.
# I0000 00:00:1781774927.402205  794926 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781774927.492340  794926 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# W0000 00:00:1781774927.492360  794926 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
