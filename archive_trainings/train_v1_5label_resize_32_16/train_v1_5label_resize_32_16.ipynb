# %% [markdown]
# # Pipeline huấn luyện **v1 RESIZE (LSTM 32→16)** + Export INT8 cho ESP32-S3
#
# Kiến trúc CNN-LSTM thu nhỏ (LSTM 64→32 ⇒ 32→16 (thu nhỏ tiếp)).
# Toàn bộ notebook chạy **Keras 2 (legacy)** để LSTM fuse được khi convert TFLite.
#
# ## 1. Kết nối Google Drive, cài tf-keras & giải nén Dataset

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 2. Tiền xử lý (Extract & Preprocess - Step 1)
# Chuyển đổi gia tốc (g), góc quay (rad/s) và downsample 100Hz.

# %%
import glob
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm

INPUT_DIR  = Path(WORKSPACE) / 'SisFall_dataset'
OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Processed'

target_har = {'D01', 'D02', 'D03', 'D04', 'D05', 'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17', 'D18', 'D19'}
ACCEL_SCALE = 32.0 / 8192.0
GYRO_SCALE = (4000.0 / 65536.0) * (np.pi / 180.0)

all_files = list(INPUT_DIR.rglob('*.txt'))
files_to_process = [f for f in all_files if f.name.startswith('F') or f.name[:3] in target_har]

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

for file_path in tqdm(files_to_process, desc="Preprocessing"):
    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            lines = f.readlines()
            
        data = []
        for line in lines:
            line = line.strip().rstrip(';')
            if not line: continue
            parts = line.split(',')
            if len(parts) >= 6:
                data.append([float(x) for x in parts[:6]])
                
        if not data: continue
        df = pd.DataFrame(data, columns=['ax', 'ay', 'az', 'gx', 'gy', 'gz'])
        
        df[['ax', 'ay', 'az']] *= ACCEL_SCALE
        df[['gx', 'gy', 'gz']] *= GYRO_SCALE
        df = df.iloc[::2, :].reset_index(drop=True)
        
        rel_path = file_path.relative_to(INPUT_DIR)
        out_file = OUTPUT_DIR / rel_path.parent / (file_path.stem + '.csv')
        out_file.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(out_file, index=False)
    except Exception as e:
        pass
print("Hoàn tất Step 1!")
# Out:
# Preprocessing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Step 1!

# %% [markdown]
# # 3. Cắt Window (Windowing - Step 2) — bản chỉnh cho Trans/D18/D19
#
# - **D18 (vấp khi đi)** & **D19 (nhảy nhẹ)**: chỉ lấy **1 cửa sổ Trans** tại đỉnh SVM cao nhất; phần đi bộ còn lại **bỏ hết** (không Walk, không Idle).
# - **Trans augment ×3**: dịch trước/sau 20 mẫu — **chỉ cho subject TRAIN** (tránh thổi phồng Val/Test).
# - D01/D02/D05→Walk, D03/D04→Run (sliding window); D07…D17→Trans(≤2 đỉnh)+Idle.

# %%
from scipy.signal import find_peaks

WINDOW_OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Windowed_new'

# Chỉ AUGMENT Trans cho các subject thuộc tập TRAIN -> tránh rò rỉ/thổi phồng Val/Test.
TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
TRANS_AUG_SHIFTS = [-20, 0, 20]   # dịch trước/sau 20 mẫu -> x3 mẫu Trans

def extract_window(df, center, window_size=200):
    start, end = center - window_size // 2, center + window_size // 2
    if start < 0: start, end = 0, window_size
    if end > len(df): end, start = len(df), max(0, len(df) - window_size)
    return df.iloc[start:end]

def classify_idle(win_df):
    ax_m, ay_m, az_m = win_df['ax'].abs().mean(), win_df['ay'].abs().mean(), win_df['az'].abs().mean()
    return 'Idle_StandSit' if (ay_m > ax_m and ay_m > az_m) else 'Idle_Lie'

def save_trans(df, peak, out_dir, filename, subject_id, tag):
    # Lưu 1 cửa sổ Trans tại peak; augment x3 (dịch +-20) nếu subject thuộc TRAIN.
    shifts = TRANS_AUG_SHIFTS if subject_id in TRAIN_SUBJECTS else [0]
    n = 0
    for shift in shifts:
        win = extract_window(df, peak + shift)
        if len(win) == 200:
            win.to_csv(out_dir / f"{filename}_Trans_{tag}_s{shift:+d}.csv", index=False)
            n += 1
    return n

all_processed = list(OUTPUT_DIR.rglob('*.csv'))
trans_har    = {'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17'}  # ADL ngồi/đứng/nằm -> Trans + Idle
cont_har     = {'D01', 'D02', 'D03', 'D04', 'D05'}                # đi/chạy liên tục (KHÔNG còn D18/D19)
stumble_jump = {'D18', 'D19'}                                     # D18 vấp khi đi, D19 nhảy nhẹ

windows_generated = 0
for f in tqdm(all_processed, desc="Windowing"):
    df = pd.read_csv(f)
    if len(df) < 200: continue

    filename, prefix = f.stem, f.stem[:3]
    subject_id = filename.split('_')[1]
    out_dir = WINDOW_OUTPUT_DIR / f.parent.name
    out_dir.mkdir(parents=True, exist_ok=True)
    svm = np.sqrt(df['ax']**2 + df['ay']**2 + df['az']**2)

    if filename.startswith('F'):
        # Fall: 5 cửa sổ quanh đỉnh va chạm
        peak_idx = int(svm.argmax())
        for w_idx, shift in enumerate([-60, -30, 0, 30, 60]):
            win = extract_window(df, peak_idx + shift)
            if len(win) == 200:
                win.to_csv(out_dir / f"{filename}_Fall_W{w_idx:03d}.csv", index=False)
                windows_generated += 1

    elif prefix in stumble_jump:
        # D18 (vấp khi đi) / D19 (nhảy nhẹ): CHỈ 1 cửa sổ Trans tại đỉnh SVM cao nhất.
        # Phần còn lại (đi bộ) BỎ HẾT: không lấy Walk, không lấy Idle (Walk đã quá nhiều).
        peak_idx = int(svm.argmax())
        windows_generated += save_trans(df, peak_idx, out_dir, filename, subject_id, 'P000')

    elif prefix in trans_har:
        # ADL chuyển động: lấy tối đa 2 đỉnh SVM cao nhất làm Trans (mỗi đỉnh augment x3 nếu train)
        peaks, props = find_peaks(svm, height=1.0, distance=200)
        if len(peaks) >= 2:
            selected_peaks = np.sort(peaks[np.argsort(props['peak_heights'])[-2:]])
        elif len(peaks) == 1:
            selected_peaks = peaks
        else:
            selected_peaks = [int(svm.argmax())]

        for i, peak in enumerate(selected_peaks):
            windows_generated += save_trans(df, int(peak), out_dir, filename, subject_id, f'W{i:03d}')

        # Idle: các đoạn cách xa MỌI đỉnh >= 80 mẫu (không augment)
        for start in range(0, len(df) - 200 + 1, 100):
            center = start + 100
            if all(abs(center - p) >= 80 for p in selected_peaks):
                win = df.iloc[start:start+200]
                win.to_csv(out_dir / f"{filename}_{classify_idle(win)}_W{start//100:03d}.csv", index=False)
                windows_generated += 1

    elif prefix in cont_har:
        # Đi/chạy liên tục: sliding window step=100
        for start in range(0, len(df) - 200 + 1, 100):
            win = df.iloc[start:start+200]
            label = "Walk" if prefix in {'D01', 'D02', 'D05'} else "Run"
            win.to_csv(out_dir / f"{filename}_{label}_W{start//100:03d}.csv", index=False)
            windows_generated += 1

print(f"Hoàn tất Windowing! Tổng số cửa sổ: {windows_generated}")
# Out:
# Windowing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Windowing! Tổng số cửa sổ: 47506

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                X[:, :, 3:6] = X[:, :, 3:6] / 2000.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781763231.868529  429163 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — RESIZE (LSTM 32→16)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Dropout, Dense
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # Thí nghiệm A: thu nhỏ CẢ 2 lớp LSTM -> 32 -> 16
    inputs = Input(shape=input_shape)

    # CNN block (giữ nguyên)
    x = Conv1D(64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu', padding='same')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.3)(x)

    # LSTM block (THU NHỎ TIẾP: 32 -> 16)
    x = LSTM(32, return_sequences=True)(x)
    x = LSTM(16)(x)
    x = Dropout(0.4)(x)

    # Classification head
    x = Dense(32, activation='relu')(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_new'
        cache_dir = f'{WORKSPACE}/cache_resize_64_32'
        out_dir   = f'{WORKSPACE}/output_resize_32_16'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "resize_32_16"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()
X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 1.0, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 8365, 'Trans': 5706, 'Fall': 7125}
# E0000 00:00:1781763234.658111  429163 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I0000 00:00:1781763234.658150  429163 cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# I0000 00:00:1781763234.658159  429163 cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# I0000 00:00:1781763234.658170  429163 cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# I0000 00:00:1781763234.658173  429163 cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: quangnh
# I0000 00:00:1781763234.658177  429163 cuda_diagnostics.cc:183] hostname: quangnh
# I0000 00:00:1781763234.658309  429163 cuda_diagnostics.cc:190] libcuda reported version is: 550.54.15
# I0000 00:00:1781763234.658332  429163 cuda_diagnostics.cc:194] kernel reported version is: 550.54.15
# I0000 00:00:1781763234.658335  429163 cuda_diagnostics.cc:284] kernel version seems to match DSO: 550.54.15
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]          0
#
#  conv1d (Conv1D)             (None, 200, 64)           1216
#
#  conv1d_1 (Conv1D)           (None, 200, 64)           12352
#
#  max_pooling1d (MaxPooling1  (None, 100, 64)           0
#  D)
#
#  dropout (Dropout)           (None, 100, 64)           0
#
#  lstm (LSTM)                 (None, 100, 32)           12416
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 32)                544
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 29829 (116.52 KB)
# Trainable params: 29829 (116.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3577 - accuracy: 0.5377
# Epoch 1: val_loss improved from inf to 1.06606, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 47s 80ms/step - loss: 1.3577 - accuracy: 0.5377 - val_loss: 1.0661 - val_accuracy: 0.6712 - lr: 0.0010
# Epoch 2/100
# 545/545 [==============================] - ETA: 0s - loss: 1.1224 - accuracy: 0.7026
# Epoch 2: val_loss improved from 1.06606 to 0.84675, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 48s 88ms/step - loss: 1.1224 - accuracy: 0.7026 - val_loss: 0.8468 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 3/100
# 545/545 [==============================] - ETA: 0s - loss: 0.9913 - accuracy: 0.7966
# Epoch 3: val_loss improved from 0.84675 to 0.77731, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 44s 80ms/step - loss: 0.9913 - accuracy: 0.7966 - val_loss: 0.7773 - val_accuracy: 0.8377 - lr: 0.0010
# Epoch 4/100
# 545/545 [==============================] - ETA: 0s - loss: 0.9182 - accuracy: 0.8364
# Epoch 4: val_loss improved from 0.77731 to 0.71299, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 39s 71ms/step - loss: 0.9182 - accuracy: 0.8364 - val_loss: 0.7130 - val_accuracy: 0.8601 - lr: 0.0010
# Epoch 5/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.8722 - accuracy: 0.8625
# Epoch 5: val_loss improved from 0.71299 to 0.66956, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 37s 68ms/step - loss: 0.8723 - accuracy: 0.8625 - val_loss: 0.6696 - val_accuracy: 0.8788 - lr: 0.0010
# Epoch 6/100
# 545/545 [==============================] - ETA: 0s - loss: 0.8279 - accuracy: 0.8819
# Epoch 6: val_loss did not improve from 0.66956
# 545/545 [==============================] - 37s 68ms/step - loss: 0.8279 - accuracy: 0.8819 - val_loss: 0.6774 - val_accuracy: 0.8763 - lr: 0.0010
# Epoch 7/100
# 545/545 [==============================] - ETA: 0s - loss: 0.8047 - accuracy: 0.8952
# Epoch 7: val_loss improved from 0.66956 to 0.65043, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 40s 73ms/step - loss: 0.8047 - accuracy: 0.8952 - val_loss: 0.6504 - val_accuracy: 0.8873 - lr: 0.0010
# Epoch 8/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7919 - accuracy: 0.8994
# Epoch 8: val_loss improved from 0.65043 to 0.64592, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 44s 81ms/step - loss: 0.7919 - accuracy: 0.8994 - val_loss: 0.6459 - val_accuracy: 0.8915 - lr: 0.0010
# Epoch 9/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7823 - accuracy: 0.9046
# Epoch 9: val_loss did not improve from 0.64592
# 545/545 [==============================] - 47s 87ms/step - loss: 0.7823 - accuracy: 0.9046 - val_loss: 0.6476 - val_accuracy: 0.8999 - lr: 0.0010
# Epoch 10/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7691 - accuracy: 0.9080
# Epoch 10: val_loss improved from 0.64592 to 0.63673, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 45s 83ms/step - loss: 0.7691 - accuracy: 0.9080 - val_loss: 0.6367 - val_accuracy: 0.8973 - lr: 0.0010
# Epoch 11/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7601 - accuracy: 0.9119
# Epoch 11: val_loss did not improve from 0.63673
# 545/545 [==============================] - 41s 76ms/step - loss: 0.7601 - accuracy: 0.9119 - val_loss: 0.6380 - val_accuracy: 0.8970 - lr: 0.0010
# Epoch 12/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7466 - accuracy: 0.9175
# Epoch 12: val_loss improved from 0.63673 to 0.61366, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 42s 76ms/step - loss: 0.7466 - accuracy: 0.9175 - val_loss: 0.6137 - val_accuracy: 0.9065 - lr: 0.0010
# Epoch 13/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.9153
# Epoch 13: val_loss did not improve from 0.61366
# 545/545 [==============================] - 40s 74ms/step - loss: 0.7535 - accuracy: 0.9153 - val_loss: 0.6173 - val_accuracy: 0.9033 - lr: 0.0010
# Epoch 14/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7453 - accuracy: 0.9194
# Epoch 14: val_loss improved from 0.61366 to 0.59265, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 37s 69ms/step - loss: 0.7453 - accuracy: 0.9194 - val_loss: 0.5926 - val_accuracy: 0.9229 - lr: 0.0010
# Epoch 15/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.9242
# Epoch 15: val_loss did not improve from 0.59265
# 545/545 [==============================] - 41s 75ms/step - loss: 0.7350 - accuracy: 0.9242 - val_loss: 0.6018 - val_accuracy: 0.9201 - lr: 0.0010
# Epoch 16/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7270 - accuracy: 0.9282
# Epoch 16: val_loss did not improve from 0.59265
# 545/545 [==============================] - 41s 75ms/step - loss: 0.7270 - accuracy: 0.9282 - val_loss: 0.6067 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 17/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7244 - accuracy: 0.9293
# Epoch 17: val_loss did not improve from 0.59265
# 545/545 [==============================] - 37s 68ms/step - loss: 0.7244 - accuracy: 0.9293 - val_loss: 0.6033 - val_accuracy: 0.9184 - lr: 0.0010
# Epoch 18/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.9319
# Epoch 18: val_loss improved from 0.59265 to 0.59118, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 37s 67ms/step - loss: 0.7186 - accuracy: 0.9319 - val_loss: 0.5912 - val_accuracy: 0.9212 - lr: 0.0010
# Epoch 19/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7128 - accuracy: 0.9335
# Epoch 19: val_loss improved from 0.59118 to 0.57566, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 40s 74ms/step - loss: 0.7127 - accuracy: 0.9335 - val_loss: 0.5757 - val_accuracy: 0.9305 - lr: 0.0010
# Epoch 20/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7151 - accuracy: 0.9319
# Epoch 20: val_loss did not improve from 0.57566
# 545/545 [==============================] - 42s 76ms/step - loss: 0.7151 - accuracy: 0.9319 - val_loss: 0.6012 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 21/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.9352
# Epoch 21: val_loss improved from 0.57566 to 0.57308, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 43s 78ms/step - loss: 0.7071 - accuracy: 0.9352 - val_loss: 0.5731 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 22/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7109 - accuracy: 0.9348
# Epoch 22: val_loss improved from 0.57308 to 0.57203, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 43s 78ms/step - loss: 0.7109 - accuracy: 0.9348 - val_loss: 0.5720 - val_accuracy: 0.9313 - lr: 0.0010
# Epoch 23/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7019 - accuracy: 0.9375
# Epoch 23: val_loss did not improve from 0.57203
# 545/545 [==============================] - 44s 81ms/step - loss: 0.7019 - accuracy: 0.9375 - val_loss: 0.5771 - val_accuracy: 0.9311 - lr: 0.0010
# Epoch 24/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7026 - accuracy: 0.9366
# Epoch 24: val_loss did not improve from 0.57203
# 545/545 [==============================] - 40s 74ms/step - loss: 0.7025 - accuracy: 0.9366 - val_loss: 0.5877 - val_accuracy: 0.9253 - lr: 0.0010
# Epoch 25/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7036 - accuracy: 0.9361
# Epoch 25: val_loss did not improve from 0.57203
# 545/545 [==============================] - 42s 76ms/step - loss: 0.7038 - accuracy: 0.9361 - val_loss: 0.5894 - val_accuracy: 0.9288 - lr: 0.0010
# Epoch 26/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6951 - accuracy: 0.9391
# Epoch 26: val_loss improved from 0.57203 to 0.56529, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 35s 65ms/step - loss: 0.6952 - accuracy: 0.9390 - val_loss: 0.5653 - val_accuracy: 0.9357 - lr: 0.0010
# Epoch 27/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7173 - accuracy: 0.9294
# Epoch 27: val_loss did not improve from 0.56529
# 545/545 [==============================] - 36s 67ms/step - loss: 0.7173 - accuracy: 0.9294 - val_loss: 0.6040 - val_accuracy: 0.9229 - lr: 0.0010
# Epoch 28/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.9388
# Epoch 28: val_loss improved from 0.56529 to 0.56080, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 37s 68ms/step - loss: 0.6941 - accuracy: 0.9388 - val_loss: 0.5608 - val_accuracy: 0.9383 - lr: 0.0010
# Epoch 29/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.9410
# Epoch 29: val_loss did not improve from 0.56080
# 545/545 [==============================] - 40s 73ms/step - loss: 0.6885 - accuracy: 0.9410 - val_loss: 0.5724 - val_accuracy: 0.9322 - lr: 0.0010
# Epoch 30/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.9401
# Epoch 30: val_loss did not improve from 0.56080
# 545/545 [==============================] - 40s 74ms/step - loss: 0.6915 - accuracy: 0.9401 - val_loss: 0.5786 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 31/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.9418
# Epoch 31: val_loss did not improve from 0.56080
# 545/545 [==============================] - 44s 80ms/step - loss: 0.6875 - accuracy: 0.9418 - val_loss: 0.5737 - val_accuracy: 0.9314 - lr: 0.0010
# Epoch 32/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.9411
# Epoch 32: val_loss did not improve from 0.56080
# 545/545 [==============================] - 40s 74ms/step - loss: 0.6899 - accuracy: 0.9411 - val_loss: 0.5821 - val_accuracy: 0.9328 - lr: 0.0010
# Epoch 33/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6877 - accuracy: 0.9412
# Epoch 33: val_loss did not improve from 0.56080
# 545/545 [==============================] - 37s 67ms/step - loss: 0.6877 - accuracy: 0.9412 - val_loss: 0.5667 - val_accuracy: 0.9348 - lr: 0.0010
# Epoch 34/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6773 - accuracy: 0.9453
# Epoch 34: val_loss did not improve from 0.56080
# 545/545 [==============================] - 41s 75ms/step - loss: 0.6773 - accuracy: 0.9453 - val_loss: 0.5717 - val_accuracy: 0.9354 - lr: 5.0000e-04
# Epoch 35/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.9464
# Epoch 35: val_loss improved from 0.56080 to 0.55889, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/best_model_resize_32_16.keras
# 545/545 [==============================] - 37s 67ms/step - loss: 0.6744 - accuracy: 0.9464 - val_loss: 0.5589 - val_accuracy: 0.9382 - lr: 5.0000e-04
# Epoch 36/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6742 - accuracy: 0.9453
# Epoch 36: val_loss did not improve from 0.55889
# 545/545 [==============================] - 36s 66ms/step - loss: 0.6742 - accuracy: 0.9453 - val_loss: 0.5652 - val_accuracy: 0.9331 - lr: 5.0000e-04
# Epoch 37/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.9460
# Epoch 37: val_loss did not improve from 0.55889
# 545/545 [==============================] - 36s 66ms/step - loss: 0.6757 - accuracy: 0.9460 - val_loss: 0.5710 - val_accuracy: 0.9334 - lr: 5.0000e-04
# Epoch 38/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.9474
# Epoch 38: val_loss did not improve from 0.55889
# 545/545 [==============================] - 36s 66ms/step - loss: 0.6719 - accuracy: 0.9473 - val_loss: 0.5755 - val_accuracy: 0.9325 - lr: 5.0000e-04
# Epoch 39/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.9468
# Epoch 39: val_loss did not improve from 0.55889
# 545/545 [==============================] - 39s 71ms/step - loss: 0.6733 - accuracy: 0.9468 - val_loss: 0.5757 - val_accuracy: 0.9331 - lr: 5.0000e-04
# Epoch 40/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.9488
# Epoch 40: val_loss did not improve from 0.55889
# 545/545 [==============================] - 42s 77ms/step - loss: 0.6707 - accuracy: 0.9488 - val_loss: 0.5767 - val_accuracy: 0.9371 - lr: 5.0000e-04
# Epoch 41/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6641 - accuracy: 0.9501
# Epoch 41: val_loss did not improve from 0.55889
# 545/545 [==============================] - 42s 78ms/step - loss: 0.6641 - accuracy: 0.9501 - val_loss: 0.5692 - val_accuracy: 0.9363 - lr: 2.5000e-04
# Epoch 42/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6635 - accuracy: 0.9503
# Epoch 42: val_loss did not improve from 0.55889
# 545/545 [==============================] - 40s 73ms/step - loss: 0.6635 - accuracy: 0.9503 - val_loss: 0.5714 - val_accuracy: 0.9357 - lr: 2.5000e-04
# Epoch 43/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6638 - accuracy: 0.9503
# Epoch 43: val_loss did not improve from 0.55889
# 545/545 [==============================] - 36s 66ms/step - loss: 0.6638 - accuracy: 0.9503 - val_loss: 0.5613 - val_accuracy: 0.9391 - lr: 2.5000e-04
# Epoch 44/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.9503
# Epoch 44: val_loss did not improve from 0.55889
# 545/545 [==============================] - 40s 73ms/step - loss: 0.6625 - accuracy: 0.9503 - val_loss: 0.5734 - val_accuracy: 0.9348 - lr: 2.5000e-04
# Epoch 45/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6630 - accuracy: 0.9504
# Epoch 45: val_loss did not improve from 0.55889
# 545/545 [==============================] - 42s 78ms/step - loss: 0.6630 - accuracy: 0.9504 - val_loss: 0.5749 - val_accuracy: 0.9346 - lr: 2.5000e-04
# Epoch 46/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6576 - accuracy: 0.9521
# Epoch 46: val_loss did not improve from 0.55889
# 545/545 [==============================] - 42s 77ms/step - loss: 0.6576 - accuracy: 0.9521 - val_loss: 0.5610 - val_accuracy: 0.9394 - lr: 1.2500e-04
# Epoch 47/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.9523
# Epoch 47: val_loss did not improve from 0.55889
# 545/545 [==============================] - 41s 76ms/step - loss: 0.6572 - accuracy: 0.9523 - val_loss: 0.5680 - val_accuracy: 0.9362 - lr: 1.2500e-04
# Epoch 48/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6562 - accuracy: 0.9530
# Epoch 48: val_loss did not improve from 0.55889
# 545/545 [==============================] - 40s 72ms/step - loss: 0.6562 - accuracy: 0.9530 - val_loss: 0.5649 - val_accuracy: 0.9382 - lr: 1.2500e-04
# Epoch 49/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6570 - accuracy: 0.9527
# Epoch 49: val_loss did not improve from 0.55889
# 545/545 [==============================] - 37s 67ms/step - loss: 0.6570 - accuracy: 0.9527 - val_loss: 0.5640 - val_accuracy: 0.9377 - lr: 1.2500e-04
# Epoch 50/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6573 - accuracy: 0.9511
# Epoch 50: val_loss did not improve from 0.55889
# 545/545 [==============================] - 36s 66ms/step - loss: 0.6573 - accuracy: 0.9511 - val_loss: 0.5648 - val_accuracy: 0.9351 - lr: 1.2500e-04
# 24/24 [==============================] - 2s 42ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - resize_32_16 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9747    0.9082    0.9402      1906
#          Run     0.9725    0.9779    0.9752      1085
#         Idle     0.9058    0.9223    0.9140      1982
#        Trans     0.6780    0.8732    0.7633       410
#         Fall     0.9986    0.9587    0.9782       750
#
#     accuracy                         0.9289      6133
#    macro avg     0.9059    0.9280    0.9142      6133
# weighted avg     0.9351    0.9289    0.9308      6133
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 719
#   - TỶ LỆ RECALL TÉ NGÃ: 95.87%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/report_resize_32_16.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
# Notebook dang chay Keras 2 (legacy) nen LSTM fuse thang thanh UNIDIRECTIONAL_SEQUENCE_LSTM.
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

# Clone sang batch co dinh = 1 de chac chan LSTM fuse khi convert.
static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

# --- Doc metadata that tu interpreter ---
it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','FULLY_CONNECTED':'AddFullyConnected','SOFTMAX':'AddSoftmax',
    'LOGISTIC':'AddLogistic','TANH':'AddTanh','RELU':'AddRelu','RESHAPE':'AddReshape',
    'UNIDIRECTIONAL_SEQUENCE_LSTM':'AddUnidirectionalSequenceLSTM','QUANTIZE':'AddQuantize',
    'DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice','CONCATENATION':'AddConcatenation',
    'ADD':'AddAdd','MUL':'AddMul','PACK':'AddPack','UNPACK':'AddUnpack','SHAPE':'AddShape',
    'FILL':'AddFill','GATHER':'AddGather','SLICE':'AddSlice','SPLIT':'AddSplit','TRANSPOSE':'AddTranspose',
    'MEAN':'AddMean','PAD':'AddPad','EXPAND_DIMS':'AddExpandDims','SQUEEZE':'AddSqueeze',
}
res_lines = []
for o in reg_ops:
    m = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m}();" if m else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    "// Sinh tu notebook (KHONG sua tay).\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

# C array (12 byte/dong)
body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h (co nhung ops + quant + goi y resolver)")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmppxyx0inu/assets
# INFO:tensorflow:Assets written to: /tmp/tmppxyx0inu/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781765255.196146  429163 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781765255.196168  429163 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781765255.196481  429163 reader.cc:83] Reading SavedModel from: /tmp/tmppxyx0inu
# I0000 00:00:1781765255.211101  429163 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781765255.211121  429163 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmppxyx0inu
# I0000 00:00:1781765255.277437  429163 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781765255.310924  429163 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781765255.410278  429163 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmppxyx0inu
# I0000 00:00:1781765255.491217  429163 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 294749 microseconds.
# I0000 00:00:1781765255.731185  429163 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781765255.938883  429163 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.416 M  ops, equivalently 2.708 M  MACs
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_resize_32_16/model_resize_32_16_int8.tflite  (44344 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'RESHAPE', 'SOFTMAX', 'STRIDED_SLICE', 'UNIDIRECTIONAL_SEQUENCE_LSTM']
# [*] Da sinh model_data_resize_32_16.cc / .h (co nhung ops + quant + goi y resolver)
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781765256.375461  429163 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.416 M  ops, equivalently 2.708 M  MACs
# W0000 00:00:1781765256.375479  429163 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
