# %% [markdown]
# # v22_optimize — TCN tối ưu ESP-NN (bỏ dilation, separable k3, relu6, bỏ SE)
#
# Giữ cấu trúc residual của v22 nhưng sửa hết chỗ làm chậm trên ESP32-S3.
#
# **Dùng lại `cache_resize_64_32` có sẵn — KHÔNG tiền xử lý / windowing lại.**

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' 
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                X[:, :, 3:6] = X[:, :, 3:6] / 2000.0
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781769332.795322  636125 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Kiến trúc — v22_optimize (residual TCN, ESP-NN friendly)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     Add, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D,
                                     Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # v22_optimize - giu CAU TRUC RESIDUAL cua v22 nhung sua het cho ESP-NN dap phanh:
    #   BO dilation (dilation>1 roi ve reference) -> dung dilation=1
    #   Conv thuong k7 -> SeparableConv k3 (depthwise 6.3x + pointwise 14.2x)
    #   relu -> relu6 (11.48x) | BO SE block (sigmoid khong tang toc)
    #   Receptive field lay tu MaxPool downsample (thay cho dilation)
    inputs = Input(shape=input_shape)
    x = BatchNormalization()(inputs)
    x = Conv1D(32, 3, padding='same', use_bias=False)(x)     # project -> 32 ch
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    for stack in range(2):                                   # 2 stack giong v22
        for i in range(4):                                   # 4 block residual / stack
            residual = x
            y = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
            y = BatchNormalization()(y); y = Activation('relu6')(y)
            y = SeparableConv1D(32, 3, padding='same', use_bias=False)(y)
            y = BatchNormalization()(y)
            x = Add()([y, residual])                         # residual (Add 3.78x)
            x = Activation('relu6')(x)
        x = MaxPooling1D(2)(x)                               # downsample -> receptive field

    gap = GlobalAveragePooling1D()(x)
    gmp = GlobalMaxPooling1D()(x)
    x = Concatenate()([gap, gmp])                            # dual pooling giong v22
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_new'
        cache_dir = f'{WORKSPACE}/cache_resize_64_32'
        out_dir   = f'{WORKSPACE}/output_v22_optimize'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v22_optimize"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()
X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 1.0, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Load data từ Cache...
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 8365, 'Trans': 5706, 'Fall': 7125}
# E0000 00:00:1781769334.978822  636125 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I0000 00:00:1781769334.978867  636125 cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# I0000 00:00:1781769334.978878  636125 cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# I0000 00:00:1781769334.978892  636125 cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# I0000 00:00:1781769334.978894  636125 cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: quangnh
# I0000 00:00:1781769334.978899  636125 cuda_diagnostics.cc:183] hostname: quangnh
# I0000 00:00:1781769334.979053  636125 cuda_diagnostics.cc:190] libcuda reported version is: 550.54.15
# I0000 00:00:1781769334.979080  636125 cuda_diagnostics.cc:194] kernel reported version is: 550.54.15
# I0000 00:00:1781769334.979085  636125 cuda_diagnostics.cc:284] kernel version seems to match DSO: 550.54.15
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]             0         []
#
#  batch_normalization (Batch  (None, 200, 6)               24        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 200, 32)              576       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 200, 32)              128       ['conv1d[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 200, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  separable_conv1d (Separabl  (None, 200, 32)              1120      ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_2 (Bat  (None, 200, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 200, 32)              0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv1d_1 (Separa  (None, 200, 32)              1120      ['activation_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 200, 32)              128       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 200, 32)              0         ['batch_normalization_3[0][0]'
#                                                                     , 'activation[0][0]']
#
#  activation_2 (Activation)   (None, 200, 32)              0         ['add[0][0]']
#
#  separable_conv1d_2 (Separa  (None, 200, 32)              1120      ['activation_2[0][0]']
#  bleConv1D)
#
#  batch_normalization_4 (Bat  (None, 200, 32)              128       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 200, 32)              0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  separable_conv1d_3 (Separa  (None, 200, 32)              1120      ['activation_3[0][0]']
#  bleConv1D)
#
#  batch_normalization_5 (Bat  (None, 200, 32)              128       ['separable_conv1d_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 200, 32)              0         ['batch_normalization_5[0][0]'
#                                                                     , 'activation_2[0][0]']
#
#  activation_4 (Activation)   (None, 200, 32)              0         ['add_1[0][0]']
#
#  separable_conv1d_4 (Separa  (None, 200, 32)              1120      ['activation_4[0][0]']
#  bleConv1D)
#
#  batch_normalization_6 (Bat  (None, 200, 32)              128       ['separable_conv1d_4[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 200, 32)              0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  separable_conv1d_5 (Separa  (None, 200, 32)              1120      ['activation_5[0][0]']
#  bleConv1D)
#
#  batch_normalization_7 (Bat  (None, 200, 32)              128       ['separable_conv1d_5[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 200, 32)              0         ['batch_normalization_7[0][0]'
#                                                                     , 'activation_4[0][0]']
#
#  activation_6 (Activation)   (None, 200, 32)              0         ['add_2[0][0]']
#
#  separable_conv1d_6 (Separa  (None, 200, 32)              1120      ['activation_6[0][0]']
#  bleConv1D)
#
#  batch_normalization_8 (Bat  (None, 200, 32)              128       ['separable_conv1d_6[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 200, 32)              0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv1d_7 (Separa  (None, 200, 32)              1120      ['activation_7[0][0]']
#  bleConv1D)
#
#  batch_normalization_9 (Bat  (None, 200, 32)              128       ['separable_conv1d_7[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 200, 32)              0         ['batch_normalization_9[0][0]'
#                                                                     , 'activation_6[0][0]']
#
#  activation_8 (Activation)   (None, 200, 32)              0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 100, 32)              0         ['activation_8[0][0]']
#  D)
#
#  separable_conv1d_8 (Separa  (None, 100, 32)              1120      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_10 (Ba  (None, 100, 32)              128       ['separable_conv1d_8[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 100, 32)              0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  separable_conv1d_9 (Separa  (None, 100, 32)              1120      ['activation_9[0][0]']
#  bleConv1D)
#
#  batch_normalization_11 (Ba  (None, 100, 32)              128       ['separable_conv1d_9[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 100, 32)              0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'max_pooling1d[0][0]']
#
#  activation_10 (Activation)  (None, 100, 32)              0         ['add_4[0][0]']
#
#  separable_conv1d_10 (Separ  (None, 100, 32)              1120      ['activation_10[0][0]']
#  ableConv1D)
#
#  batch_normalization_12 (Ba  (None, 100, 32)              128       ['separable_conv1d_10[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 100, 32)              0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  separable_conv1d_11 (Separ  (None, 100, 32)              1120      ['activation_11[0][0]']
#  ableConv1D)
#
#  batch_normalization_13 (Ba  (None, 100, 32)              128       ['separable_conv1d_11[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 100, 32)              0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  activation_12 (Activation)  (None, 100, 32)              0         ['add_5[0][0]']
#
#  separable_conv1d_12 (Separ  (None, 100, 32)              1120      ['activation_12[0][0]']
#  ableConv1D)
#
#  batch_normalization_14 (Ba  (None, 100, 32)              128       ['separable_conv1d_12[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 100, 32)              0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  separable_conv1d_13 (Separ  (None, 100, 32)              1120      ['activation_13[0][0]']
#  ableConv1D)
#
#  batch_normalization_15 (Ba  (None, 100, 32)              128       ['separable_conv1d_13[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 100, 32)              0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'activation_12[0][0]']
#
#  activation_14 (Activation)  (None, 100, 32)              0         ['add_6[0][0]']
#
#  separable_conv1d_14 (Separ  (None, 100, 32)              1120      ['activation_14[0][0]']
#  ableConv1D)
#
#  batch_normalization_16 (Ba  (None, 100, 32)              128       ['separable_conv1d_14[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 100, 32)              0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  separable_conv1d_15 (Separ  (None, 100, 32)              1120      ['activation_15[0][0]']
#  ableConv1D)
#
#  batch_normalization_17 (Ba  (None, 100, 32)              128       ['separable_conv1d_15[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 100, 32)              0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'activation_14[0][0]']
#
#  activation_16 (Activation)  (None, 100, 32)              0         ['add_7[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 50, 32)               0         ['activation_16[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 32)                   0         ['max_pooling1d_1[0][0]']
#  GlobalAveragePooling1D)
#
#  global_max_pooling1d (Glob  (None, 32)                   0         ['max_pooling1d_1[0][0]']
#  alMaxPooling1D)
#
#  concatenate (Concatenate)   (None, 64)                   0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'global_max_pooling1d[0][0]']
#
#  dropout (Dropout)           (None, 64)                   0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 5)                    325       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 21021 (82.11 KB)
# Trainable params: 19921 (77.82 KB)
# Non-trainable params: 1100 (4.30 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.6804 - accuracy: 0.7130
# Epoch 1: val_loss improved from inf to 0.90131, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 33s 52ms/step - loss: 1.6799 - accuracy: 0.7131 - val_loss: 0.9013 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 2/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.9778 - accuracy: 0.8388
# Epoch 2: val_loss improved from 0.90131 to 0.69605, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 28s 52ms/step - loss: 0.9779 - accuracy: 0.8387 - val_loss: 0.6961 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 3/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.8918 - accuracy: 0.8681
# Epoch 3: val_loss improved from 0.69605 to 0.66019, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 33s 60ms/step - loss: 0.8919 - accuracy: 0.8681 - val_loss: 0.6602 - val_accuracy: 0.8866 - lr: 0.0010
# Epoch 4/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.8585 - accuracy: 0.8807
# Epoch 4: val_loss did not improve from 0.66019
# 545/545 [==============================] - 30s 56ms/step - loss: 0.8585 - accuracy: 0.8806 - val_loss: 0.6838 - val_accuracy: 0.8779 - lr: 0.0010
# Epoch 5/100
# 545/545 [==============================] - ETA: 0s - loss: 0.8327 - accuracy: 0.8903
# Epoch 5: val_loss did not improve from 0.66019
# 545/545 [==============================] - 29s 53ms/step - loss: 0.8327 - accuracy: 0.8903 - val_loss: 0.6753 - val_accuracy: 0.8782 - lr: 0.0010
# Epoch 6/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.8179 - accuracy: 0.8946
# Epoch 6: val_loss improved from 0.66019 to 0.64239, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 27s 50ms/step - loss: 0.8182 - accuracy: 0.8944 - val_loss: 0.6424 - val_accuracy: 0.8961 - lr: 0.0010
# Epoch 7/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.8074 - accuracy: 0.8982
# Epoch 7: val_loss improved from 0.64239 to 0.61503, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 28s 52ms/step - loss: 0.8073 - accuracy: 0.8982 - val_loss: 0.6150 - val_accuracy: 0.9154 - lr: 0.0010
# Epoch 8/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7950 - accuracy: 0.9041
# Epoch 8: val_loss did not improve from 0.61503
# 545/545 [==============================] - 28s 51ms/step - loss: 0.7950 - accuracy: 0.9041 - val_loss: 0.6564 - val_accuracy: 0.8870 - lr: 0.0010
# Epoch 9/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7850 - accuracy: 0.9075
# Epoch 9: val_loss improved from 0.61503 to 0.61271, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 29s 54ms/step - loss: 0.7851 - accuracy: 0.9075 - val_loss: 0.6127 - val_accuracy: 0.9071 - lr: 0.0010
# Epoch 10/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7807 - accuracy: 0.9106
# Epoch 10: val_loss did not improve from 0.61271
# 545/545 [==============================] - 26s 48ms/step - loss: 0.7807 - accuracy: 0.9106 - val_loss: 0.6483 - val_accuracy: 0.8895 - lr: 0.0010
# Epoch 11/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7731 - accuracy: 0.9145
# Epoch 11: val_loss did not improve from 0.61271
# 545/545 [==============================] - 27s 50ms/step - loss: 0.7731 - accuracy: 0.9145 - val_loss: 0.6275 - val_accuracy: 0.8985 - lr: 0.0010
# Epoch 12/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7657 - accuracy: 0.9155
# Epoch 12: val_loss improved from 0.61271 to 0.60494, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 26s 49ms/step - loss: 0.7656 - accuracy: 0.9155 - val_loss: 0.6049 - val_accuracy: 0.9109 - lr: 0.0010
# Epoch 13/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7605 - accuracy: 0.9173
# Epoch 13: val_loss did not improve from 0.60494
# 545/545 [==============================] - 27s 49ms/step - loss: 0.7604 - accuracy: 0.9173 - val_loss: 0.6178 - val_accuracy: 0.8967 - lr: 0.0010
# Epoch 14/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7564 - accuracy: 0.9193
# Epoch 14: val_loss did not improve from 0.60494
# 545/545 [==============================] - 29s 53ms/step - loss: 0.7564 - accuracy: 0.9193 - val_loss: 0.6162 - val_accuracy: 0.9092 - lr: 0.0010
# Epoch 15/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7523 - accuracy: 0.9218
# Epoch 15: val_loss did not improve from 0.60494
# 545/545 [==============================] - 29s 52ms/step - loss: 0.7523 - accuracy: 0.9218 - val_loss: 0.6744 - val_accuracy: 0.8694 - lr: 0.0010
# Epoch 16/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7481 - accuracy: 0.9228
# Epoch 16: val_loss did not improve from 0.60494
# 545/545 [==============================] - 27s 49ms/step - loss: 0.7481 - accuracy: 0.9228 - val_loss: 0.6172 - val_accuracy: 0.8997 - lr: 0.0010
# Epoch 17/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.9256
# Epoch 17: val_loss did not improve from 0.60494
# 545/545 [==============================] - 28s 51ms/step - loss: 0.7437 - accuracy: 0.9256 - val_loss: 0.6055 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 18/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7351 - accuracy: 0.9282
# Epoch 18: val_loss improved from 0.60494 to 0.59418, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 28s 52ms/step - loss: 0.7351 - accuracy: 0.9282 - val_loss: 0.5942 - val_accuracy: 0.9106 - lr: 5.0000e-04
# Epoch 19/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7288 - accuracy: 0.9308
# Epoch 19: val_loss improved from 0.59418 to 0.58357, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/best_model_v22_optimize.keras
# 545/545 [==============================] - 32s 58ms/step - loss: 0.7288 - accuracy: 0.9308 - val_loss: 0.5836 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 20/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7278 - accuracy: 0.9301
# Epoch 20: val_loss did not improve from 0.58357
# 545/545 [==============================] - 26s 47ms/step - loss: 0.7278 - accuracy: 0.9302 - val_loss: 0.5933 - val_accuracy: 0.9071 - lr: 5.0000e-04
# Epoch 21/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7251 - accuracy: 0.9328
# Epoch 21: val_loss did not improve from 0.58357
# 545/545 [==============================] - 27s 50ms/step - loss: 0.7251 - accuracy: 0.9328 - val_loss: 0.5839 - val_accuracy: 0.9163 - lr: 5.0000e-04
# Epoch 22/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7235 - accuracy: 0.9335
# Epoch 22: val_loss did not improve from 0.58357
# 545/545 [==============================] - 27s 49ms/step - loss: 0.7235 - accuracy: 0.9335 - val_loss: 0.6225 - val_accuracy: 0.9045 - lr: 5.0000e-04
# Epoch 23/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7227 - accuracy: 0.9328
# Epoch 23: val_loss did not improve from 0.58357
# 545/545 [==============================] - 28s 52ms/step - loss: 0.7226 - accuracy: 0.9328 - val_loss: 0.5956 - val_accuracy: 0.9132 - lr: 5.0000e-04
# Epoch 24/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.9350
# Epoch 24: val_loss did not improve from 0.58357
# 545/545 [==============================] - 27s 49ms/step - loss: 0.7209 - accuracy: 0.9350 - val_loss: 0.6033 - val_accuracy: 0.9092 - lr: 5.0000e-04
# Epoch 25/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7141 - accuracy: 0.9362
# Epoch 25: val_loss did not improve from 0.58357
# 545/545 [==============================] - 26s 49ms/step - loss: 0.7141 - accuracy: 0.9362 - val_loss: 0.5881 - val_accuracy: 0.9131 - lr: 2.5000e-04
# Epoch 26/100
# 545/545 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.9375
# Epoch 26: val_loss did not improve from 0.58357
# 545/545 [==============================] - 23s 43ms/step - loss: 0.7121 - accuracy: 0.9375 - val_loss: 0.5968 - val_accuracy: 0.9094 - lr: 2.5000e-04
# Epoch 27/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.9382
# Epoch 27: val_loss did not improve from 0.58357
# 545/545 [==============================] - 25s 46ms/step - loss: 0.7117 - accuracy: 0.9381 - val_loss: 0.5929 - val_accuracy: 0.9120 - lr: 2.5000e-04
# Epoch 28/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.9381
# Epoch 28: val_loss did not improve from 0.58357
# 545/545 [==============================] - 33s 60ms/step - loss: 0.7097 - accuracy: 0.9381 - val_loss: 0.5960 - val_accuracy: 0.9091 - lr: 2.5000e-04
# Epoch 29/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.9388
# Epoch 29: val_loss did not improve from 0.58357
# 545/545 [==============================] - 39s 71ms/step - loss: 0.7094 - accuracy: 0.9388 - val_loss: 0.5905 - val_accuracy: 0.9134 - lr: 2.5000e-04
# Epoch 30/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.9416
# Epoch 30: val_loss did not improve from 0.58357
# 545/545 [==============================] - 37s 68ms/step - loss: 0.7051 - accuracy: 0.9416 - val_loss: 0.5847 - val_accuracy: 0.9169 - lr: 1.2500e-04
# Epoch 31/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7035 - accuracy: 0.9406
# Epoch 31: val_loss did not improve from 0.58357
# 545/545 [==============================] - 38s 70ms/step - loss: 0.7036 - accuracy: 0.9406 - val_loss: 0.5973 - val_accuracy: 0.9106 - lr: 1.2500e-04
# Epoch 32/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7032 - accuracy: 0.9429
# Epoch 32: val_loss did not improve from 0.58357
# 545/545 [==============================] - 38s 69ms/step - loss: 0.7033 - accuracy: 0.9429 - val_loss: 0.5881 - val_accuracy: 0.9152 - lr: 1.2500e-04
# Epoch 33/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7030 - accuracy: 0.9414
# Epoch 33: val_loss did not improve from 0.58357
# 545/545 [==============================] - 37s 68ms/step - loss: 0.7031 - accuracy: 0.9414 - val_loss: 0.5904 - val_accuracy: 0.9124 - lr: 1.2500e-04
# Epoch 34/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.7030 - accuracy: 0.9405
# Epoch 34: val_loss did not improve from 0.58357
# 545/545 [==============================] - 38s 70ms/step - loss: 0.7030 - accuracy: 0.9405 - val_loss: 0.5839 - val_accuracy: 0.9155 - lr: 1.2500e-04
# 24/24 [==============================] - 2s 47ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v22_optimize (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9852    0.9071    0.9446      1906
#          Run     0.9669    0.9954    0.9809      1085
#         Idle     0.8896    0.8819    0.8857      1982
#        Trans     0.5778    0.7878    0.6667       410
#         Fall     0.9905    0.9733    0.9818       750
#
#     accuracy                         0.9147      6133
#    macro avg     0.8820    0.9091    0.8919      6133
# weighted avg     0.9245    0.9147    0.9180      6133
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 730
#   - TỶ LỆ RECALL TÉ NGÃ: 97.33%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/report_v22_optimize.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
    'UNIDIRECTIONAL_SEQUENCE_LSTM':'AddUnidirectionalSequenceLSTM',
}
res_lines = []
for o in reg_ops:
    m = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m}();" if m else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpol_c723c/assets
# INFO:tensorflow:Assets written to: /tmp/tmpol_c723c/assets
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781770362.634780  636125 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781770362.634808  636125 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781770362.635095  636125 reader.cc:83] Reading SavedModel from: /tmp/tmpol_c723c
# I0000 00:00:1781770362.650091  636125 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781770362.650110  636125 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpol_c723c
# I0000 00:00:1781770362.707974  636125 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781770362.720721  636125 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781770362.904257  636125 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpol_c723c
# I0000 00:00:1781770363.068234  636125 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 433164 microseconds.
# I0000 00:00:1781770363.277777  636125 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781770363.618627  636125 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.818 M  ops, equivalently 2.909 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781770364.437119  636125 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 5.818 M  ops, equivalently 2.909 M  MACs
# W0000 00:00:1781770364.437136  636125 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v22_optimize/model_v22_optimize_int8.tflite  (83320 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['ADD', 'CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'MUL', 'REDUCE_MAX', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v22_optimize.cc / .h
