# %% [markdown]
# # v29 — v28 + SỬA chuẩn hóa gyro (đơn vị rad/s)
#
# Kiến trúc = **v28** (CNN thuần ESP-NN, head **avg+max**, Trans class_weight **0.55**).
# Khác biệt **duy nhất**: `apply_preprocessing` chia gyro cho **34.907 rad/s** (full-scale đúng) thay vì 2000.
#
# **Notebook đầy đủ, cache riêng `cache_v29`.** Lưu ý: phần sửa gyro nằm ở `apply_preprocessing` (chạy *sau* khi load cache) → nội dung `cache_v29` **trùng** `cache_resize_64_32`. Muốn bỏ qua windowing chậm: trỏ `cache_dir` về `cache_resize_64_32` và bỏ chạy cell tiền xử lý + windowing.

# %% [markdown]
# ## 📌 Tài liệu: đơn vị cảm biến & sửa lỗi chuẩn hóa gyro
#
# **Đơn vị sau tiền xử lý (step1):**
# - Accel (ADXL345, ±16g, 13-bit): `raw × 32/8192` → đơn vị **g**.
# - Gyro (ITG3200, ±2000°/s, 16-bit): `raw × (4000/65536) × (π/180)` → đơn vị **rad/s** (có nhân π/180).
#
# **Lỗi ở bản cũ (v1–v28):** `apply_preprocessing` chia gyro cho **2000** — con số này khớp range **±2000 °/s**, tức được viết cho đơn vị **°/s**. Nhưng dữ liệu đã là **rad/s** → chia dư hệ số `π/180 ≈ 1/57.3`, làm **gyro nhỏ đi ~57×**. Vì lớp **Trans sống trong gyro**, việc này làm yếu đúng tín hiệu Trans cần → góp phần vào nhầm Idle↔Trans trên mọi model.
#
# **Vì sao chỉ chia, không trừ offset:** gyro ITG3200 **zero-centered** — lúc đứng yên vận tốc góc ≈ 0 (giá trị ≈ 0), KHÔNG có baseline như accel (luôn có ~1g trọng lực). Nên chuẩn hóa gyro là **phép chia thuần** theo full-scale, không cần trừ mean.
#
# **Sửa ở v29:** chia gyro cho full-scale **rad/s** = `2000 × π/180 = 34.907 rad/s` — khôi phục đúng ý "±full-range → ±1", đối xứng với accel `clip(±8g)/8`.

# %%
# === Kích hoạt Keras 2 (legacy) cho TOÀN BỘ notebook ===
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# !pip install -q tf-keras

import shutil

ZIP_PATH  = '/media/data3/users/hungvm/dataset/sisfall/archive.zip'
WORKSPACE = '/media/data3/users/hungvm/dataset/sisfall/workspace'

if not os.path.exists(WORKSPACE):
    os.makedirs(WORKSPACE)
    # !unzip -q "{ZIP_PATH}" -d "{WORKSPACE}"
    print("Giải nén hoàn tất!")
else:
    print("Workspace đã tồn tại!")
# Out:
# Workspace đã tồn tại!

# %% [markdown]
# # 2. Tiền xử lý (Extract & Preprocess - Step 1)
# Chuyển đổi gia tốc (g), góc quay (rad/s) và downsample 100Hz.

# %%
import glob
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm

INPUT_DIR  = Path(WORKSPACE) / 'SisFall_dataset'
OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Processed_v29'

target_har = {'D01', 'D02', 'D03', 'D04', 'D05', 'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17', 'D18', 'D19'}
ACCEL_SCALE = 32.0 / 8192.0
GYRO_SCALE = (4000.0 / 65536.0) * (np.pi / 180.0)

all_files = list(INPUT_DIR.rglob('*.txt'))
files_to_process = [f for f in all_files if f.name.startswith('F') or f.name[:3] in target_har]

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

for file_path in tqdm(files_to_process, desc="Preprocessing"):
    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            lines = f.readlines()
            
        data = []
        for line in lines:
            line = line.strip().rstrip(';')
            if not line: continue
            parts = line.split(',')
            if len(parts) >= 6:
                data.append([float(x) for x in parts[:6]])
                
        if not data: continue
        df = pd.DataFrame(data, columns=['ax', 'ay', 'az', 'gx', 'gy', 'gz'])
        
        df[['ax', 'ay', 'az']] *= ACCEL_SCALE
        df[['gx', 'gy', 'gz']] *= GYRO_SCALE
        df = df.iloc[::2, :].reset_index(drop=True)
        
        rel_path = file_path.relative_to(INPUT_DIR)
        out_file = OUTPUT_DIR / rel_path.parent / (file_path.stem + '.csv')
        out_file.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(out_file, index=False)
    except Exception as e:
        pass
print("Hoàn tất Step 1!")
# Out:
# Preprocessing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Step 1!

# %% [markdown]
# # 3. Cắt Window (Windowing - Step 2) — bản chỉnh cho Trans/D18/D19
#
# - **D18 (vấp khi đi)** & **D19 (nhảy nhẹ)**: chỉ lấy **1 cửa sổ Trans** tại đỉnh SVM cao nhất; phần đi bộ còn lại **bỏ hết** (không Walk, không Idle).
# - **Trans augment ×3**: dịch trước/sau 20 mẫu — **chỉ cho subject TRAIN** (tránh thổi phồng Val/Test).
# - D01/D02/D05→Walk, D03/D04→Run (sliding window); D07…D17→Trans(≤2 đỉnh)+Idle.

# %%
from scipy.signal import find_peaks

WINDOW_OUTPUT_DIR = Path(WORKSPACE) / 'SisFall_dataset_Windowed_v29'

# Chỉ AUGMENT Trans cho các subject thuộc tập TRAIN -> tránh rò rỉ/thổi phồng Val/Test.
TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
TRANS_AUG_SHIFTS = [-20, 0, 20]   # dịch trước/sau 20 mẫu -> x3 mẫu Trans

def extract_window(df, center, window_size=200):
    start, end = center - window_size // 2, center + window_size // 2
    if start < 0: start, end = 0, window_size
    if end > len(df): end, start = len(df), max(0, len(df) - window_size)
    return df.iloc[start:end]

def classify_idle(win_df):
    ax_m, ay_m, az_m = win_df['ax'].abs().mean(), win_df['ay'].abs().mean(), win_df['az'].abs().mean()
    return 'Idle_StandSit' if (ay_m > ax_m and ay_m > az_m) else 'Idle_Lie'

def save_trans(df, peak, out_dir, filename, subject_id, tag):
    # Lưu 1 cửa sổ Trans tại peak; augment x3 (dịch +-20) nếu subject thuộc TRAIN.
    shifts = TRANS_AUG_SHIFTS if subject_id in TRAIN_SUBJECTS else [0]
    n = 0
    for shift in shifts:
        win = extract_window(df, peak + shift)
        if len(win) == 200:
            win.to_csv(out_dir / f"{filename}_Trans_{tag}_s{shift:+d}.csv", index=False)
            n += 1
    return n

all_processed = list(OUTPUT_DIR.rglob('*.csv'))
trans_har    = {'D07', 'D08', 'D11', 'D12', 'D13', 'D15', 'D17'}  # ADL ngồi/đứng/nằm -> Trans + Idle
cont_har     = {'D01', 'D02', 'D03', 'D04', 'D05'}                # đi/chạy liên tục (KHÔNG còn D18/D19)
stumble_jump = {'D18', 'D19'}                                     # D18 vấp khi đi, D19 nhảy nhẹ

windows_generated = 0
for f in tqdm(all_processed, desc="Windowing"):
    df = pd.read_csv(f)
    if len(df) < 200: continue

    filename, prefix = f.stem, f.stem[:3]
    subject_id = filename.split('_')[1]
    out_dir = WINDOW_OUTPUT_DIR / f.parent.name
    out_dir.mkdir(parents=True, exist_ok=True)
    svm = np.sqrt(df['ax']**2 + df['ay']**2 + df['az']**2)

    if filename.startswith('F'):
        # Fall: 5 cửa sổ quanh đỉnh va chạm
        peak_idx = int(svm.argmax())
        for w_idx, shift in enumerate([-60, -30, 0, 30, 60]):
            win = extract_window(df, peak_idx + shift)
            if len(win) == 200:
                win.to_csv(out_dir / f"{filename}_Fall_W{w_idx:03d}.csv", index=False)
                windows_generated += 1

    elif prefix in stumble_jump:
        # D18 (vấp khi đi) / D19 (nhảy nhẹ): CHỈ 1 cửa sổ Trans tại đỉnh SVM cao nhất.
        # Phần còn lại (đi bộ) BỎ HẾT: không lấy Walk, không lấy Idle (Walk đã quá nhiều).
        peak_idx = int(svm.argmax())
        windows_generated += save_trans(df, peak_idx, out_dir, filename, subject_id, 'P000')

    elif prefix in trans_har:
        # ADL chuyển động: lấy tối đa 2 đỉnh SVM cao nhất làm Trans (mỗi đỉnh augment x3 nếu train)
        peaks, props = find_peaks(svm, height=1.0, distance=200)
        if len(peaks) >= 2:
            selected_peaks = np.sort(peaks[np.argsort(props['peak_heights'])[-2:]])
        elif len(peaks) == 1:
            selected_peaks = peaks
        else:
            selected_peaks = [int(svm.argmax())]

        for i, peak in enumerate(selected_peaks):
            windows_generated += save_trans(df, int(peak), out_dir, filename, subject_id, f'W{i:03d}')

        # Idle: các đoạn cách xa MỌI đỉnh >= 80 mẫu (không augment)
        for start in range(0, len(df) - 200 + 1, 100):
            center = start + 100
            if all(abs(center - p) >= 80 for p in selected_peaks):
                win = df.iloc[start:start+200]
                win.to_csv(out_dir / f"{filename}_{classify_idle(win)}_W{start//100:03d}.csv", index=False)
                windows_generated += 1

    elif prefix in cont_har:
        # Đi/chạy liên tục: sliding window step=100
        for start in range(0, len(df) - 200 + 1, 100):
            win = df.iloc[start:start+200]
            label = "Walk" if prefix in {'D01', 'D02', 'D05'} else "Run"
            win.to_csv(out_dir / f"{filename}_{label}_W{start//100:03d}.csv", index=False)
            windows_generated += 1

print(f"Hoàn tất Windowing! Tổng số cửa sổ: {windows_generated}")
# Out:
# Windowing:   0%|          | 0/3637 [00:00<?, ?it/s]
# Hoàn tất Windowing! Tổng số cửa sổ: 47506

# %% [markdown]
# # 4. ML Pipeline I/O (DataPreprocessor & OutputReporter)
# Đây là 2 class cốt lõi chịu trách nhiệm tổ chức Dataloader, Caching, Split Subject và Report.

# %%
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import shutil

class DataPreprocessor:
    def __init__(self, data_dir, cache_dir, class_names):
        self.data_dir = Path(data_dir)
        self.cache_dir = Path(cache_dir)
        self.class_names = class_names
        
        self.TRAIN_SUBJECTS = {f"SA{i:02d}" for i in range(1, 19)} | {f"SE{i:02d}" for i in range(1, 9)}
        self.VAL_SUBJECTS = {f"SA{i:02d}" for i in range(19, 22)} | {f"SE{i:02d}" for i in range(9, 12)}
        self.TEST_SUBJECTS = {f"SA{i:02d}" for i in range(22, 24)} | {f"SE{i:02d}" for i in range(12, 16)}

    def parse_filename_info(self, filename):
        if '_Trans_' in filename: return 'Trans'
        if '_StandSit_' in filename or '_Lie_' in filename: return 'Idle'
        prefix = filename[:3]
        if prefix in ['D01', 'D02', 'D05', 'D06']: return 'Walk'
        if prefix in ['D03', 'D04']: return 'Run'
        if prefix.startswith('F'): return 'Fall'
        return None

    def load_single_csv(self, file_path):
        try:
            filename = file_path.stem
            subject_id = filename.split('_')[1]
            label_str = self.parse_filename_info(filename)
            if label_str is None: return None
            label = self.class_names.index(label_str)
            df = pd.read_csv(file_path)
            if len(df) != 200: return None
            return df.to_numpy(), label, subject_id
        except: return None

    def load_or_create_dataset(self):
        self.cache_dir.mkdir(exist_ok=True, parents=True)
        train_x, train_y = self.cache_dir/'X_train.npy', self.cache_dir/'y_train.npy'
        val_x, val_y = self.cache_dir/'X_val.npy', self.cache_dir/'y_val.npy'
        test_x, test_y = self.cache_dir/'X_test.npy', self.cache_dir/'y_test.npy'
        
        if all(p.exists() for p in [train_x, train_y, val_x, val_y, test_x, test_y]):
            print("[*] Load data từ Cache...")
            return (np.load(train_x), np.load(train_y), np.load(val_x), np.load(val_y), np.load(test_x), np.load(test_y))

        print(f"[*] Đang đọc file CSV từ {self.data_dir}...")
        all_files = list(self.data_dir.rglob('*.csv'))
        
        if len(all_files) == 0:
            raise FileNotFoundError(f"LỖI: Không tìm thấy file CSV nào trong {self.data_dir}. Vui lòng chạy lại Bước 2 (Windowing)!")
            
        X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            for res in tqdm(executor.map(self.load_single_csv, all_files), total=len(all_files)):
                if res is None: continue
                data, label, sub = res
                if sub in self.TRAIN_SUBJECTS: X_train.append(data); y_train.append(label)
                elif sub in self.VAL_SUBJECTS: X_val.append(data); y_val.append(label)
                elif sub in self.TEST_SUBJECTS: X_test.append(data); y_test.append(label)
                    
        X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.int32)
        X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.int32)
        X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.int32)
        
        np.save(train_x, X_train); np.save(train_y, y_train)
        np.save(val_x, X_val); np.save(val_y, y_val)
        np.save(test_x, X_test); np.save(test_y, y_test)
        
        return X_train, y_train, X_val, y_val, X_test, y_test

    def apply_preprocessing(self, X_train, X_val, X_test):
        # Sửa lỗi Index Error: Chỉ cắt mảng nếu mảng thực sự có chứa dữ liệu (3 chiều)
        for X in [X_train, X_val, X_test]:
            if X.ndim == 3 and X.shape[0] > 0:
                X[:, :, 0:3] = np.clip(X[:, :, 0:3], -8.0, 8.0) / 8.0
                # FIX v29: gyro da o rad/s (step1 nhan pi/180). /2000 cu la cho deg/s -> sai don vi.
                # Chia full-scale rad/s = 2000*pi/180 = 34.907. Gyro zero-centered nen chi chia, khong tru offset.
                X[:, :, 3:6] = X[:, :, 3:6] / (2000.0 * np.pi / 180.0)   # = /34.907 rad/s
        return X_train, X_val, X_test

    def get_balanced_class_weights(self, y_train, class_weight_modifiers=None):
        if len(y_train) == 0: return {}
        vals = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
        weights = dict(zip(np.unique(y_train), vals))
        if class_weight_modifiers:
            for cls_name, mod in class_weight_modifiers.items():
                if cls_name in self.class_names:
                    weights[self.class_names.index(cls_name)] *= mod
        return weights

class OutputReporter:
    def __init__(self, out_dir, class_names):
        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(exist_ok=True, parents=True)
        self.class_names = class_names

    def plot_training_history(self, history, version="v_colab"):
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train'); plt.plot(history.history['val_accuracy'], label='Val'); plt.legend(); plt.title('Accuracy')
        plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train'); plt.plot(history.history['val_loss'], label='Val'); plt.legend(); plt.title('Loss')
        plt.tight_layout(); plt.savefig(self.out_dir / f'history_{version}.png'); plt.show()

    def evaluate_and_report(self, model, X_test, y_test, version="v_colab", fall_threshold=0.25):
        if len(X_test) == 0: return
        fall_idx = self.class_names.index('Fall')
        y_pred_probs = model.predict(X_test, batch_size=256)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_pred[y_pred_probs[:, fall_idx] >= fall_threshold] = fall_idx
        
        report_str = "\n" + "="*50 + "\n"
        report_str += f"BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - {version} (Threshold {fall_threshold})\n"
        report_str += "="*50 + "\n"
        
        cls_report = classification_report(y_test, y_pred, target_names=self.class_names, digits=4)
        report_str += cls_report + "\n"
        print(report_str)
        
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8,6))
        plt.imshow(cm, cmap=plt.cm.Blues); plt.colorbar()
        plt.xticks(np.arange(len(self.class_names)), self.class_names, rotation=45)
        plt.yticks(np.arange(len(self.class_names)), self.class_names)
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i,j],'d'), ha="center", color="white" if cm[i,j] > cm.max()/2. else "black")
        plt.ylabel('Nhãn Thực Tế')
        plt.xlabel('Nhãn Dự Đoán')
        plt.tight_layout()
        plt.savefig(self.out_dir / f'confusion_matrix_{version}.png')
        plt.show()
        
        true_falls = np.sum(y_test == fall_idx)
        detected_falls = cm[fall_idx, fall_idx]
        recall_fall = (detected_falls / true_falls) * 100 if true_falls > 0 else 0
        
        eval_str = "\n" + "="*50 + "\n"
        eval_str += "KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):\n"
        eval_str += f"  - Số ca ngã thực tế: {true_falls}\n"
        eval_str += f"  - Số ca ngã phát hiện đúng: {detected_falls}\n"
        eval_str += f"  - TỶ LỆ RECALL TÉ NGÃ: {recall_fall:.2f}%\n"
        eval_str += "="*50 + "\n"
        
        print(eval_str)
        report_str += eval_str
        
        with open(self.out_dir / f'report_{version}.txt', 'w', encoding='utf-8') as rf:
            rf.write(report_str)
        print(f"[*] Đã lưu báo cáo tại {self.out_dir / f'report_{version}.txt'}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781775164.127942  800612 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5. Kiến trúc Model — v29 (CNN thuần ESP-NN, head avg+max)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv1D, SeparableConv1D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, Flatten, Concatenate, Dropout, Dense)
from tensorflow.keras.models import Model

def build_model(input_shape=(200, 6), n_classes=5):
    # v29 = kien truc v28 (CNN thuan ESP-NN, head avg+max). Chi khac o apply_preprocessing (gyro scale).
    #   Head avg+max: GAP pha loang xung gyro cua Trans -> them nhanh max-over-time giu dinh.
    #   Dung MaxPooling1D(full)+Flatten (op MAX_POOL_2D, ESP-NN 7.83x) thay GlobalMaxPooling (REDUCE_MAX, khong tang toc).
    inp = Input(shape=input_shape)

    x = Conv1D(24, 3, strides=2, padding='same', use_bias=False)(inp)
    x = BatchNormalization()(x); x = Activation('relu6')(x)

    x = SeparableConv1D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 100->50

    x = SeparableConv1D(48, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 50->25

    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x); x = Activation('relu6')(x)
    x = MaxPooling1D(2)(x)                       # 25->12

    # Head: avg (MEAN) + max-over-time (MAX_POOL_2D) -> bat dinh xung gyro cua Trans
    a = GlobalAveragePooling1D()(x)
    m = MaxPooling1D(pool_size=int(x.shape[1]))(x)
    m = Flatten()(m)
    x = Concatenate()([a, m])
    x = Dropout(0.3)(x)
    outputs = Dense(n_classes, activation='softmax')(x)

    model = Model(inp, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # 6. Huấn luyện + Đánh giá

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

class FallDetectionTrainerResize(DataPreprocessor, OutputReporter):
    def __init__(self):
        data_dir  = f'{WORKSPACE}/SisFall_dataset_Windowed_v29'
        cache_dir = f'{WORKSPACE}/cache_v29'
        out_dir   = f'{WORKSPACE}/output_v29'
        class_names = ['Walk', 'Run', 'Idle', 'Trans', 'Fall']
        DataPreprocessor.__init__(self, data_dir, cache_dir, class_names)
        OutputReporter.__init__(self, out_dir, class_names)
        self.version = "v29"

trainer = FallDetectionTrainerResize()
checkpoint_path = Path(trainer.out_dir) / f'best_model_{trainer.version}.keras'

# 1. Nạp + tiền xử lý
X_train, y_train, X_val, y_val, X_test, y_test = trainer.load_or_create_dataset()
X_train, X_val, X_test = trainer.apply_preprocessing(X_train, X_val, X_test)
print("Phân bố nhãn train:", {trainer.class_names[k]: int((y_train==k).sum()) for k in range(5)})

# 2. Class weights (đẩy Fall x3)
weight_modifiers = {'Fall': 3.0, 'Trans': 0.55, 'Idle': 1.0}
class_weights = trainer.get_balanced_class_weights(y_train, weight_modifiers)

# 3. One-hot
y_train_oh = to_categorical(y_train, num_classes=5)
y_val_oh = to_categorical(y_val, num_classes=5)

# 4. Build model RESIZE
model = build_model(input_shape=(200, 6), n_classes=5)
model.summary()

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath=str(checkpoint_path), monitor='val_loss', save_best_only=True, verbose=1),
]

# 6. Train
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=100, batch_size=64,
    class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

# 7. Đánh giá
trainer.plot_training_history(history, version=trainer.version)
trainer.evaluate_and_report(model, X_test, y_test, version=trainer.version, fall_threshold=0.25)
# Out:
# [*] Đang đọc file CSV từ /media/data3/users/hungvm/dataset/sisfall/workspace/SisFall_dataset_Windowed_v29...
#   0%|          | 0/47506 [00:00<?, ?it/s]
# Phân bố nhãn train: {'Walk': 8427, 'Run': 5217, 'Idle': 8365, 'Trans': 5706, 'Fall': 7125}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 6)]             0         []
#
#  conv1d (Conv1D)             (None, 100, 24)              432       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 100, 24)              96        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 100, 24)              0         ['batch_normalization[0][0]']
#
#  separable_conv1d (Separabl  (None, 100, 32)              840       ['activation[0][0]']
#  eConv1D)
#
#  batch_normalization_1 (Bat  (None, 100, 32)              128       ['separable_conv1d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 100, 32)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 50, 32)               0         ['activation_1[0][0]']
#  D)
#
#  separable_conv1d_1 (Separa  (None, 50, 48)               1632      ['max_pooling1d[0][0]']
#  bleConv1D)
#
#  batch_normalization_2 (Bat  (None, 50, 48)               192       ['separable_conv1d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 50, 48)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 48)               0         ['activation_2[0][0]']
#  g1D)
#
#  separable_conv1d_2 (Separa  (None, 25, 64)               3216      ['max_pooling1d_1[0][0]']
#  bleConv1D)
#
#  batch_normalization_3 (Bat  (None, 25, 64)               256       ['separable_conv1d_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 25, 64)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 12, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)                0         ['max_pooling1d_2[0][0]']
#  g1D)
#
#  global_average_pooling1d (  (None, 64)                   0         ['max_pooling1d_2[0][0]']
#  GlobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 64)                   0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 5)                    645       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7437 (29.05 KB)
# Trainable params: 7101 (27.74 KB)
# Non-trainable params: 336 (1.31 KB)
# __________________________________________________________________________________________________
# I0000 00:00:1781775208.644109  800612 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9781 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/100
# I0000 00:00:1781775210.462199  811717 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1781775211.831054  811717 service.cc:153] XLA service 0x7f2442efa660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781775211.831084  811717 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 12.4.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1781775211.835565  811717 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781775211.920563  811717 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 545/545 [==============================] - ETA: 0s - loss: 1.0946 - accuracy: 0.7537
# Epoch 1: val_loss improved from inf to 0.91122, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 8s 6ms/step - loss: 1.0946 - accuracy: 0.7537 - val_loss: 0.9112 - val_accuracy: 0.7802 - lr: 0.0010
# Epoch 2/100
# 545/545 [==============================] - ETA: 0s - loss: 0.8053 - accuracy: 0.8598
# Epoch 2: val_loss improved from 0.91122 to 0.61997, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.8053 - accuracy: 0.8598 - val_loss: 0.6200 - val_accuracy: 0.9065 - lr: 0.0010
# Epoch 3/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.7488 - accuracy: 0.8885
# Epoch 3: val_loss improved from 0.61997 to 0.59647, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7488 - accuracy: 0.8885 - val_loss: 0.5965 - val_accuracy: 0.9166 - lr: 0.0010
# Epoch 4/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.7251 - accuracy: 0.9003
# Epoch 4: val_loss did not improve from 0.59647
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7252 - accuracy: 0.9004 - val_loss: 0.6015 - val_accuracy: 0.9128 - lr: 0.0010
# Epoch 5/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.9077
# Epoch 5: val_loss improved from 0.59647 to 0.58525, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7108 - accuracy: 0.9077 - val_loss: 0.5852 - val_accuracy: 0.9199 - lr: 0.0010
# Epoch 6/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.7015 - accuracy: 0.9112
# Epoch 6: val_loss did not improve from 0.58525
# 545/545 [==============================] - 3s 6ms/step - loss: 0.7018 - accuracy: 0.9111 - val_loss: 0.5859 - val_accuracy: 0.9184 - lr: 0.0010
# Epoch 7/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6943 - accuracy: 0.9127
# Epoch 7: val_loss did not improve from 0.58525
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6944 - accuracy: 0.9127 - val_loss: 0.5888 - val_accuracy: 0.9178 - lr: 0.0010
# Epoch 8/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6845 - accuracy: 0.9185
# Epoch 8: val_loss improved from 0.58525 to 0.57396, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6845 - accuracy: 0.9185 - val_loss: 0.5740 - val_accuracy: 0.9230 - lr: 0.0010
# Epoch 9/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6812 - accuracy: 0.9188
# Epoch 9: val_loss did not improve from 0.57396
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6815 - accuracy: 0.9187 - val_loss: 0.5778 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 10/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6759 - accuracy: 0.9227
# Epoch 10: val_loss did not improve from 0.57396
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6760 - accuracy: 0.9228 - val_loss: 0.5787 - val_accuracy: 0.9233 - lr: 0.0010
# Epoch 11/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.9231
# Epoch 11: val_loss did not improve from 0.57396
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6727 - accuracy: 0.9232 - val_loss: 0.5812 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 12/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6683 - accuracy: 0.9249
# Epoch 12: val_loss improved from 0.57396 to 0.56500, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6684 - accuracy: 0.9249 - val_loss: 0.5650 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 13/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6661 - accuracy: 0.9264
# Epoch 13: val_loss did not improve from 0.56500
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6660 - accuracy: 0.9264 - val_loss: 0.5735 - val_accuracy: 0.9229 - lr: 0.0010
# Epoch 14/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6634 - accuracy: 0.9272
# Epoch 14: val_loss did not improve from 0.56500
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6635 - accuracy: 0.9273 - val_loss: 0.5705 - val_accuracy: 0.9239 - lr: 0.0010
# Epoch 15/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6606 - accuracy: 0.9273
# Epoch 15: val_loss improved from 0.56500 to 0.56399, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6606 - accuracy: 0.9272 - val_loss: 0.5640 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 16/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6580 - accuracy: 0.9298
# Epoch 16: val_loss did not improve from 0.56399
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6581 - accuracy: 0.9300 - val_loss: 0.5695 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 17/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6556 - accuracy: 0.9298
# Epoch 17: val_loss improved from 0.56399 to 0.56003, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6557 - accuracy: 0.9298 - val_loss: 0.5600 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 18/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6556 - accuracy: 0.9313
# Epoch 18: val_loss improved from 0.56003 to 0.55800, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6555 - accuracy: 0.9314 - val_loss: 0.5580 - val_accuracy: 0.9294 - lr: 0.0010
# Epoch 19/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6532 - accuracy: 0.9316
# Epoch 19: val_loss did not improve from 0.55800
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6533 - accuracy: 0.9316 - val_loss: 0.5588 - val_accuracy: 0.9271 - lr: 0.0010
# Epoch 20/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6517 - accuracy: 0.9331
# Epoch 20: val_loss did not improve from 0.55800
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6517 - accuracy: 0.9333 - val_loss: 0.5644 - val_accuracy: 0.9267 - lr: 0.0010
# Epoch 21/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6497 - accuracy: 0.9341
# Epoch 21: val_loss improved from 0.55800 to 0.55505, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6496 - accuracy: 0.9340 - val_loss: 0.5550 - val_accuracy: 0.9300 - lr: 0.0010
# Epoch 22/100
# 539/545 [============================>.] - ETA: 0s - loss: 0.6481 - accuracy: 0.9339
# Epoch 22: val_loss improved from 0.55505 to 0.54787, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6483 - accuracy: 0.9339 - val_loss: 0.5479 - val_accuracy: 0.9322 - lr: 0.0010
# Epoch 23/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6471 - accuracy: 0.9347
# Epoch 23: val_loss did not improve from 0.54787
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6473 - accuracy: 0.9347 - val_loss: 0.5645 - val_accuracy: 0.9291 - lr: 0.0010
# Epoch 24/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6472 - accuracy: 0.9347
# Epoch 24: val_loss did not improve from 0.54787
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6472 - accuracy: 0.9348 - val_loss: 0.5501 - val_accuracy: 0.9336 - lr: 0.0010
# Epoch 25/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6458 - accuracy: 0.9359
# Epoch 25: val_loss did not improve from 0.54787
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6457 - accuracy: 0.9357 - val_loss: 0.5522 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 26/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6450 - accuracy: 0.9368
# Epoch 26: val_loss did not improve from 0.54787
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6449 - accuracy: 0.9370 - val_loss: 0.5513 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 27/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6437 - accuracy: 0.9360
# Epoch 27: val_loss did not improve from 0.54787
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6437 - accuracy: 0.9360 - val_loss: 0.5505 - val_accuracy: 0.9316 - lr: 0.0010
# Epoch 28/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6385 - accuracy: 0.9400
# Epoch 28: val_loss improved from 0.54787 to 0.54643, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6386 - accuracy: 0.9399 - val_loss: 0.5464 - val_accuracy: 0.9342 - lr: 5.0000e-04
# Epoch 29/100
# 543/545 [============================>.] - ETA: 0s - loss: 0.6374 - accuracy: 0.9392
# Epoch 29: val_loss did not improve from 0.54643
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6376 - accuracy: 0.9392 - val_loss: 0.5510 - val_accuracy: 0.9336 - lr: 5.0000e-04
# Epoch 30/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6366 - accuracy: 0.9403
# Epoch 30: val_loss improved from 0.54643 to 0.54526, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6363 - accuracy: 0.9405 - val_loss: 0.5453 - val_accuracy: 0.9345 - lr: 5.0000e-04
# Epoch 31/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6375 - accuracy: 0.9402
# Epoch 31: val_loss improved from 0.54526 to 0.54417, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6374 - accuracy: 0.9403 - val_loss: 0.5442 - val_accuracy: 0.9349 - lr: 5.0000e-04
# Epoch 32/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6368 - accuracy: 0.9406
# Epoch 32: val_loss did not improve from 0.54417
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6364 - accuracy: 0.9407 - val_loss: 0.5466 - val_accuracy: 0.9349 - lr: 5.0000e-04
# Epoch 33/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6362 - accuracy: 0.9410
# Epoch 33: val_loss improved from 0.54417 to 0.54403, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6361 - accuracy: 0.9411 - val_loss: 0.5440 - val_accuracy: 0.9360 - lr: 5.0000e-04
# Epoch 34/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6360 - accuracy: 0.9411
# Epoch 34: val_loss did not improve from 0.54403
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6360 - accuracy: 0.9411 - val_loss: 0.5475 - val_accuracy: 0.9336 - lr: 5.0000e-04
# Epoch 35/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6351 - accuracy: 0.9420
# Epoch 35: val_loss did not improve from 0.54403
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6351 - accuracy: 0.9421 - val_loss: 0.5461 - val_accuracy: 0.9356 - lr: 5.0000e-04
# Epoch 36/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.9431
# Epoch 36: val_loss did not improve from 0.54403
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6344 - accuracy: 0.9429 - val_loss: 0.5441 - val_accuracy: 0.9359 - lr: 5.0000e-04
# Epoch 37/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6337 - accuracy: 0.9425
# Epoch 37: val_loss did not improve from 0.54403
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6338 - accuracy: 0.9424 - val_loss: 0.5463 - val_accuracy: 0.9362 - lr: 5.0000e-04
# Epoch 38/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6341 - accuracy: 0.9424
# Epoch 38: val_loss improved from 0.54403 to 0.54173, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6339 - accuracy: 0.9424 - val_loss: 0.5417 - val_accuracy: 0.9374 - lr: 5.0000e-04
# Epoch 39/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6330 - accuracy: 0.9435
# Epoch 39: val_loss did not improve from 0.54173
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6330 - accuracy: 0.9435 - val_loss: 0.5446 - val_accuracy: 0.9345 - lr: 5.0000e-04
# Epoch 40/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6322 - accuracy: 0.9427
# Epoch 40: val_loss did not improve from 0.54173
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6324 - accuracy: 0.9427 - val_loss: 0.5424 - val_accuracy: 0.9365 - lr: 5.0000e-04
# Epoch 41/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6331 - accuracy: 0.9431
# Epoch 41: val_loss did not improve from 0.54173
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6328 - accuracy: 0.9433 - val_loss: 0.5482 - val_accuracy: 0.9348 - lr: 5.0000e-04
# Epoch 42/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.9429
# Epoch 42: val_loss did not improve from 0.54173
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6329 - accuracy: 0.9429 - val_loss: 0.5427 - val_accuracy: 0.9366 - lr: 5.0000e-04
# Epoch 43/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.9432
# Epoch 43: val_loss did not improve from 0.54173
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6324 - accuracy: 0.9432 - val_loss: 0.5463 - val_accuracy: 0.9354 - lr: 5.0000e-04
# Epoch 44/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6292 - accuracy: 0.9441
# Epoch 44: val_loss improved from 0.54173 to 0.54136, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6295 - accuracy: 0.9442 - val_loss: 0.5414 - val_accuracy: 0.9380 - lr: 2.5000e-04
# Epoch 45/100
# 538/545 [============================>.] - ETA: 0s - loss: 0.6290 - accuracy: 0.9452
# Epoch 45: val_loss did not improve from 0.54136
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6290 - accuracy: 0.9451 - val_loss: 0.5474 - val_accuracy: 0.9354 - lr: 2.5000e-04
# Epoch 46/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.9447
# Epoch 46: val_loss did not improve from 0.54136
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6288 - accuracy: 0.9447 - val_loss: 0.5448 - val_accuracy: 0.9359 - lr: 2.5000e-04
# Epoch 47/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6274 - accuracy: 0.9461
# Epoch 47: val_loss improved from 0.54136 to 0.54034, saving model to /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/best_model_v29.keras
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6274 - accuracy: 0.9462 - val_loss: 0.5403 - val_accuracy: 0.9379 - lr: 2.5000e-04
# Epoch 48/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6290 - accuracy: 0.9453
# Epoch 48: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6287 - accuracy: 0.9452 - val_loss: 0.5429 - val_accuracy: 0.9366 - lr: 2.5000e-04
# Epoch 49/100
# 540/545 [============================>.] - ETA: 0s - loss: 0.6284 - accuracy: 0.9461
# Epoch 49: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6283 - accuracy: 0.9459 - val_loss: 0.5452 - val_accuracy: 0.9365 - lr: 2.5000e-04
# Epoch 50/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6274 - accuracy: 0.9460
# Epoch 50: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6274 - accuracy: 0.9460 - val_loss: 0.5438 - val_accuracy: 0.9374 - lr: 2.5000e-04
# Epoch 51/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.9454
# Epoch 51: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6276 - accuracy: 0.9454 - val_loss: 0.5443 - val_accuracy: 0.9368 - lr: 2.5000e-04
# Epoch 52/100
# 544/545 [============================>.] - ETA: 0s - loss: 0.6277 - accuracy: 0.9455
# Epoch 52: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6276 - accuracy: 0.9455 - val_loss: 0.5464 - val_accuracy: 0.9369 - lr: 2.5000e-04
# Epoch 53/100
# 542/545 [============================>.] - ETA: 0s - loss: 0.6267 - accuracy: 0.9463
# Epoch 53: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6264 - accuracy: 0.9463 - val_loss: 0.5464 - val_accuracy: 0.9356 - lr: 1.2500e-04
# Epoch 54/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6266 - accuracy: 0.9464
# Epoch 54: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6268 - accuracy: 0.9464 - val_loss: 0.5425 - val_accuracy: 0.9371 - lr: 1.2500e-04
# Epoch 55/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6272 - accuracy: 0.9467
# Epoch 55: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6267 - accuracy: 0.9469 - val_loss: 0.5416 - val_accuracy: 0.9369 - lr: 1.2500e-04
# Epoch 56/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.9458
# Epoch 56: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6264 - accuracy: 0.9458 - val_loss: 0.5434 - val_accuracy: 0.9380 - lr: 1.2500e-04
# Epoch 57/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6261 - accuracy: 0.9461
# Epoch 57: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6262 - accuracy: 0.9462 - val_loss: 0.5418 - val_accuracy: 0.9377 - lr: 1.2500e-04
# Epoch 58/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.9470
# Epoch 58: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6254 - accuracy: 0.9470 - val_loss: 0.5459 - val_accuracy: 0.9365 - lr: 6.2500e-05
# Epoch 59/100
# 545/545 [==============================] - ETA: 0s - loss: 0.6250 - accuracy: 0.9467
# Epoch 59: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6250 - accuracy: 0.9467 - val_loss: 0.5448 - val_accuracy: 0.9369 - lr: 6.2500e-05
# Epoch 60/100
# 536/545 [============================>.] - ETA: 0s - loss: 0.6257 - accuracy: 0.9474
# Epoch 60: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6255 - accuracy: 0.9473 - val_loss: 0.5457 - val_accuracy: 0.9365 - lr: 6.2500e-05
# Epoch 61/100
# 541/545 [============================>.] - ETA: 0s - loss: 0.6242 - accuracy: 0.9477
# Epoch 61: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6242 - accuracy: 0.9479 - val_loss: 0.5421 - val_accuracy: 0.9379 - lr: 6.2500e-05
# Epoch 62/100
# 537/545 [============================>.] - ETA: 0s - loss: 0.6256 - accuracy: 0.9476
# Epoch 62: val_loss did not improve from 0.54034
# 545/545 [==============================] - 3s 6ms/step - loss: 0.6252 - accuracy: 0.9478 - val_loss: 0.5423 - val_accuracy: 0.9379 - lr: 6.2500e-05
# 24/24 [==============================] - 0s 3ms/step
#
# ==================================================
# BÁO CÁO PHÂN LOẠI TẬP KIỂM THỬ - v29 (Threshold 0.25)
# ==================================================
#               precision    recall  f1-score   support
#
#         Walk     0.9738    0.9355    0.9542      1906
#          Run     0.9829    0.9539    0.9682      1085
#         Idle     0.9018    0.9268    0.9142      1982
#        Trans     0.7159    0.7683    0.7412       410
#         Fall     0.9495    0.9773    0.9632       750
#
#     accuracy                         0.9299      6133
#    macro avg     0.9048    0.9124    0.9082      6133
# weighted avg     0.9319    0.9299    0.9306      6133
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ CHUYÊN BIỆT LỚP TÉ NGÃ (FALL):
#   - Số ca ngã thực tế: 750
#   - Số ca ngã phát hiện đúng: 733
#   - TỶ LỆ RECALL TÉ NGÃ: 97.73%
# ==================================================
#
# [*] Đã lưu báo cáo tại /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/report_v29.txt

# %% [markdown]
# # 7. Export INT8 TFLite → `model_data_v1_resize.cc/.h`

# %%
# === Export INT8 TFLite + sinh model_data .cc/.h (NHUNG SAN ops cho TFLM wrapper) ===
import numpy as np
ver = trainer.version
out_dir = Path(trainer.out_dir)

np.random.seed(42)
rep_idx = np.random.choice(len(X_train), size=min(300, len(X_train)), replace=False)
def representative_data_gen():
    for i in rep_idx:
        yield [X_train[i:i+1].astype(np.float32)]

static_in = tf.keras.Input(batch_shape=(1, 200, 6), dtype='float32')
static_model = tf.keras.models.clone_model(model, input_tensors=static_in)
static_model.set_weights(model.get_weights())

converter = tf.lite.TFLiteConverter.from_keras_model(static_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

tflite_path = out_dir / f'model_{ver}_int8.tflite'
tflite_path.write_bytes(tflite_model)
print(f"[*] Saved {tflite_path}  ({len(tflite_model)} bytes)")

it = tf.lite.Interpreter(model_content=tflite_model); it.allocate_tensors()
inp = it.get_input_details()[0]; outp = it.get_output_details()[0]
all_ops = sorted({d['op_name'] for d in it._get_ops_details()})
NON_REG = {'DELEGATE', 'CALL_ONCE', 'CUSTOM'}
reg_ops = [o for o in all_ops if o not in NON_REG]
in_scale, in_zp = inp['quantization']; out_scale, out_zp = outp['quantization']
in_len = int(np.prod(inp['shape'])); out_len = int(np.prod(outp['shape']))
print("[*] Input :", inp['shape'], inp['dtype'])
print("[*] Output:", outp['shape'], outp['dtype'])
print("[*] Ops can dang ky:", reg_ops)

OP2ADD = {
    'CONV_2D':'AddConv2D','DEPTHWISE_CONV_2D':'AddDepthwiseConv2D','MAX_POOL_2D':'AddMaxPool2D',
    'AVERAGE_POOL_2D':'AddAveragePool2D','MEAN':'AddMean','FULLY_CONNECTED':'AddFullyConnected',
    'SOFTMAX':'AddSoftmax','LOGISTIC':'AddLogistic','RELU6':'AddRelu6','RESHAPE':'AddReshape',
    'ADD':'AddAdd','MUL':'AddMul','CONCATENATION':'AddConcatenation','PAD':'AddPad',
    'QUANTIZE':'AddQuantize','DEQUANTIZE':'AddDequantize','STRIDED_SLICE':'AddStridedSlice',
}
res_lines = []
for o in reg_ops:
    m2 = OP2ADD.get(o)
    res_lines.append(f"//   resolver.{m2}();" if m2 else f"//   /* op '{o}': tu tra cuu Add method */")

meta = (
    "// ============================================================\n"
    f"// AUTO-GENERATED model data  --  {ver}\n"
    f"// TFLite INT8 size : {len(tflite_model)} bytes\n"
    "// ------------------------------------------------------------\n"
    f"// Input  : shape={list(inp['shape'])} dtype={inp['dtype'].__name__} quant(scale={in_scale:.8g}, zero_point={in_zp})\n"
    f"// Output : shape={list(outp['shape'])} dtype={outp['dtype'].__name__} quant(scale={out_scale:.8g}, zero_point={out_zp})\n"
    "// INT8<->real:  q = round(real/scale)+zero_point ; real = (q-zero_point)*scale\n"
    "// ------------------------------------------------------------\n"
    f"// OPS cua mang ({len(reg_ops)}) -- dang ky DUNG nhung op nay:\n"
    + "".join(f"//   - {o}\n" for o in reg_ops)
    + (f"// (Bo qua pseudo-op: {', '.join(o for o in all_ops if o in NON_REG)})\n" if any(o in NON_REG for o in all_ops) else "")
    + "//\n"
    f"// GOI Y MicroMutableOpResolver (so op = {len(reg_ops)}):\n"
    f"//   static tflite::MicroMutableOpResolver<{len(reg_ops)}> resolver;\n"
    + "".join(l + "\n" for l in res_lines)
    + "// ============================================================\n"
)

body, line = '', '  '
for i, b in enumerate(tflite_model):
    line += f'0x{b:02x}, '
    if (i+1) % 12 == 0:
        body += line.rstrip() + '\n'; line = '  '
if line.strip():
    body += line.rstrip()
body = body.rstrip(', \n')

cc = (meta + '#include "model_data.h"\n\n'
      f'const unsigned char g_model_data[] alignas(16) = {{\n{body}\n}};\n\n'
      f'const unsigned int g_model_data_len = {len(tflite_model)};\n')
(out_dir / f'model_data_{ver}.cc').write_text(cc, encoding='utf-8')

h = (meta + "#ifndef MODEL_DATA_H_\n#define MODEL_DATA_H_\n\n"
     f"#define MODEL_INPUT_LEN   {in_len}\n#define MODEL_OUTPUT_LEN  {out_len}\n#define MODEL_NUM_OPS     {len(reg_ops)}\n\n"
     '#ifdef __cplusplus\nextern "C" {\n#endif\n\n'
     "extern const unsigned char g_model_data[];\nextern const unsigned int g_model_data_len;\n\n"
     "#ifdef __cplusplus\n}\n#endif\n\n#endif  // MODEL_DATA_H_\n")
(out_dir / f'model_data_{ver}.h').write_text(h, encoding='utf-8')
print(f"[*] Da sinh model_data_{ver}.cc / .h")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpqigvoja2/assets
# INFO:tensorflow:Assets written to: /tmp/tmpqigvoja2/assets
# [*] Saved /media/data3/users/hungvm/dataset/sisfall/workspace/output_v29/model_v29_int8.tflite  (25080 bytes)
# [*] Input : [  1 200   6] <class 'numpy.int8'>
# [*] Output: [1 5] <class 'numpy.int8'>
# [*] Ops can dang ky: ['CONCATENATION', 'CONV_2D', 'DEPTHWISE_CONV_2D', 'FULLY_CONNECTED', 'MAX_POOL_2D', 'MEAN', 'RESHAPE', 'SOFTMAX']
# [*] Da sinh model_data_v29.cc / .h
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1781775411.273631  800612 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1781775411.273643  800612 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1781775411.273840  800612 reader.cc:83] Reading SavedModel from: /tmp/tmpqigvoja2
# I0000 00:00:1781775411.276320  800612 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1781775411.276329  800612 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpqigvoja2
# I0000 00:00:1781775411.286468  800612 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1781775411.288557  800612 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1781775411.319636  800612 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpqigvoja2
# I0000 00:00:1781775411.332830  800612 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 59000 microseconds.
# I0000 00:00:1781775411.421480  800612 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# I0000 00:00:1781775411.504610  800612 flatbuffer_export.cc:4302] Estimated count of arithmetic ops: 0.603 M  ops, equivalently 0.301 M  MACs
# W0000 00:00:1781775411.504627  800612 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.
# /media/data3/users/hungvm/anaconda3/envs/har_fall/lib/python3.11/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
